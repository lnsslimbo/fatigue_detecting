# %%
# -*- coding: utf-8 -*-
# import the necessary packages
from scipy.spatial import distance as dist
from imutils.video import FileVideoStream
from imutils.video import VideoStream
from imutils import face_utils
import numpy as np # 数据处理的库 numpy
import argparse
import imutils
import time
import dlib
import cv2
 
 
def eye_aspect_ratio(eye):
    # 垂直眼标志（X，Y）坐标
    A = dist.euclidean(eye[1], eye[5])# 计算两个集合之间的欧式距离
    B = dist.euclidean(eye[2], eye[4])
    # 计算水平之间的欧几里得距离
    # 水平眼标志（X，Y）坐标
    C = dist.euclidean(eye[0], eye[3])
    # 眼睛长宽比的计算
    ear = (A + B) / (2.0 * C)
    # 返回眼睛的长宽比
    return ear
 
def mouth_aspect_ratio(mouth):
    A = np.linalg.norm(mouth[2] - mouth[9])  # 51, 59
    B = np.linalg.norm(mouth[4] - mouth[7])  # 53, 57
    C = np.linalg.norm(mouth[0] - mouth[6])  # 49, 55
    mar = (A + B) / (2.0 * C)
    return mar


# 定义两个常数
# 眼睛长宽比
# 闪烁阈值
EYE_AR_THRESH = 0.2
EYE_AR_CONSEC_FRAMES = 3
# 打哈欠长宽比
# 闪烁阈值
MAR_THRESH = 0.5
MOUTH_AR_CONSEC_FRAMES = 3
# 初始化帧计数器和眨眼总数
COUNTER = 0
TOTAL = 0
# 初始化帧计数器和打哈欠总数
mCOUNTER = 0
mTOTAL = 0
 
# 初始化DLIB的人脸检测器（HOG），然后创建面部标志物预测
print("[INFO] loading facial landmark predictor...")
# 第一步：使用dlib.get_frontal_face_detector() 获得脸部位置检测器
detector = dlib.get_frontal_face_detector()
# 第二步：使用dlib.shape_predictor获得脸部特征位置检测器
predictor = dlib.shape_predictor('D:/myworkspace/JupyterNotebook/fatigue_detecting/model/shape_predictor_68_face_landmarks.dat')
 
# 第三步：分别获取左右眼面部标志的索引
(lStart, lEnd) = face_utils.FACIAL_LANDMARKS_IDXS["left_eye"]
(rStart, rEnd) = face_utils.FACIAL_LANDMARKS_IDXS["right_eye"]
(mStart, mEnd) = face_utils.FACIAL_LANDMARKS_IDXS["mouth"]

# 第四步：打开cv2 本地摄像头
cap = cv2.VideoCapture(0)
 
# 从视频流循环帧
while True:
    # 第五步：进行循环，读取图片，并对图片做维度扩大，并进灰度化
    ret, frame = cap.read()
    frame = imutils.resize(frame, width=720)
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    # 第六步：使用detector(gray, 0) 进行脸部位置检测
    rects = detector(gray, 0)
    
    # 第七步：循环脸部位置信息，使用predictor(gray, rect)获得脸部特征位置的信息
    for rect in rects:
        shape = predictor(gray, rect)
        
        # 第八步：将脸部特征信息转换为数组array的格式
        shape = face_utils.shape_to_np(shape)
        
        # 第九步：提取左眼和右眼坐标
        leftEye = shape[lStart:lEnd]
        rightEye = shape[rStart:rEnd]
        # 嘴巴坐标
        mouth = shape[mStart:mEnd]
        
        
        # 第十步：构造函数计算左右眼的EAR值，使用平均值作为最终的EAR
        leftEAR = eye_aspect_ratio(leftEye)
        rightEAR = eye_aspect_ratio(rightEye)
        ear = (leftEAR + rightEAR) / 2.0
        # 打哈欠
        mar = mouth_aspect_ratio(mouth)
 
        # 第十一步：使用cv2.convexHull获得凸包位置，使用drawContours画出轮廓位置进行画图操作
        leftEyeHull = cv2.convexHull(leftEye)
        rightEyeHull = cv2.convexHull(rightEye)
        cv2.drawContours(frame, [leftEyeHull], -1, (0, 255, 0), 1)
        cv2.drawContours(frame, [rightEyeHull], -1, (0, 255, 0), 1)
        mouthHull = cv2.convexHull(mouth)
        cv2.drawContours(frame, [mouthHull], -1, (0, 255, 0), 1)
 
        # 第十二步：进行画图操作，用矩形框标注人脸
        left = rect.left()
        top = rect.top()
        right = rect.right()
        bottom = rect.bottom()
        cv2.rectangle(frame, (left, top), (right, bottom), (0, 255, 0), 3)    
 
        '''
            分别计算左眼和右眼的评分求平均作为最终的评分，如果小于阈值，则加1，如果连续3次都小于阈值，则表示进行了一次眨眼活动
        '''
        # 第十三步：循环，满足条件的，眨眼次数+1
        if ear < EYE_AR_THRESH:# 眼睛长宽比：0.2
            COUNTER += 1
           
        else:
            # 如果连续3次都小于阈值，则表示进行了一次眨眼活动
            if COUNTER >= EYE_AR_CONSEC_FRAMES:# 阈值：3
                TOTAL += 1
            # 重置眼帧计数器
            COUNTER = 0
            
        # 第十四步：进行画图操作，同时使用cv2.putText将眨眼次数进行显示
        cv2.putText(frame, "Faces: {}".format(len(rects)), (10, 30),cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 0, 255), 2)
        cv2.putText(frame, "Blinks: {}".format(TOTAL), (150, 30),cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 0, 255), 2)
        cv2.putText(frame, "COUNTER: {}".format(COUNTER), (300, 30),cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 0, 255), 2) 
        cv2.putText(frame, "EAR: {:.2f}".format(ear), (450, 30),cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 0, 255), 2)
        
        '''
            计算张嘴评分，如果小于阈值，则加1，如果连续3次都小于阈值，则表示打了一次哈欠，同一次哈欠大约在3帧
        '''
        # 同理，判断是否打哈欠    
        if mar > MAR_THRESH:# 张嘴阈值0.5
            mCOUNTER += 1
            cv2.putText(frame, "Yawning!", (10, 60),cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 0, 255), 2)
        else:
            # 如果连续3次都小于阈值，则表示打了一次哈欠
            if mCOUNTER >= MOUTH_AR_CONSEC_FRAMES:# 阈值：3
                mTOTAL += 1
            # 重置嘴帧计数器
            mCOUNTER = 0
        cv2.putText(frame, "Yawning: {}".format(mTOTAL), (150, 60),cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 0, 255), 2)
        cv2.putText(frame, "mCOUNTER: {}".format(mCOUNTER), (300, 60),cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 0, 255), 2) 
        cv2.putText(frame, "MAR: {:.2f}".format(mar), (480, 60),cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 0, 255), 2)
            
        # 第十五步：进行画图操作，68个特征点标识
        for (x, y) in shape:
            cv2.circle(frame, (x, y), 1, (0, 0, 255), -1)

    print('嘴巴实时长宽比:{:.2f} '.format(mar)+"\t是否张嘴："+str([False,True][mar > MAR_THRESH]))
    print('眼睛实时长宽比:{:.2f} '.format(ear)+"\t是否眨眼："+str([False,True][COUNTER>=1]))
    
    # 确定疲劳提示
    if TOTAL >= 50 or mTOTAL>=15:
        cv2.putText(frame, "SLEEP!!!", (100, 200),cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 3)
        
    # 按q退出
    cv2.putText(frame, "Press 'q': Quit", (20, 500),cv2.FONT_HERSHEY_SIMPLEX, 0.7, (84, 255, 159), 2)
    # 窗口显示 show with opencv
    cv2.imshow("Frame", frame)
    
    # if the `q` key was pressed, break from the loop
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
        
# 释放摄像头 release camera
cap.release()
# do a bit of cleanup
cv2.destroyAllWindows()
# Out:
# [INFO] loading facial landmark predictor...
# D:\mydownload\Anaconda3\lib\site-packages\ipykernel_launcher.py:152: DeprecationWarning: In future, it will be an error for 'np.bool_' scalars to be interpreted as an index
# 嘴巴实时长宽比:0.48 	是否张嘴：False
# 眼睛实时长宽比:0.31 	是否眨眼：False
# 嘴巴实时长宽比:0.47 	是否张嘴：False
# 眼睛实时长宽比:0.33 	是否眨眼：False
# 嘴巴实时长宽比:0.48 	是否张嘴：False
# 眼睛实时长宽比:0.33 	是否眨眼：False
# 嘴巴实时长宽比:0.47 	是否张嘴：False
# 眼睛实时长宽比:0.33 	是否眨眼：False
# 嘴巴实时长宽比:0.48 	是否张嘴：False
# 眼睛实时长宽比:0.33 	是否眨眼：False
# 嘴巴实时长宽比:0.47 	是否张嘴：False
# 眼睛实时长宽比:0.33 	是否眨眼：False
# 嘴巴实时长宽比:0.47 	是否张嘴：False
# 眼睛实时长宽比:0.35 	是否眨眼：False
# 嘴巴实时长宽比:0.49 	是否张嘴：False
# 眼睛实时长宽比:0.34 	是否眨眼：False
# 嘴巴实时长宽比:0.48 	是否张嘴：False
# 眼睛实时长宽比:0.33 	是否眨眼：False
# 嘴巴实时长宽比:0.46 	是否张嘴：False
# 眼睛实时长宽比:0.32 	是否眨眼：False
# 嘴巴实时长宽比:0.48 	是否张嘴：False
# 眼睛实时长宽比:0.35 	是否眨眼：False
# 嘴巴实时长宽比:0.48 	是否张嘴：False
# 眼睛实时长宽比:0.34 	是否眨眼：False
# 嘴巴实时长宽比:0.46 	是否张嘴：False
# 眼睛实时长宽比:0.36 	是否眨眼：False
# 嘴巴实时长宽比:0.45 	是否张嘴：False
# 眼睛实时长宽比:0.35 	是否眨眼：False
# 嘴巴实时长宽比:0.48 	是否张嘴：False
# 眼睛实时长宽比:0.35 	是否眨眼：False
# 嘴巴实时长宽比:0.48 	是否张嘴：False
# 眼睛实时长宽比:0.34 	是否眨眼：False
# 嘴巴实时长宽比:0.50 	是否张嘴：False
# 眼睛实时长宽比:0.28 	是否眨眼：False
# 嘴巴实时长宽比:0.48 	是否张嘴：False
# 眼睛实时长宽比:0.27 	是否眨眼：False
# 嘴巴实时长宽比:0.47 	是否张嘴：False
# 眼睛实时长宽比:0.25 	是否眨眼：False
# 嘴巴实时长宽比:0.46 	是否张嘴：False
# 眼睛实时长宽比:0.26 	是否眨眼：False
# 嘴巴实时长宽比:0.46 	是否张嘴：False
# 眼睛实时长宽比:0.25 	是否眨眼：False
# 嘴巴实时长宽比:0.48 	是否张嘴：False
# 眼睛实时长宽比:0.24 	是否眨眼：False
# 嘴巴实时长宽比:0.48 	是否张嘴：False
# 眼睛实时长宽比:0.24 	是否眨眼：False
# 嘴巴实时长宽比:0.48 	是否张嘴：False
# 眼睛实时长宽比:0.27 	是否眨眼：False
# 嘴巴实时长宽比:0.48 	是否张嘴：False
# 眼睛实时长宽比:0.27 	是否眨眼：False
# 嘴巴实时长宽比:0.48 	是否张嘴：False
# 眼睛实时长宽比:0.28 	是否眨眼：False
# 嘴巴实时长宽比:0.48 	是否张嘴：False
# 眼睛实时长宽比:0.27 	是否眨眼：False
# 嘴巴实时长宽比:0.48 	是否张嘴：False
# 眼睛实时长宽比:0.26 	是否眨眼：False
# 嘴巴实时长宽比:0.50 	是否张嘴：False
# 眼睛实时长宽比:0.28 	是否眨眼：False
# 嘴巴实时长宽比:0.50 	是否张嘴：False
# 眼睛实时长宽比:0.27 	是否眨眼：False
# 嘴巴实时长宽比:0.47 	是否张嘴：False
# 眼睛实时长宽比:0.21 	是否眨眼：False
# 嘴巴实时长宽比:0.48 	是否张嘴：False
# 眼睛实时长宽比:0.21 	是否眨眼：False
# 嘴巴实时长宽比:0.48 	是否张嘴：False
# 眼睛实时长宽比:0.28 	是否眨眼：False
# 嘴巴实时长宽比:0.49 	是否张嘴：False
# 眼睛实时长宽比:0.34 	是否眨眼：False
# 嘴巴实时长宽比:0.49 	是否张嘴：False
# 眼睛实时长宽比:0.35 	是否眨眼：False
# 嘴巴实时长宽比:0.48 	是否张嘴：False
# 眼睛实时长宽比:0.35 	是否眨眼：False
# 嘴巴实时长宽比:0.49 	是否张嘴：False
# 眼睛实时长宽比:0.34 	是否眨眼：False
# 嘴巴实时长宽比:0.48 	是否张嘴：False
# 眼睛实时长宽比:0.32 	是否眨眼：False
# 嘴巴实时长宽比:0.48 	是否张嘴：False
# 眼睛实时长宽比:0.31 	是否眨眼：False
# 嘴巴实时长宽比:0.48 	是否张嘴：False
# 眼睛实时长宽比:0.32 	是否眨眼：False
# 嘴巴实时长宽比:0.48 	是否张嘴：False
# 眼睛实时长宽比:0.33 	是否眨眼：False
# 嘴巴实时长宽比:0.48 	是否张嘴：False
# 眼睛实时长宽比:0.33 	是否眨眼：False
# 嘴巴实时长宽比:0.48 	是否张嘴：False
# 眼睛实时长宽比:0.34 	是否眨眼：False
# 嘴巴实时长宽比:0.48 	是否张嘴：False
# 眼睛实时长宽比:0.32 	是否眨眼：False
# 嘴巴实时长宽比:0.48 	是否张嘴：False
# 眼睛实时长宽比:0.33 	是否眨眼：False
# 嘴巴实时长宽比:0.48 	是否张嘴：False
# 眼睛实时长宽比:0.33 	是否眨眼：False
# 嘴巴实时长宽比:0.47 	是否张嘴：False
# 眼睛实时长宽比:0.35 	是否眨眼：False
# 嘴巴实时长宽比:0.46 	是否张嘴：False
# 眼睛实时长宽比:0.35 	是否眨眼：False
# 嘴巴实时长宽比:0.48 	是否张嘴：False
# 眼睛实时长宽比:0.32 	是否眨眼：False
# 嘴巴实时长宽比:0.47 	是否张嘴：False
# 眼睛实时长宽比:0.35 	是否眨眼：False
# 嘴巴实时长宽比:0.48 	是否张嘴：False
# 眼睛实时长宽比:0.35 	是否眨眼：False
# 嘴巴实时长宽比:0.48 	是否张嘴：False
# 眼睛实时长宽比:0.34 	是否眨眼：False
# 嘴巴实时长宽比:0.49 	是否张嘴：False
# 眼睛实时长宽比:0.35 	是否眨眼：False
# 嘴巴实时长宽比:0.47 	是否张嘴：False
# 眼睛实时长宽比:0.34 	是否眨眼：False
# 嘴巴实时长宽比:0.49 	是否张嘴：False
# 眼睛实时长宽比:0.34 	是否眨眼：False
# 嘴巴实时长宽比:0.49 	是否张嘴：False
# 眼睛实时长宽比:0.34 	是否眨眼：False
# 嘴巴实时长宽比:0.48 	是否张嘴：False
# 眼睛实时长宽比:0.34 	是否眨眼：False
# 嘴巴实时长宽比:0.50 	是否张嘴：True
# 眼睛实时长宽比:0.33 	是否眨眼：False
# 嘴巴实时长宽比:0.49 	是否张嘴：False
# 眼睛实时长宽比:0.31 	是否眨眼：False
# 嘴巴实时长宽比:0.50 	是否张嘴：False
# 眼睛实时长宽比:0.33 	是否眨眼：False
# 嘴巴实时长宽比:0.48 	是否张嘴：False
# 眼睛实时长宽比:0.32 	是否眨眼：False
# 嘴巴实时长宽比:0.64 	是否张嘴：True
# 眼睛实时长宽比:0.34 	是否眨眼：False
# 嘴巴实时长宽比:0.70 	是否张嘴：True
# 眼睛实时长宽比:0.35 	是否眨眼：False
# 嘴巴实时长宽比:0.70 	是否张嘴：True
# 眼睛实时长宽比:0.35 	是否眨眼：False
# 嘴巴实时长宽比:0.72 	是否张嘴：True
# 眼睛实时长宽比:0.34 	是否眨眼：False
# 嘴巴实时长宽比:0.74 	是否张嘴：True
# 眼睛实时长宽比:0.35 	是否眨眼：False
# 嘴巴实时长宽比:0.71 	是否张嘴：True
# 眼睛实时长宽比:0.35 	是否眨眼：False
# 嘴巴实时长宽比:0.71 	是否张嘴：True
# 眼睛实时长宽比:0.35 	是否眨眼：False
# 嘴巴实时长宽比:0.70 	是否张嘴：True
# 眼睛实时长宽比:0.34 	是否眨眼：False
# 嘴巴实时长宽比:0.70 	是否张嘴：True
# 眼睛实时长宽比:0.37 	是否眨眼：False
# 嘴巴实时长宽比:0.71 	是否张嘴：True
# 眼睛实时长宽比:0.34 	是否眨眼：False
# 嘴巴实时长宽比:0.68 	是否张嘴：True
# 眼睛实时长宽比:0.33 	是否眨眼：False
# 嘴巴实时长宽比:0.69 	是否张嘴：True
# 眼睛实时长宽比:0.34 	是否眨眼：False
# 嘴巴实时长宽比:0.67 	是否张嘴：True
# 眼睛实时长宽比:0.35 	是否眨眼：False
# 嘴巴实时长宽比:0.67 	是否张嘴：True
# 眼睛实时长宽比:0.34 	是否眨眼：False
# 嘴巴实时长宽比:0.65 	是否张嘴：True
# 眼睛实时长宽比:0.34 	是否眨眼：False
# 嘴巴实时长宽比:0.66 	是否张嘴：True
# 眼睛实时长宽比:0.36 	是否眨眼：False
# 嘴巴实时长宽比:0.66 	是否张嘴：True
# 眼睛实时长宽比:0.36 	是否眨眼：False
# 嘴巴实时长宽比:0.64 	是否张嘴：True
# 眼睛实时长宽比:0.35 	是否眨眼：False
# 嘴巴实时长宽比:0.67 	是否张嘴：True
# 眼睛实时长宽比:0.35 	是否眨眼：False
# 嘴巴实时长宽比:0.66 	是否张嘴：True
# 眼睛实时长宽比:0.35 	是否眨眼：False
# 嘴巴实时长宽比:0.65 	是否张嘴：True
# 眼睛实时长宽比:0.35 	是否眨眼：False
# 嘴巴实时长宽比:0.60 	是否张嘴：True
# 眼睛实时长宽比:0.35 	是否眨眼：False
# 嘴巴实时长宽比:0.54 	是否张嘴：True
# 眼睛实时长宽比:0.33 	是否眨眼：False
# 嘴巴实时长宽比:0.54 	是否张嘴：True
# 眼睛实时长宽比:0.33 	是否眨眼：False
# 嘴巴实时长宽比:0.53 	是否张嘴：True
# 眼睛实时长宽比:0.33 	是否眨眼：False
# 嘴巴实时长宽比:0.51 	是否张嘴：True
# 眼睛实时长宽比:0.32 	是否眨眼：False
# 嘴巴实时长宽比:0.47 	是否张嘴：False
# 眼睛实时长宽比:0.33 	是否眨眼：False
# 嘴巴实时长宽比:0.46 	是否张嘴：False
# 眼睛实时长宽比:0.35 	是否眨眼：False
# 嘴巴实时长宽比:0.48 	是否张嘴：False
# 眼睛实时长宽比:0.32 	是否眨眼：False
# 嘴巴实时长宽比:0.49 	是否张嘴：False
# 眼睛实时长宽比:0.33 	是否眨眼：False
# 嘴巴实时长宽比:0.54 	是否张嘴：True
# 眼睛实时长宽比:0.34 	是否眨眼：False
# 嘴巴实时长宽比:0.56 	是否张嘴：True
# 眼睛实时长宽比:0.32 	是否眨眼：False
# 嘴巴实时长宽比:0.56 	是否张嘴：True
# 眼睛实时长宽比:0.35 	是否眨眼：False
# 嘴巴实时长宽比:0.56 	是否张嘴：True
# 眼睛实时长宽比:0.33 	是否眨眼：False
# 嘴巴实时长宽比:0.56 	是否张嘴：True
# 眼睛实时长宽比:0.34 	是否眨眼：False
# 嘴巴实时长宽比:0.55 	是否张嘴：True
# 眼睛实时长宽比:0.34 	是否眨眼：False
# 嘴巴实时长宽比:0.60 	是否张嘴：True
# 眼睛实时长宽比:0.30 	是否眨眼：False
# 嘴巴实时长宽比:0.56 	是否张嘴：True
# 眼睛实时长宽比:0.17 	是否眨眼：True
# 嘴巴实时长宽比:0.55 	是否张嘴：True
# 眼睛实时长宽比:0.27 	是否眨眼：False
# 嘴巴实时长宽比:0.56 	是否张嘴：True
# 眼睛实时长宽比:0.31 	是否眨眼：False
# 嘴巴实时长宽比:0.56 	是否张嘴：True
# 眼睛实时长宽比:0.34 	是否眨眼：False
# 嘴巴实时长宽比:0.54 	是否张嘴：True
# 眼睛实时长宽比:0.34 	是否眨眼：False
# 嘴巴实时长宽比:0.55 	是否张嘴：True
# 眼睛实时长宽比:0.35 	是否眨眼：False
# 嘴巴实时长宽比:0.56 	是否张嘴：True
# 眼睛实时长宽比:0.35 	是否眨眼：False
# 嘴巴实时长宽比:0.51 	是否张嘴：True
# 眼睛实时长宽比:0.34 	是否眨眼：False
# 嘴巴实时长宽比:0.54 	是否张嘴：True
# 眼睛实时长宽比:0.35 	是否眨眼：False
# 嘴巴实时长宽比:0.56 	是否张嘴：True
# 眼睛实时长宽比:0.34 	是否眨眼：False
# 嘴巴实时长宽比:0.54 	是否张嘴：True
# 眼睛实时长宽比:0.34 	是否眨眼：False
# 嘴巴实时长宽比:0.56 	是否张嘴：True
# 眼睛实时长宽比:0.34 	是否眨眼：False
# 嘴巴实时长宽比:0.56 	是否张嘴：True
# 眼睛实时长宽比:0.36 	是否眨眼：False
# 嘴巴实时长宽比:0.58 	是否张嘴：True
# 眼睛实时长宽比:0.35 	是否眨眼：False
# 嘴巴实时长宽比:0.55 	是否张嘴：True
# 眼睛实时长宽比:0.35 	是否眨眼：False
# 嘴巴实时长宽比:0.55 	是否张嘴：True
# 眼睛实时长宽比:0.33 	是否眨眼：False
# 嘴巴实时长宽比:0.68 	是否张嘴：True
# 眼睛实时长宽比:0.35 	是否眨眼：False
# 嘴巴实时长宽比:0.73 	是否张嘴：True
# 眼睛实时长宽比:0.34 	是否眨眼：False
# 嘴巴实时长宽比:0.74 	是否张嘴：True
# 眼睛实时长宽比:0.34 	是否眨眼：False
# 嘴巴实时长宽比:0.73 	是否张嘴：True
# 眼睛实时长宽比:0.35 	是否眨眼：False
# 嘴巴实时长宽比:0.72 	是否张嘴：True
# 眼睛实时长宽比:0.37 	是否眨眼：False
# 嘴巴实时长宽比:0.71 	是否张嘴：True
# 眼睛实时长宽比:0.36 	是否眨眼：False
# 嘴巴实时长宽比:0.71 	是否张嘴：True
# 眼睛实时长宽比:0.35 	是否眨眼：False
# 嘴巴实时长宽比:0.69 	是否张嘴：True
# 眼睛实时长宽比:0.34 	是否眨眼：False
# 嘴巴实时长宽比:0.68 	是否张嘴：True
# 眼睛实时长宽比:0.35 	是否眨眼：False
# 嘴巴实时长宽比:0.68 	是否张嘴：True
# 眼睛实时长宽比:0.37 	是否眨眼：False
# 嘴巴实时长宽比:0.67 	是否张嘴：True
# 眼睛实时长宽比:0.33 	是否眨眼：False
# 嘴巴实时长宽比:0.66 	是否张嘴：True
# 眼睛实时长宽比:0.33 	是否眨眼：False
# 嘴巴实时长宽比:0.67 	是否张嘴：True
# 眼睛实时长宽比:0.33 	是否眨眼：False
# 嘴巴实时长宽比:0.68 	是否张嘴：True
# 眼睛实时长宽比:0.34 	是否眨眼：False
# 嘴巴实时长宽比:0.68 	是否张嘴：True
# 眼睛实时长宽比:0.34 	是否眨眼：False
# 嘴巴实时长宽比:0.66 	是否张嘴：True
# 眼睛实时长宽比:0.34 	是否眨眼：False
# 嘴巴实时长宽比:0.63 	是否张嘴：True
# 眼睛实时长宽比:0.34 	是否眨眼：False
# 嘴巴实时长宽比:0.67 	是否张嘴：True
# 眼睛实时长宽比:0.34 	是否眨眼：False
# 嘴巴实时长宽比:0.56 	是否张嘴：True
# 眼睛实时长宽比:0.36 	是否眨眼：False
# 嘴巴实时长宽比:0.56 	是否张嘴：True
# 眼睛实时长宽比:0.36 	是否眨眼：False
# 嘴巴实时长宽比:0.58 	是否张嘴：True
# 眼睛实时长宽比:0.36 	是否眨眼：False
# 嘴巴实时长宽比:0.59 	是否张嘴：True
# 眼睛实时长宽比:0.36 	是否眨眼：False
# 嘴巴实时长宽比:0.61 	是否张嘴：True
# 眼睛实时长宽比:0.36 	是否眨眼：False
# 嘴巴实时长宽比:0.64 	是否张嘴：True
# 眼睛实时长宽比:0.37 	是否眨眼：False
# 嘴巴实时长宽比:0.66 	是否张嘴：True
# 眼睛实时长宽比:0.35 	是否眨眼：False
# 嘴巴实时长宽比:0.63 	是否张嘴：True
# 眼睛实时长宽比:0.36 	是否眨眼：False
# 嘴巴实时长宽比:0.64 	是否张嘴：True
# 眼睛实时长宽比:0.36 	是否眨眼：False
# 嘴巴实时长宽比:0.64 	是否张嘴：True
# 眼睛实时长宽比:0.36 	是否眨眼：False
# 嘴巴实时长宽比:0.61 	是否张嘴：True
# 眼睛实时长宽比:0.35 	是否眨眼：False
# 嘴巴实时长宽比:0.64 	是否张嘴：True
# 眼睛实时长宽比:0.33 	是否眨眼：False
# 嘴巴实时长宽比:0.58 	是否张嘴：True
# 眼睛实时长宽比:0.36 	是否眨眼：False
# 嘴巴实时长宽比:0.63 	是否张嘴：True
# 眼睛实时长宽比:0.33 	是否眨眼：False
# 嘴巴实时长宽比:0.60 	是否张嘴：True
# 眼睛实时长宽比:0.35 	是否眨眼：False
# 嘴巴实时长宽比:0.62 	是否张嘴：True
# 眼睛实时长宽比:0.35 	是否眨眼：False
# 嘴巴实时长宽比:0.59 	是否张嘴：True
# 眼睛实时长宽比:0.33 	是否眨眼：False
# 嘴巴实时长宽比:0.59 	是否张嘴：True
# 眼睛实时长宽比:0.34 	是否眨眼：False
# 嘴巴实时长宽比:0.58 	是否张嘴：True
# 眼睛实时长宽比:0.33 	是否眨眼：False
# 嘴巴实时长宽比:0.59 	是否张嘴：True
# 眼睛实时长宽比:0.32 	是否眨眼：False
# 嘴巴实时长宽比:0.59 	是否张嘴：True
# 眼睛实时长宽比:0.36 	是否眨眼：False
# 嘴巴实时长宽比:0.58 	是否张嘴：True
# 眼睛实时长宽比:0.34 	是否眨眼：False
# 嘴巴实时长宽比:0.55 	是否张嘴：True
# 眼睛实时长宽比:0.34 	是否眨眼：False
# 嘴巴实时长宽比:0.60 	是否张嘴：True
# 眼睛实时长宽比:0.35 	是否眨眼：False
# 嘴巴实时长宽比:0.58 	是否张嘴：True
# 眼睛实时长宽比:0.35 	是否眨眼：False
# 嘴巴实时长宽比:0.56 	是否张嘴：True
# 眼睛实时长宽比:0.33 	是否眨眼：False
# 嘴巴实时长宽比:0.58 	是否张嘴：True
# 眼睛实时长宽比:0.35 	是否眨眼：False
# 嘴巴实时长宽比:0.56 	是否张嘴：True
# 眼睛实时长宽比:0.35 	是否眨眼：False
# 嘴巴实时长宽比:0.54 	是否张嘴：True
# 眼睛实时长宽比:0.36 	是否眨眼：False
# 嘴巴实时长宽比:0.56 	是否张嘴：True
# 眼睛实时长宽比:0.35 	是否眨眼：False
# 嘴巴实时长宽比:0.56 	是否张嘴：True
# 眼睛实时长宽比:0.36 	是否眨眼：False
# 嘴巴实时长宽比:0.56 	是否张嘴：True
# 眼睛实时长宽比:0.34 	是否眨眼：False
# 嘴巴实时长宽比:0.55 	是否张嘴：True
# 眼睛实时长宽比:0.34 	是否眨眼：False
# 嘴巴实时长宽比:0.56 	是否张嘴：True
# 眼睛实时长宽比:0.35 	是否眨眼：False
# 嘴巴实时长宽比:0.57 	是否张嘴：True
# 眼睛实时长宽比:0.34 	是否眨眼：False
# 嘴巴实时长宽比:0.57 	是否张嘴：True
# 眼睛实时长宽比:0.34 	是否眨眼：False
# 嘴巴实时长宽比:0.56 	是否张嘴：True
# 眼睛实时长宽比:0.35 	是否眨眼：False
# 嘴巴实时长宽比:0.57 	是否张嘴：True
# 眼睛实时长宽比:0.32 	是否眨眼：False
# 嘴巴实时长宽比:0.56 	是否张嘴：True
# 眼睛实时长宽比:0.35 	是否眨眼：False
# 嘴巴实时长宽比:0.57 	是否张嘴：True
# 眼睛实时长宽比:0.35 	是否眨眼：False
# 嘴巴实时长宽比:0.58 	是否张嘴：True
# 眼睛实时长宽比:0.37 	是否眨眼：False
# 嘴巴实时长宽比:0.56 	是否张嘴：True
# 眼睛实时长宽比:0.33 	是否眨眼：False
# 嘴巴实时长宽比:0.57 	是否张嘴：True
# 眼睛实时长宽比:0.35 	是否眨眼：False
# 嘴巴实时长宽比:0.56 	是否张嘴：True
# 眼睛实时长宽比:0.35 	是否眨眼：False
# 嘴巴实时长宽比:0.55 	是否张嘴：True
# 眼睛实时长宽比:0.35 	是否眨眼：False
# 嘴巴实时长宽比:0.55 	是否张嘴：True
# 眼睛实时长宽比:0.35 	是否眨眼：False
# 嘴巴实时长宽比:0.53 	是否张嘴：True
# 眼睛实时长宽比:0.34 	是否眨眼：False
# 嘴巴实时长宽比:0.55 	是否张嘴：True
# 眼睛实时长宽比:0.34 	是否眨眼：False
# 嘴巴实时长宽比:0.57 	是否张嘴：True
# 眼睛实时长宽比:0.34 	是否眨眼：False
# 嘴巴实时长宽比:0.55 	是否张嘴：True
# 眼睛实时长宽比:0.35 	是否眨眼：False
# 嘴巴实时长宽比:0.55 	是否张嘴：True
# 眼睛实时长宽比:0.35 	是否眨眼：False
# 嘴巴实时长宽比:0.64 	是否张嘴：True
# 眼睛实时长宽比:0.35 	是否眨眼：False
# 嘴巴实时长宽比:0.77 	是否张嘴：True
# 眼睛实时长宽比:0.34 	是否眨眼：False
# 嘴巴实时长宽比:0.84 	是否张嘴：True
# 眼睛实时长宽比:0.35 	是否眨眼：False
# 嘴巴实时长宽比:0.83 	是否张嘴：True
# 眼睛实时长宽比:0.35 	是否眨眼：False
# 嘴巴实时长宽比:0.84 	是否张嘴：True
# 眼睛实时长宽比:0.33 	是否眨眼：False
# 嘴巴实时长宽比:0.82 	是否张嘴：True
# 眼睛实时长宽比:0.32 	是否眨眼：False
# 嘴巴实时长宽比:0.81 	是否张嘴：True
# 眼睛实时长宽比:0.30 	是否眨眼：False
# 嘴巴实时长宽比:0.81 	是否张嘴：True
# 眼睛实时长宽比:0.31 	是否眨眼：False
# 嘴巴实时长宽比:0.77 	是否张嘴：True
# 眼睛实时长宽比:0.32 	是否眨眼：False
# 嘴巴实时长宽比:0.76 	是否张嘴：True
# 眼睛实时长宽比:0.30 	是否眨眼：False
# 嘴巴实时长宽比:0.77 	是否张嘴：True
# 眼睛实时长宽比:0.31 	是否眨眼：False
# 嘴巴实时长宽比:0.74 	是否张嘴：True
# 眼睛实时长宽比:0.31 	是否眨眼：False
# 嘴巴实时长宽比:0.74 	是否张嘴：True
# 眼睛实时长宽比:0.32 	是否眨眼：False
# 嘴巴实时长宽比:0.76 	是否张嘴：True
# 眼睛实时长宽比:0.30 	是否眨眼：False
# 嘴巴实时长宽比:0.72 	是否张嘴：True
# 眼睛实时长宽比:0.33 	是否眨眼：False
# 嘴巴实时长宽比:0.76 	是否张嘴：True
# 眼睛实时长宽比:0.32 	是否眨眼：False
# 嘴巴实时长宽比:0.74 	是否张嘴：True
# 眼睛实时长宽比:0.33 	是否眨眼：False
# 嘴巴实时长宽比:0.70 	是否张嘴：True
# 眼睛实时长宽比:0.32 	是否眨眼：False
# 嘴巴实时长宽比:0.70 	是否张嘴：True
# 眼睛实时长宽比:0.32 	是否眨眼：False
# 嘴巴实时长宽比:0.68 	是否张嘴：True
# 眼睛实时长宽比:0.31 	是否眨眼：False
# 嘴巴实时长宽比:0.71 	是否张嘴：True
# 眼睛实时长宽比:0.32 	是否眨眼：False
# 嘴巴实时长宽比:0.70 	是否张嘴：True
# 眼睛实时长宽比:0.32 	是否眨眼：False
# 嘴巴实时长宽比:0.69 	是否张嘴：True
# 眼睛实时长宽比:0.32 	是否眨眼：False
# 嘴巴实时长宽比:0.72 	是否张嘴：True
# 眼睛实时长宽比:0.32 	是否眨眼：False
# 嘴巴实时长宽比:0.74 	是否张嘴：True
# 眼睛实时长宽比:0.33 	是否眨眼：False
# 嘴巴实时长宽比:0.73 	是否张嘴：True
# 眼睛实时长宽比:0.33 	是否眨眼：False
# 嘴巴实时长宽比:0.62 	是否张嘴：True
# 眼睛实时长宽比:0.33 	是否眨眼：False
# 嘴巴实时长宽比:0.55 	是否张嘴：True
# 眼睛实时长宽比:0.33 	是否眨眼：False
# 嘴巴实时长宽比:0.52 	是否张嘴：True
# 眼睛实时长宽比:0.34 	是否眨眼：False
# 嘴巴实时长宽比:0.51 	是否张嘴：True
# 眼睛实时长宽比:0.33 	是否眨眼：False
# 嘴巴实时长宽比:0.48 	是否张嘴：False
# 眼睛实时长宽比:0.33 	是否眨眼：False
# 嘴巴实时长宽比:0.46 	是否张嘴：False
# 眼睛实时长宽比:0.32 	是否眨眼：False
# 嘴巴实时长宽比:0.46 	是否张嘴：False
# 眼睛实时长宽比:0.33 	是否眨眼：False
# 嘴巴实时长宽比:0.47 	是否张嘴：False
# 眼睛实时长宽比:0.32 	是否眨眼：False
# 嘴巴实时长宽比:0.47 	是否张嘴：False
# 眼睛实时长宽比:0.31 	是否眨眼：False
# 嘴巴实时长宽比:0.45 	是否张嘴：False
# 眼睛实时长宽比:0.33 	是否眨眼：False
# 嘴巴实时长宽比:0.46 	是否张嘴：False
# 眼睛实时长宽比:0.33 	是否眨眼：False
# 嘴巴实时长宽比:0.45 	是否张嘴：False
# 眼睛实时长宽比:0.33 	是否眨眼：False
# 嘴巴实时长宽比:0.46 	是否张嘴：False
# 眼睛实时长宽比:0.32 	是否眨眼：False
# 嘴巴实时长宽比:0.46 	是否张嘴：False
# 眼睛实时长宽比:0.33 	是否眨眼：False
# 嘴巴实时长宽比:0.47 	是否张嘴：False
# 眼睛实时长宽比:0.34 	是否眨眼：False
# 嘴巴实时长宽比:0.45 	是否张嘴：False
# 眼睛实时长宽比:0.33 	是否眨眼：False
# 嘴巴实时长宽比:0.44 	是否张嘴：False
# 眼睛实时长宽比:0.34 	是否眨眼：False
# 嘴巴实时长宽比:0.47 	是否张嘴：False
# 眼睛实时长宽比:0.32 	是否眨眼：False
# 嘴巴实时长宽比:0.46 	是否张嘴：False
# 眼睛实时长宽比:0.34 	是否眨眼：False
# 嘴巴实时长宽比:0.45 	是否张嘴：False
# 眼睛实时长宽比:0.32 	是否眨眼：False
# 嘴巴实时长宽比:0.45 	是否张嘴：False
# 眼睛实时长宽比:0.32 	是否眨眼：False
# 嘴巴实时长宽比:0.43 	是否张嘴：False
# 眼睛实时长宽比:0.32 	是否眨眼：False
# 嘴巴实时长宽比:0.45 	是否张嘴：False
# 眼睛实时长宽比:0.32 	是否眨眼：False
# 嘴巴实时长宽比:0.45 	是否张嘴：False
# 眼睛实时长宽比:0.33 	是否眨眼：False
# 嘴巴实时长宽比:0.44 	是否张嘴：False
# 眼睛实时长宽比:0.33 	是否眨眼：False
# 嘴巴实时长宽比:0.44 	是否张嘴：False
# 眼睛实时长宽比:0.34 	是否眨眼：False
# 嘴巴实时长宽比:0.44 	是否张嘴：False
# 眼睛实时长宽比:0.32 	是否眨眼：False
# 嘴巴实时长宽比:0.44 	是否张嘴：False
# 眼睛实时长宽比:0.32 	是否眨眼：False
# 嘴巴实时长宽比:0.46 	是否张嘴：False
# 眼睛实时长宽比:0.32 	是否眨眼：False
# 嘴巴实时长宽比:0.45 	是否张嘴：False
# 眼睛实时长宽比:0.32 	是否眨眼：False
# 嘴巴实时长宽比:0.50 	是否张嘴：False
# 眼睛实时长宽比:0.34 	是否眨眼：False
# 嘴巴实时长宽比:0.60 	是否张嘴：True
# 眼睛实时长宽比:0.33 	是否眨眼：False
# 嘴巴实时长宽比:0.79 	是否张嘴：True
# 眼睛实时长宽比:0.33 	是否眨眼：False
# 嘴巴实时长宽比:0.95 	是否张嘴：True
# 眼睛实时长宽比:0.35 	是否眨眼：False
# 嘴巴实时长宽比:0.96 	是否张嘴：True
# 眼睛实时长宽比:0.35 	是否眨眼：False
# 嘴巴实时长宽比:0.86 	是否张嘴：True
# 眼睛实时长宽比:0.34 	是否眨眼：False
# 嘴巴实时长宽比:0.86 	是否张嘴：True
# 眼睛实时长宽比:0.34 	是否眨眼：False
# 嘴巴实时长宽比:0.80 	是否张嘴：True
# 眼睛实时长宽比:0.34 	是否眨眼：False
# 嘴巴实时长宽比:0.80 	是否张嘴：True
# 眼睛实时长宽比:0.34 	是否眨眼：False
# 嘴巴实时长宽比:0.75 	是否张嘴：True
# 眼睛实时长宽比:0.32 	是否眨眼：False
# 嘴巴实时长宽比:0.78 	是否张嘴：True
# 眼睛实时长宽比:0.34 	是否眨眼：False
# 嘴巴实时长宽比:0.78 	是否张嘴：True
# 眼睛实时长宽比:0.33 	是否眨眼：False
# 嘴巴实时长宽比:0.77 	是否张嘴：True
# 眼睛实时长宽比:0.33 	是否眨眼：False
# 嘴巴实时长宽比:0.79 	是否张嘴：True
# 眼睛实时长宽比:0.33 	是否眨眼：False
# 嘴巴实时长宽比:0.79 	是否张嘴：True
# 眼睛实时长宽比:0.33 	是否眨眼：False
# 嘴巴实时长宽比:0.78 	是否张嘴：True
# 眼睛实时长宽比:0.35 	是否眨眼：False
# 嘴巴实时长宽比:0.76 	是否张嘴：True
# 眼睛实时长宽比:0.33 	是否眨眼：False
# 嘴巴实时长宽比:0.74 	是否张嘴：True
# 眼睛实时长宽比:0.34 	是否眨眼：False
# 嘴巴实时长宽比:0.76 	是否张嘴：True
# 眼睛实时长宽比:0.33 	是否眨眼：False
# 嘴巴实时长宽比:0.76 	是否张嘴：True
# 眼睛实时长宽比:0.33 	是否眨眼：False
# 嘴巴实时长宽比:0.75 	是否张嘴：True
# 眼睛实时长宽比:0.33 	是否眨眼：False
# 嘴巴实时长宽比:0.76 	是否张嘴：True
# 眼睛实时长宽比:0.33 	是否眨眼：False
# 嘴巴实时长宽比:0.76 	是否张嘴：True
# 眼睛实时长宽比:0.33 	是否眨眼：False
# 嘴巴实时长宽比:0.76 	是否张嘴：True
# 眼睛实时长宽比:0.33 	是否眨眼：False
# 嘴巴实时长宽比:0.78 	是否张嘴：True
# 眼睛实时长宽比:0.34 	是否眨眼：False
# 嘴巴实时长宽比:0.80 	是否张嘴：True
# 眼睛实时长宽比:0.30 	是否眨眼：False
# 嘴巴实时长宽比:0.76 	是否张嘴：True
# 眼睛实时长宽比:0.33 	是否眨眼：False
# 嘴巴实时长宽比:0.76 	是否张嘴：True
# 眼睛实时长宽比:0.31 	是否眨眼：False
# 嘴巴实时长宽比:0.76 	是否张嘴：True
# 眼睛实时长宽比:0.32 	是否眨眼：False
# 嘴巴实时长宽比:0.78 	是否张嘴：True
# 眼睛实时长宽比:0.32 	是否眨眼：False
# 嘴巴实时长宽比:0.76 	是否张嘴：True
# 眼睛实时长宽比:0.33 	是否眨眼：False
# 嘴巴实时长宽比:0.79 	是否张嘴：True
# 眼睛实时长宽比:0.32 	是否眨眼：False
# 嘴巴实时长宽比:0.76 	是否张嘴：True
# 眼睛实时长宽比:0.34 	是否眨眼：False
# 嘴巴实时长宽比:0.76 	是否张嘴：True
# 眼睛实时长宽比:0.33 	是否眨眼：False
# 嘴巴实时长宽比:0.76 	是否张嘴：True
# 眼睛实时长宽比:0.33 	是否眨眼：False
# 嘴巴实时长宽比:0.75 	是否张嘴：True
# 眼睛实时长宽比:0.34 	是否眨眼：False
# 嘴巴实时长宽比:0.75 	是否张嘴：True
# 眼睛实时长宽比:0.35 	是否眨眼：False
# 嘴巴实时长宽比:0.77 	是否张嘴：True
# 眼睛实时长宽比:0.33 	是否眨眼：False
# 嘴巴实时长宽比:0.71 	是否张嘴：True
# 眼睛实时长宽比:0.34 	是否眨眼：False
# 嘴巴实时长宽比:0.67 	是否张嘴：True
# 眼睛实时长宽比:0.33 	是否眨眼：False
# 嘴巴实时长宽比:0.61 	是否张嘴：True
# 眼睛实时长宽比:0.33 	是否眨眼：False
# 嘴巴实时长宽比:0.60 	是否张嘴：True
# 眼睛实时长宽比:0.35 	是否眨眼：False
# 嘴巴实时长宽比:0.55 	是否张嘴：True
# 眼睛实时长宽比:0.34 	是否眨眼：False
# 嘴巴实时长宽比:0.50 	是否张嘴：True
# 眼睛实时长宽比:0.34 	是否眨眼：False
# 嘴巴实时长宽比:0.47 	是否张嘴：False
# 眼睛实时长宽比:0.34 	是否眨眼：False
# 嘴巴实时长宽比:0.49 	是否张嘴：False
# 眼睛实时长宽比:0.34 	是否眨眼：False
# 嘴巴实时长宽比:0.48 	是否张嘴：False
# 眼睛实时长宽比:0.32 	是否眨眼：False
# 嘴巴实时长宽比:0.49 	是否张嘴：False
# 眼睛实时长宽比:0.32 	是否眨眼：False
# 嘴巴实时长宽比:0.49 	是否张嘴：False
# 眼睛实时长宽比:0.32 	是否眨眼：False
# 嘴巴实时长宽比:0.51 	是否张嘴：True
# 眼睛实时长宽比:0.33 	是否眨眼：False
# 嘴巴实时长宽比:0.48 	是否张嘴：False
# 眼睛实时长宽比:0.32 	是否眨眼：False
# 嘴巴实时长宽比:0.49 	是否张嘴：False
# 眼睛实时长宽比:0.34 	是否眨眼：False
# 嘴巴实时长宽比:0.48 	是否张嘴：False
# 眼睛实时长宽比:0.34 	是否眨眼：False
# 嘴巴实时长宽比:0.49 	是否张嘴：False
# 眼睛实时长宽比:0.35 	是否眨眼：False
# 嘴巴实时长宽比:0.48 	是否张嘴：False
# 眼睛实时长宽比:0.34 	是否眨眼：False
# 嘴巴实时长宽比:0.48 	是否张嘴：False
# 眼睛实时长宽比:0.33 	是否眨眼：False
# 嘴巴实时长宽比:0.49 	是否张嘴：False
# 眼睛实时长宽比:0.33 	是否眨眼：False
# 嘴巴实时长宽比:0.47 	是否张嘴：False
# 眼睛实时长宽比:0.33 	是否眨眼：False
# 嘴巴实时长宽比:0.48 	是否张嘴：False
# 眼睛实时长宽比:0.33 	是否眨眼：False
# 嘴巴实时长宽比:0.48 	是否张嘴：False
# 眼睛实时长宽比:0.33 	是否眨眼：False
# 嘴巴实时长宽比:0.48 	是否张嘴：False
# 眼睛实时长宽比:0.32 	是否眨眼：False
# 嘴巴实时长宽比:0.48 	是否张嘴：False
# 眼睛实时长宽比:0.34 	是否眨眼：False
# 嘴巴实时长宽比:0.49 	是否张嘴：False
# 眼睛实时长宽比:0.33 	是否眨眼：False
# 嘴巴实时长宽比:0.49 	是否张嘴：False
# 眼睛实时长宽比:0.33 	是否眨眼：False
# 嘴巴实时长宽比:0.53 	是否张嘴：True
# 眼睛实时长宽比:0.33 	是否眨眼：False
# 嘴巴实时长宽比:0.64 	是否张嘴：True
# 眼睛实时长宽比:0.35 	是否眨眼：False
# 嘴巴实时长宽比:0.79 	是否张嘴：True
# 眼睛实时长宽比:0.35 	是否眨眼：False
# 嘴巴实时长宽比:0.84 	是否张嘴：True
# 眼睛实时长宽比:0.33 	是否眨眼：False
# 嘴巴实时长宽比:0.85 	是否张嘴：True
# 眼睛实时长宽比:0.35 	是否眨眼：False
# 嘴巴实时长宽比:0.83 	是否张嘴：True
# 眼睛实时长宽比:0.34 	是否眨眼：False
# 嘴巴实时长宽比:0.83 	是否张嘴：True
# 眼睛实时长宽比:0.34 	是否眨眼：False
# 嘴巴实时长宽比:0.84 	是否张嘴：True
# 眼睛实时长宽比:0.34 	是否眨眼：False
# 嘴巴实时长宽比:0.86 	是否张嘴：True
# 眼睛实时长宽比:0.34 	是否眨眼：False
# 嘴巴实时长宽比:0.82 	是否张嘴：True
# 眼睛实时长宽比:0.33 	是否眨眼：False
# 嘴巴实时长宽比:0.84 	是否张嘴：True
# 眼睛实时长宽比:0.35 	是否眨眼：False
# 嘴巴实时长宽比:0.82 	是否张嘴：True
# 眼睛实时长宽比:0.34 	是否眨眼：False
# 嘴巴实时长宽比:0.81 	是否张嘴：True
# 眼睛实时长宽比:0.31 	是否眨眼：False
# 嘴巴实时长宽比:0.82 	是否张嘴：True
# 眼睛实时长宽比:0.35 	是否眨眼：False
# 嘴巴实时长宽比:0.79 	是否张嘴：True
# 眼睛实时长宽比:0.33 	是否眨眼：False
# 嘴巴实时长宽比:0.79 	是否张嘴：True
# 眼睛实时长宽比:0.35 	是否眨眼：False
# 嘴巴实时长宽比:0.81 	是否张嘴：True
# 眼睛实时长宽比:0.29 	是否眨眼：False
# 嘴巴实时长宽比:0.79 	是否张嘴：True
# 眼睛实时长宽比:0.17 	是否眨眼：True
# 嘴巴实时长宽比:0.79 	是否张嘴：True
# 眼睛实时长宽比:0.23 	是否眨眼：False
# 嘴巴实时长宽比:0.79 	是否张嘴：True
# 眼睛实时长宽比:0.29 	是否眨眼：False
# 嘴巴实时长宽比:0.78 	是否张嘴：True
# 眼睛实时长宽比:0.31 	是否眨眼：False
# 嘴巴实时长宽比:0.80 	是否张嘴：True
# 眼睛实时长宽比:0.32 	是否眨眼：False
# 嘴巴实时长宽比:0.78 	是否张嘴：True
# 眼睛实时长宽比:0.32 	是否眨眼：False
# 嘴巴实时长宽比:0.79 	是否张嘴：True
# 眼睛实时长宽比:0.32 	是否眨眼：False
# 嘴巴实时长宽比:0.80 	是否张嘴：True
# 眼睛实时长宽比:0.33 	是否眨眼：False
# 嘴巴实时长宽比:0.78 	是否张嘴：True
# 眼睛实时长宽比:0.31 	是否眨眼：False
# 嘴巴实时长宽比:0.76 	是否张嘴：True
# 眼睛实时长宽比:0.32 	是否眨眼：False
# 嘴巴实时长宽比:0.79 	是否张嘴：True
# 眼睛实时长宽比:0.33 	是否眨眼：False
# 嘴巴实时长宽比:0.77 	是否张嘴：True
# 眼睛实时长宽比:0.32 	是否眨眼：False
# 嘴巴实时长宽比:0.75 	是否张嘴：True
# 眼睛实时长宽比:0.32 	是否眨眼：False
# 嘴巴实时长宽比:0.72 	是否张嘴：True
# 眼睛实时长宽比:0.34 	是否眨眼：False
# 嘴巴实时长宽比:0.69 	是否张嘴：True
# 眼睛实时长宽比:0.32 	是否眨眼：False
# 嘴巴实时长宽比:0.62 	是否张嘴：True
# 眼睛实时长宽比:0.32 	是否眨眼：False
# 嘴巴实时长宽比:0.62 	是否张嘴：True
# 眼睛实时长宽比:0.32 	是否眨眼：False
# 嘴巴实时长宽比:0.59 	是否张嘴：True
# 眼睛实时长宽比:0.32 	是否眨眼：False
# 嘴巴实时长宽比:0.54 	是否张嘴：True
# 眼睛实时长宽比:0.32 	是否眨眼：False
# 嘴巴实时长宽比:0.47 	是否张嘴：False
# 眼睛实时长宽比:0.33 	是否眨眼：False
# 嘴巴实时长宽比:0.43 	是否张嘴：False
# 眼睛实时长宽比:0.33 	是否眨眼：False
# 嘴巴实时长宽比:0.46 	是否张嘴：False
# 眼睛实时长宽比:0.32 	是否眨眼：False
# 嘴巴实时长宽比:0.45 	是否张嘴：False
# 眼睛实时长宽比:0.32 	是否眨眼：False
# 嘴巴实时长宽比:0.45 	是否张嘴：False
# 眼睛实时长宽比:0.33 	是否眨眼：False
# 嘴巴实时长宽比:0.48 	是否张嘴：False
# 眼睛实时长宽比:0.31 	是否眨眼：False
# 嘴巴实时长宽比:0.48 	是否张嘴：False
# 眼睛实时长宽比:0.32 	是否眨眼：False
# 嘴巴实时长宽比:0.46 	是否张嘴：False
# 眼睛实时长宽比:0.32 	是否眨眼：False
# 嘴巴实时长宽比:0.49 	是否张嘴：False
# 眼睛实时长宽比:0.33 	是否眨眼：False
# 嘴巴实时长宽比:0.47 	是否张嘴：False
# 眼睛实时长宽比:0.34 	是否眨眼：False
# 嘴巴实时长宽比:0.47 	是否张嘴：False
# 眼睛实时长宽比:0.33 	是否眨眼：False
# 嘴巴实时长宽比:0.48 	是否张嘴：False
# 眼睛实时长宽比:0.33 	是否眨眼：False
# 嘴巴实时长宽比:0.48 	是否张嘴：False
# 眼睛实时长宽比:0.32 	是否眨眼：False
# 嘴巴实时长宽比:0.48 	是否张嘴：False
# 眼睛实时长宽比:0.33 	是否眨眼：False
# 嘴巴实时长宽比:0.46 	是否张嘴：False
# 眼睛实时长宽比:0.32 	是否眨眼：False
# 嘴巴实时长宽比:0.46 	是否张嘴：False
# 眼睛实时长宽比:0.32 	是否眨眼：False
# 嘴巴实时长宽比:0.48 	是否张嘴：False
# 眼睛实时长宽比:0.33 	是否眨眼：False
# 嘴巴实时长宽比:0.48 	是否张嘴：False
# 眼睛实时长宽比:0.34 	是否眨眼：False
# 嘴巴实时长宽比:0.48 	是否张嘴：False
# 眼睛实时长宽比:0.34 	是否眨眼：False
# 嘴巴实时长宽比:0.49 	是否张嘴：False
# 眼睛实时长宽比:0.33 	是否眨眼：False
# 嘴巴实时长宽比:0.45 	是否张嘴：False
# 眼睛实时长宽比:0.34 	是否眨眼：False
# 嘴巴实时长宽比:0.45 	是否张嘴：False
# 眼睛实时长宽比:0.34 	是否眨眼：False
# 嘴巴实时长宽比:0.50 	是否张嘴：False
# 眼睛实时长宽比:0.33 	是否眨眼：False
# 嘴巴实时长宽比:0.69 	是否张嘴：True
# 眼睛实时长宽比:0.34 	是否眨眼：False
# 嘴巴实时长宽比:0.84 	是否张嘴：True
# 眼睛实时长宽比:0.33 	是否眨眼：False
# 嘴巴实时长宽比:0.86 	是否张嘴：True
# 眼睛实时长宽比:0.33 	是否眨眼：False
# 嘴巴实时长宽比:0.87 	是否张嘴：True
# 眼睛实时长宽比:0.35 	是否眨眼：False
# 嘴巴实时长宽比:0.86 	是否张嘴：True
# 眼睛实时长宽比:0.34 	是否眨眼：False
# 嘴巴实时长宽比:0.84 	是否张嘴：True
# 眼睛实时长宽比:0.34 	是否眨眼：False
# 嘴巴实时长宽比:0.83 	是否张嘴：True
# 眼睛实时长宽比:0.33 	是否眨眼：False
# 嘴巴实时长宽比:0.84 	是否张嘴：True
# 眼睛实时长宽比:0.34 	是否眨眼：False
# 嘴巴实时长宽比:0.87 	是否张嘴：True
# 眼睛实时长宽比:0.33 	是否眨眼：False
# 嘴巴实时长宽比:0.88 	是否张嘴：True
# 眼睛实时长宽比:0.33 	是否眨眼：False
# 嘴巴实时长宽比:0.87 	是否张嘴：True
# 眼睛实时长宽比:0.33 	是否眨眼：False
# 嘴巴实时长宽比:0.85 	是否张嘴：True
# 眼睛实时长宽比:0.34 	是否眨眼：False
# 嘴巴实时长宽比:0.85 	是否张嘴：True
# 眼睛实时长宽比:0.33 	是否眨眼：False
# 嘴巴实时长宽比:0.87 	是否张嘴：True
# 眼睛实时长宽比:0.34 	是否眨眼：False
# 嘴巴实时长宽比:0.87 	是否张嘴：True
# 眼睛实时长宽比:0.34 	是否眨眼：False
# 嘴巴实时长宽比:0.84 	是否张嘴：True
# 眼睛实时长宽比:0.33 	是否眨眼：False
# 嘴巴实时长宽比:0.87 	是否张嘴：True
# 眼睛实时长宽比:0.33 	是否眨眼：False
# 嘴巴实时长宽比:0.87 	是否张嘴：True
# 眼睛实时长宽比:0.33 	是否眨眼：False
# 嘴巴实时长宽比:0.87 	是否张嘴：True
# 眼睛实时长宽比:0.34 	是否眨眼：False
# 嘴巴实时长宽比:0.86 	是否张嘴：True
# 眼睛实时长宽比:0.31 	是否眨眼：False
# 嘴巴实时长宽比:0.86 	是否张嘴：True
# 眼睛实时长宽比:0.34 	是否眨眼：False
# 嘴巴实时长宽比:0.85 	是否张嘴：True
# 眼睛实时长宽比:0.34 	是否眨眼：False
# 嘴巴实时长宽比:0.84 	是否张嘴：True
# 眼睛实时长宽比:0.33 	是否眨眼：False
# 嘴巴实时长宽比:0.87 	是否张嘴：True
# 眼睛实时长宽比:0.33 	是否眨眼：False
# 嘴巴实时长宽比:0.87 	是否张嘴：True
# 眼睛实时长宽比:0.32 	是否眨眼：False
# 嘴巴实时长宽比:0.87 	是否张嘴：True
# 眼睛实时长宽比:0.32 	是否眨眼：False
# 嘴巴实时长宽比:0.85 	是否张嘴：True
# 眼睛实时长宽比:0.34 	是否眨眼：False
# 嘴巴实时长宽比:0.80 	是否张嘴：True
# 眼睛实时长宽比:0.32 	是否眨眼：False
# 嘴巴实时长宽比:0.79 	是否张嘴：True
# 眼睛实时长宽比:0.34 	是否眨眼：False
# 嘴巴实时长宽比:0.75 	是否张嘴：True
# 眼睛实时长宽比:0.33 	是否眨眼：False
# 嘴巴实时长宽比:0.69 	是否张嘴：True
# 眼睛实时长宽比:0.33 	是否眨眼：False
# 嘴巴实时长宽比:0.58 	是否张嘴：True
# 眼睛实时长宽比:0.33 	是否眨眼：False
# 嘴巴实时长宽比:0.51 	是否张嘴：True
# 眼睛实时长宽比:0.32 	是否眨眼：False
# 嘴巴实时长宽比:0.51 	是否张嘴：True
# 眼睛实时长宽比:0.35 	是否眨眼：False
# 嘴巴实时长宽比:0.48 	是否张嘴：False
# 眼睛实时长宽比:0.33 	是否眨眼：False
# 嘴巴实时长宽比:0.48 	是否张嘴：False
# 眼睛实时长宽比:0.34 	是否眨眼：False
# 嘴巴实时长宽比:0.46 	是否张嘴：False
# 眼睛实时长宽比:0.32 	是否眨眼：False
# 嘴巴实时长宽比:0.49 	是否张嘴：False
# 眼睛实时长宽比:0.33 	是否眨眼：False
# 嘴巴实时长宽比:0.49 	是否张嘴：False
# 眼睛实时长宽比:0.32 	是否眨眼：False
# 嘴巴实时长宽比:0.49 	是否张嘴：False
# 眼睛实时长宽比:0.33 	是否眨眼：False
# 嘴巴实时长宽比:0.48 	是否张嘴：False
# 眼睛实时长宽比:0.33 	是否眨眼：False
# 嘴巴实时长宽比:0.50 	是否张嘴：False
# 眼睛实时长宽比:0.33 	是否眨眼：False
# 嘴巴实时长宽比:0.50 	是否张嘴：False
# 眼睛实时长宽比:0.32 	是否眨眼：False
# 嘴巴实时长宽比:0.48 	是否张嘴：False
# 眼睛实时长宽比:0.34 	是否眨眼：False
# 嘴巴实时长宽比:0.48 	是否张嘴：False
# 眼睛实时长宽比:0.32 	是否眨眼：False
# 嘴巴实时长宽比:0.47 	是否张嘴：False
# 眼睛实时长宽比:0.31 	是否眨眼：False
# 嘴巴实时长宽比:0.49 	是否张嘴：False
# 眼睛实时长宽比:0.31 	是否眨眼：False
# 嘴巴实时长宽比:0.47 	是否张嘴：False
# 眼睛实时长宽比:0.32 	是否眨眼：False
# 嘴巴实时长宽比:0.47 	是否张嘴：False
# 眼睛实时长宽比:0.15 	是否眨眼：True
# 嘴巴实时长宽比:0.47 	是否张嘴：False
# 眼睛实时长宽比:0.15 	是否眨眼：True
# 嘴巴实时长宽比:0.49 	是否张嘴：False
# 眼睛实时长宽比:0.11 	是否眨眼：True
# 嘴巴实时长宽比:0.49 	是否张嘴：False
# 眼睛实时长宽比:0.17 	是否眨眼：True
# 嘴巴实时长宽比:0.49 	是否张嘴：False
# 眼睛实时长宽比:0.30 	是否眨眼：False
# 嘴巴实时长宽比:0.49 	是否张嘴：False
# 眼睛实时长宽比:0.31 	是否眨眼：False
# 嘴巴实时长宽比:0.48 	是否张嘴：False
# 眼睛实时长宽比:0.31 	是否眨眼：False
# 嘴巴实时长宽比:0.47 	是否张嘴：False
# 眼睛实时长宽比:0.32 	是否眨眼：False
# 嘴巴实时长宽比:0.48 	是否张嘴：False
# 眼睛实时长宽比:0.31 	是否眨眼：False
# 嘴巴实时长宽比:0.47 	是否张嘴：False
# 眼睛实时长宽比:0.31 	是否眨眼：False
# 嘴巴实时长宽比:0.48 	是否张嘴：False
# 眼睛实时长宽比:0.29 	是否眨眼：False
# 嘴巴实时长宽比:0.46 	是否张嘴：False
# 眼睛实时长宽比:0.32 	是否眨眼：False
# 嘴巴实时长宽比:0.46 	是否张嘴：False
# 眼睛实时长宽比:0.33 	是否眨眼：False
# 嘴巴实时长宽比:0.47 	是否张嘴：False
# 眼睛实时长宽比:0.31 	是否眨眼：False
# 嘴巴实时长宽比:0.47 	是否张嘴：False
# 眼睛实时长宽比:0.32 	是否眨眼：False
# 嘴巴实时长宽比:0.48 	是否张嘴：False
# 眼睛实时长宽比:0.31 	是否眨眼：False
# 嘴巴实时长宽比:0.47 	是否张嘴：False
# 眼睛实时长宽比:0.31 	是否眨眼：False
# 嘴巴实时长宽比:0.45 	是否张嘴：False
# 眼睛实时长宽比:0.32 	是否眨眼：False
# 嘴巴实时长宽比:0.48 	是否张嘴：False
# 眼睛实时长宽比:0.31 	是否眨眼：False
# 嘴巴实时长宽比:0.46 	是否张嘴：False
# 眼睛实时长宽比:0.31 	是否眨眼：False
# 嘴巴实时长宽比:0.49 	是否张嘴：False
# 眼睛实时长宽比:0.33 	是否眨眼：False
# 嘴巴实时长宽比:0.48 	是否张嘴：False
# 眼睛实时长宽比:0.30 	是否眨眼：False
# 嘴巴实时长宽比:0.46 	是否张嘴：False
# 眼睛实时长宽比:0.31 	是否眨眼：False
# 嘴巴实时长宽比:0.49 	是否张嘴：False
# 眼睛实时长宽比:0.33 	是否眨眼：False
# 嘴巴实时长宽比:0.46 	是否张嘴：False
# 眼睛实时长宽比:0.31 	是否眨眼：False
# 嘴巴实时长宽比:0.48 	是否张嘴：False
# 眼睛实时长宽比:0.32 	是否眨眼：False
# 嘴巴实时长宽比:0.48 	是否张嘴：False
# 眼睛实时长宽比:0.32 	是否眨眼：False
# 嘴巴实时长宽比:0.47 	是否张嘴：False
# 眼睛实时长宽比:0.32 	是否眨眼：False
# 嘴巴实时长宽比:0.47 	是否张嘴：False
# 眼睛实时长宽比:0.32 	是否眨眼：False
# 嘴巴实时长宽比:0.46 	是否张嘴：False
# 眼睛实时长宽比:0.31 	是否眨眼：False

# %%
#!/usr/bin/env python
 
import cv2
import numpy as np
import dlib
import time
import math

detector = dlib.get_frontal_face_detector()
predictor = dlib.shape_predictor("D:/myworkspace/JupyterNotebook/fatigue_detecting/model/shape_predictor_68_face_landmarks.dat")
POINTS_NUM_LANDMARK = 68

# 获取最大的人脸
def _largest_face(dets):
    if len(dets) == 1:
        return 0

    face_areas = [ (det.right()-det.left())*(det.bottom()-det.top()) for det in dets]

    largest_area = face_areas[0]
    largest_index = 0
    for index in range(1, len(dets)):
        if face_areas[index] > largest_area :
            largest_index = index
            largest_area = face_areas[index]

    print("largest_face index is {} in {} faces".format(largest_index, len(dets)))

    return largest_index

# 从dlib的检测结果抽取姿态估计需要的点坐标
def get_image_points_from_landmark_shape(landmark_shape):
    if landmark_shape.num_parts != POINTS_NUM_LANDMARK:
        print("ERROR:landmark_shape.num_parts-{}".format(landmark_shape.num_parts))
        return -1, None
    
    #2D image points. If you change the image, you need to change vector
    image_points = np.array([
                                (landmark_shape.part(30).x, landmark_shape.part(30).y),     # Nose tip
                                (landmark_shape.part(8).x, landmark_shape.part(8).y),     # Chin
                                (landmark_shape.part(36).x, landmark_shape.part(36).y),     # Left eye left corner
                                (landmark_shape.part(45).x, landmark_shape.part(45).y),     # Right eye right corne
                                (landmark_shape.part(48).x, landmark_shape.part(48).y),     # Left Mouth corner
                                (landmark_shape.part(54).x, landmark_shape.part(54).y)      # Right mouth corner
                            ], dtype="double")

    return 0, image_points
    
# 用dlib检测关键点，返回姿态估计需要的几个点坐标
def get_image_points(img):
                            
    #gray = cv2.cvtColor( img, cv2.COLOR_BGR2GRAY )  # 图片调整为灰色
    dets = detector( img, 0 )

    if 0 == len( dets ):
        print( "ERROR: found no face" )
        return -1, None
    largest_index = _largest_face(dets)
    face_rectangle = dets[largest_index]

    landmark_shape = predictor(img, face_rectangle)

    return get_image_points_from_landmark_shape(landmark_shape)


# 获取旋转向量和平移向量                        
def get_pose_estimation(img_size, image_points ):
    # 参考：https://www.learnopencv.com/head-pose-estimation-using-opencv-and-dlib/
    # 3D model points.
    model_points = np.array([
                                (0.0, 0.0, 0.0),             # Nose tip
                                (0.0, -330.0, -65.0),        # Chin
                                (-225.0, 170.0, -135.0),     # Left eye left corner
                                (225.0, 170.0, -135.0),      # Right eye right corne
                                (-150.0, -150.0, -125.0),    # Left Mouth corner
                                (150.0, -150.0, -125.0)      # Right mouth corner
                             
                            ])
     
    # Camera internals
     
    focal_length = img_size[1]
    center = (img_size[1]/2, img_size[0]/2)
    camera_matrix = np.array(
                             [[focal_length, 0, center[0]],
                             [0, focal_length, center[1]],
                             [0, 0, 1]], dtype = "double"
                             )
     
    print("Camera Matrix :{}".format(camera_matrix))
     
    dist_coeffs = np.zeros((4,1)) # Assuming no lens distortion
    (success, rotation_vector, translation_vector) = cv2.solvePnP(model_points, image_points, camera_matrix, dist_coeffs, flags=cv2.SOLVEPNP_ITERATIVE )
 
    print("Rotation Vector:\n {}".format(rotation_vector))
    print("Translation Vector:\n {}".format(translation_vector))
    return success, rotation_vector, translation_vector, camera_matrix, dist_coeffs

# 从旋转向量转换为欧拉角
def get_euler_angle(rotation_vector):
    # calculate rotation angles
    theta = cv2.norm(rotation_vector, cv2.NORM_L2)
    
    # transformed to quaterniond
    w = math.cos(theta / 2)
    x = math.sin(theta / 2)*rotation_vector[0][0] / theta
    y = math.sin(theta / 2)*rotation_vector[1][0] / theta
    z = math.sin(theta / 2)*rotation_vector[2][0] / theta
    
    ysqr = y * y
    # pitch (x-axis rotation)
    t0 = 2.0 * (w * x + y * z)
    t1 = 1.0 - 2.0 * (x * x + ysqr)
    print('t0:{}, t1:{}'.format(t0, t1))
    pitch = math.atan2(t0, t1)
    
    # yaw (y-axis rotation)
    t2 = 2.0 * (w * y - z * x)
    if t2 > 1.0:
        t2 = 1.0
    if t2 < -1.0:
        t2 = -1.0
    yaw = math.asin(t2)
    
    # roll (z-axis rotation)
    t3 = 2.0 * (w * z + x * y)
    t4 = 1.0 - 2.0 * (ysqr + z * z)
    roll = math.atan2(t3, t4)
    
    print('pitch:{}, yaw:{}, roll:{}'.format(pitch, yaw, roll))
    
	# 单位转换：将弧度转换为度
    Y = int((pitch/math.pi)*180)
    X = int((yaw/math.pi)*180)
    Z = int((roll/math.pi)*180)
    
    return 0, Y, X, Z

def get_pose_estimation_in_euler_angle(landmark_shape, im_szie):
    try:
        ret, image_points = get_image_points_from_landmark_shape(landmark_shape)
        if ret != 0:
            print('get_image_points failed')
            return -1, None, None, None
    
        ret, rotation_vector, translation_vector, camera_matrix, dist_coeffs = get_pose_estimation(im_szie, image_points)
        if ret != True:
            print('get_pose_estimation failed')
            return -1, None, None, None
    
        ret, pitch, yaw, roll = get_euler_angle(rotation_vector)
        if ret != 0:
            print('get_euler_angle failed')
            return -1, None, None, None

        euler_angle_str = 'Y:{}, X:{}, Z:{}'.format(pitch, yaw, roll)
        print(euler_angle_str)
        return 0, pitch, yaw, roll
    
    except Exception as e:
        print('get_pose_estimation_in_euler_angle exception:{}'.format(e))
        return -1, None, None, None
        
if __name__ == '__main__':

    cap = cv2.VideoCapture(0)
    while (cap.isOpened()):
        start_time = time.time()
        
        # Read Image
        ret, im = cap.read()
        if ret != True:
            print('read frame failed')
            continue
        size = im.shape
        
        if size[0] > 700:
            h = size[0] / 3
            w = size[1] / 3
            im = cv2.resize( im, (int( w ), int( h )), interpolation=cv2.INTER_CUBIC )
            size = im.shape
     
        ret, image_points = get_image_points(im)
        if ret != 0:
            print('get_image_points failed')
            continue
        
        ret, rotation_vector, translation_vector, camera_matrix, dist_coeffs = get_pose_estimation(size, image_points)
        if ret != True:
            print('get_pose_estimation failed')
            continue
        used_time = time.time() - start_time
        print("used_time:{} sec".format(round(used_time, 3)))
        
        ret, pitch, yaw, roll = get_euler_angle(rotation_vector)
        euler_angle_str = 'Y:{}, X:{}, Z:{}'.format(pitch, yaw, roll)
        print(euler_angle_str)
        
        # Project a 3D point (0, 0, 1000.0) onto the image plane.
        # We use this to draw a line sticking out of the nose
         
        (nose_end_point2D, jacobian) = cv2.projectPoints(np.array([(0.0, 0.0, 1000.0)]), rotation_vector, translation_vector, camera_matrix, dist_coeffs)
         
        for p in image_points:
            cv2.circle(im, (int(p[0]), int(p[1])), 3, (0,0,255), -1)
         
         
        p1 = ( int(image_points[0][0]), int(image_points[0][1]))
        p2 = ( int(nose_end_point2D[0][0][0]), int(nose_end_point2D[0][0][1]))
         
        cv2.line(im, p1, p2, (255,0,0), 2)
         
        # Display image
        #cv2.putText( im, str(rotation_vector), (0, 100), cv2.FONT_HERSHEY_PLAIN, 1, (0, 0, 255), 1 )
        cv2.putText( im, euler_angle_str, (0, 120), cv2.FONT_HERSHEY_PLAIN, 1, (0, 0, 255), 1 )
        # 按q退出
        cv2.putText(frame, "Press 'q': Quit", (20, 500),cv2.FONT_HERSHEY_SIMPLEX, 0.7, (84, 255, 159), 2)
        # 窗口显示 show with opencv
        cv2.imshow("Output", im)
        # if the `q` key was pressed, break from the loop
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break
    # 释放摄像头 release camera
    cap.release()
    # do a bit of cleanup
    cv2.destroyAllWindows()
# Out:
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[-3.28795339]
#  [ 0.12774694]
#  [-0.25047449]]
# Translation Vector:
#  [[ 341.79770399]
#  [  47.68323618]
#  [3389.54417784]]
# used_time:0.554 sec
# t0:0.15128660684155779, t1:-0.9760368099084753
# pitch:2.987815451701243, yaw:-0.15705622270622585, roll:-0.06554251739732628
# Y:171, X:-8, Z:-3
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[-3.28971491]
#  [ 0.12447173]
#  [-0.25155751]]
# Translation Vector:
#  [[ 340.18522843]
#  [  47.22105966]
#  [3380.54348181]]
# used_time:0.068 sec
# t0:0.15310565776403243, t1:-0.9756796429682955
# pitch:2.9859399373956057, yaw:-0.1575196275834502, roll:-0.06332788694516155
# Y:171, X:-9, Z:-3
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[-3.28295523]
#  [ 0.13008136]
#  [-0.34468586]]
# Translation Vector:
#  [[ 346.40066467]
#  [  45.07729256]
#  [3382.07540854]]
# used_time:0.078 sec
# t0:0.15209351105738667, t1:-0.9652813562230151
# pitch:2.985313566361145, yaw:-0.21399591281083558, roll:-0.062385567288694536
# Y:171, X:-12, Z:-3
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[-3.27321974]
#  [ 0.11803741]
#  [-0.308361  ]]
# Translation Vector:
#  [[ 342.67473421]
#  [  48.79120912]
#  [3395.73295801]]
# used_time:0.056 sec
# t0:0.14026090265390725, t1:-0.9715579684940161
# pitch:2.998216259407281, yaw:-0.19196998757698083, roll:-0.0582640040257562
# Y:171, X:-10, Z:-3
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[-3.26812707]
#  [ 0.12848846]
#  [-0.32014571]]
# Translation Vector:
#  [[ 346.45983471]
#  [  47.81377774]
#  [3412.29971394]]
# used_time:0.064 sec
# t0:0.13581155083306426, t1:-0.9706689067113725
# pitch:3.002579664068945, yaw:-0.1997111495868446, roll:-0.06464098745590947
# Y:172, X:-11, Z:-3
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[-3.25615561]
#  [ 0.13879845]
#  [-0.31425328]]
# Translation Vector:
#  [[ 344.61175175]
#  [  48.49910273]
#  [3397.47179532]]
# used_time:0.051 sec
# t0:0.12341543051366065, t1:-0.9728742336491414
# pitch:3.015410129778319, yaw:-0.19693437756376403, roll:-0.07271982428813038
# Y:172, X:-11, Z:-4
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[-3.24693366]
#  [ 0.12559715]
#  [-0.35999035]]
# Translation Vector:
#  [[ 342.81790466]
#  [  47.52053011]
#  [3353.67341681]]
# used_time:0.054 sec
# t0:0.1180083899911415, t1:-0.9677121599223133
# pitch:3.020246037429693, yaw:-0.2246105669129391, roll:-0.06362293961377541
# Y:173, X:-12, Z:-3
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[-3.27344559]
#  [ 0.1277233 ]
#  [-0.2970133 ]]
# Translation Vector:
#  [[ 343.2841932 ]
#  [  45.11725198]
#  [3364.88989968]]
# used_time:0.058 sec
# t0:0.13955636445760278, t1:-0.9728828761114376
# pitch:2.999118357726511, yaw:-0.18551534232974334, roll:-0.06472055072626971
# Y:171, X:-10, Z:-3
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[-3.25435269]
#  [ 0.13421277]
#  [-0.25334848]]
# Translation Vector:
#  [[ 340.78196377]
#  [  45.87895586]
#  [3372.9614495 ]]
# used_time:0.047 sec
# t0:0.11820740450363626, t1:-0.980171716348053
# pitch:3.0215735987676964, yaw:-0.1597076736681023, roll:-0.07281941377476367
# Y:173, X:-9, Z:-4
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[-3.24951433]
#  [ 0.12928387]
#  [-0.36955076]]
# Translation Vector:
#  [[ 346.95409076]
#  [  46.58116791]
#  [3365.22383214]]
# used_time:0.056 sec
# t0:0.12122190811303908, t1:-0.9659898746202449
# pitch:3.016755390978746, yaw:-0.23043898652077413, roll:-0.0650630350701143
# Y:172, X:-13, Z:-3
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[-3.24951433]
#  [ 0.12928387]
#  [-0.36955076]]
# Translation Vector:
#  [[ 346.95409076]
#  [  46.58116791]
#  [3365.22383214]]
# used_time:0.046 sec
# t0:0.12122190811303908, t1:-0.9659898746202449
# pitch:3.016755390978746, yaw:-0.23043898652077413, roll:-0.0650630350701143
# Y:172, X:-13, Z:-3
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[-3.25209874]
#  [ 0.13802159]
#  [-0.29149802]]
# Translation Vector:
#  [[ 341.43007242]
#  [  45.78011036]
#  [3348.03882176]]
# used_time:0.051 sec
# t0:0.11800330166152267, t1:-0.9761661917158349
# pitch:3.0212919359348023, yaw:-0.18316188216262186, roll:-0.07376925449204136
# Y:173, X:-10, Z:-4
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[-3.25549794]
#  [ 0.134773  ]
#  [-0.3549093 ]]
# Translation Vector:
#  [[ 345.76150358]
#  [  43.43647615]
#  [3336.55673264]]
# used_time:0.048 sec
# t0:0.12577095978699349, t1:-0.9674279310479559
# pitch:3.012312232923353, yaw:-0.2214994204696133, roll:-0.06835350971973404
# Y:172, X:-12, Z:-3
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[-3.24424961]
#  [ 0.12404584]
#  [-0.38115459]]
# Translation Vector:
#  [[ 352.10479188]
#  [  41.21928447]
#  [3352.86644015]]
# used_time:0.047 sec
# t0:0.11720948035607945, t1:-0.9648242384495298
# pitch:3.0207023053120814, yaw:-0.23754916550764965, roll:-0.06199002096457088
# Y:173, X:-13, Z:-3
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[-3.26717204]
#  [ 0.12041215]
#  [-0.36649597]]
# Translation Vector:
#  [[ 352.51504827]
#  [  42.41083533]
#  [3369.60782106]]
# used_time:0.047 sec
# t0:0.13860341811354643, t1:-0.964342955773976
# pitch:2.9988419241293522, yaw:-0.2274141305255209, roll:-0.05734751231347102
# Y:171, X:-13, Z:-3
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[-3.26074892]
#  [ 0.12351397]
#  [-0.33595492]]
# Translation Vector:
#  [[ 348.59620249]
#  [  41.16694488]
#  [3355.63463554]]
# used_time:0.045 sec
# t0:0.12979759026248344, t1:-0.9695137720530855
# pitch:3.008504967578745, yaw:-0.20936170719921657, roll:-0.06171854601241435
# Y:172, X:-11, Z:-3
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[-3.25339882]
#  [ 0.12851844]
#  [-0.38154919]]
# Translation Vector:
#  [[ 352.09507298]
#  [  39.48383834]
#  [3356.29892312]]
# used_time:0.059 sec
# t0:0.12608443264193628, t1:-0.963714834097094
# pitch:3.0114998765806202, yaw:-0.23750611180834413, roll:-0.06342102538353812
# Y:172, X:-13, Z:-3
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[-3.25034586]
#  [ 0.12977676]
#  [-0.35870814]]
# Translation Vector:
#  [[ 347.80635234]
#  [  40.86320367]
#  [3352.66104843]]
# used_time:0.046 sec
# t0:0.12113958549106407, t1:-0.9674991214011144
# pitch:3.017031891935951, yaw:-0.22383434014510395, roll:-0.06579484769079386
# Y:172, X:-12, Z:-3
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[-3.25034586]
#  [ 0.12977676]
#  [-0.35870814]]
# Translation Vector:
#  [[ 347.80635234]
#  [  40.86320367]
#  [3352.66104843]]
# used_time:0.046 sec
# t0:0.12113958549106407, t1:-0.9674991214011144
# pitch:3.017031891935951, yaw:-0.22383434014510395, roll:-0.06579484769079386
# Y:172, X:-12, Z:-3
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[-3.24291317]
#  [ 0.12791809]
#  [-0.38480827]]
# Translation Vector:
#  [[ 346.21731214]
#  [  41.96216885]
#  [3346.43766932]]
# used_time:0.047 sec
# t0:0.11608244008261115, t1:-0.9643834132669649
# pitch:3.021799395948251, yaw:-0.23997176139952375, roll:-0.0643900507562528
# Y:173, X:-13, Z:-3
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[-3.24915218]
#  [ 0.12105296]
#  [-0.33797249]]
# Translation Vector:
#  [[ 345.0901607 ]
#  [  41.2814313 ]
#  [3351.76421802]]
# used_time:0.047 sec
# t0:0.11859387334359767, t1:-0.9706119770273911
# pitch:3.020010661242028, yaw:-0.21096015168153778, roll:-0.06159116405096395
# Y:173, X:-12, Z:-3
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[-3.25481628]
#  [ 0.1290886 ]
#  [-0.32680512]]
# Translation Vector:
#  [[ 343.46830363]
#  [  41.1954866 ]
#  [3364.45669892]]
# used_time:0.048 sec
# t0:0.12315164440650835, t1:-0.9714390004831803
# pitch:3.015492918366819, yaw:-0.2042469620453512, roll:-0.06634036760173144
# Y:172, X:-11, Z:-3
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[-3.25415555]
#  [ 0.12659413]
#  [-0.29414662]]
# Translation Vector:
#  [[ 337.10564317]
#  [  42.80484552]
#  [3402.1872369 ]]
# used_time:0.045 sec
# t0:0.12037816153106655, t1:-0.9756653386977157
# pitch:3.018832475190946, yaw:-0.1843071930439992, roll:-0.06640631143999452
# Y:172, X:-10, Z:-3
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[-3.28306819]
#  [ 0.16279422]
#  [ 0.10882999]]
# Translation Vector:
#  [[ 271.65789384]
#  [  36.40059662]
#  [3428.44023691]]
# used_time:0.105 sec
# t0:0.14977575107568677, t1:-0.9869913991042139
# pitch:2.9909918473486323, yaw:0.05847304892398459, roll:-0.10350347731981607
# Y:171, X:3, Z:-5
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[-3.26816481]
#  [ 0.18997709]
#  [ 0.39416603]]
# Translation Vector:
#  [[ 209.0705659]
#  [  34.325029 ]
#  [3406.2166687]]
# used_time:0.062 sec
# t0:0.16742446820869486, t1:-0.9594908189974014
# pitch:2.9688389268080946, yaw:0.22858286162478464, roll:-0.13600800804623386
# Y:170, X:13, Z:-7
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[-3.26816481]
#  [ 0.18997709]
#  [ 0.39416603]]
# Translation Vector:
#  [[ 209.0705659]
#  [  34.325029 ]
#  [3406.2166687]]
# used_time:0.045 sec
# t0:0.16742446820869486, t1:-0.9594908189974014
# pitch:2.9688389268080946, yaw:0.22858286162478464, roll:-0.13600800804623386
# Y:170, X:13, Z:-7
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[-3.21694308]
#  [ 0.22615127]
#  [ 0.69920342]]
# Translation Vector:
#  [[ 140.53643695]
#  [  39.56832517]
#  [3376.3836431 ]]
# used_time:0.046 sec
# t0:0.18246476134321057, t1:-0.8982739591996403
# pitch:2.9411910384283373, yaw:0.41125833921071064, roll:-0.18230270376971505
# Y:168, X:23, Z:-10
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[ 2.84619165]
#  [-0.21608806]
#  [-0.75293607]]
# Translation Vector:
#  [[  89.27533325]
#  [  37.59589413]
#  [3437.06261694]]
# used_time:0.046 sec
# t0:0.21869126818040927, t1:-0.8531408595261785
# pitch:2.890659035678702, yaw:0.4934071535097047, roll:-0.2150587450654902
# Y:165, X:28, Z:-12
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[-3.15717481]
#  [ 0.24803782]
#  [ 1.03788324]]
# Translation Vector:
#  [[  42.5378284 ]
#  [  38.88323846]
#  [3384.69862804]]
# used_time:0.047 sec
# t0:0.2258238225752381, t1:-0.7895936387208882
# pitch:2.863028814527662, yaw:0.6071948037448112, roll:-0.24458580544741165
# Y:164, X:34, Z:-14
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[-0.30134965]
#  [-3.76889924]
#  [-0.27691352]]
# Translation Vector:
#  [[  -27.07458736]
#  [  -50.63210373]
#  [-3530.58209365]]
# used_time:0.046 sec
# t0:0.17852196192325331, t1:-0.7868247782324191
# pitch:2.918480872421806, yaw:0.6320416783952181, roll:2.908793969617795
# Y:167, X:36, Z:166
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[-0.32109064]
#  [-3.86041237]
#  [-0.33363413]]
# Translation Vector:
#  [[    4.78018922]
#  [  -52.72948348]
#  [-3469.08067277]]
# used_time:0.134 sec
# t0:0.20382061592046802, t1:-0.721307775832662
# pitch:2.8662015138786017, yaw:0.7234117535439877, roll:2.8708619193839606
# Y:164, X:41, Z:164
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[-0.32672129]
#  [-3.87001034]
#  [-0.28255631]]
# Translation Vector:
#  [[    8.88366128]
#  [  -52.58394261]
#  [-3485.28315356]]
# used_time:0.048 sec
# t0:0.18209901318202523, t1:-0.7209081903954726
# pitch:2.8941715564885397, yaw:0.7324304794989159, roll:2.8778396818284624
# Y:165, X:41, Z:164
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[-0.30717888]
#  [-3.8639465 ]
#  [-0.3054228 ]]
# Translation Vector:
#  [[    9.16793946]
#  [  -55.95837105]
#  [-3463.94083316]]
# used_time:0.045 sec
# t0:0.18901670876586804, t1:-0.7233302090099298
# pitch:2.8859936755984634, yaw:0.7263269359891318, roll:2.8853416697131684
# Y:165, X:41, Z:165
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[-0.3401869 ]
#  [-3.84743892]
#  [-0.29578868]]
# Translation Vector:
#  [[-4.61660568e-01]
#  [-5.79482512e+01]
#  [-3.49991179e+03]]
# used_time:0.053 sec
# t0:0.19094623299679472, t1:-0.733561745651689
# pitch:2.8869434702430197, yaw:0.7105455831746513, roll:2.870291909935883
# Y:165, X:40, Z:164
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[-0.31147316]
#  [-3.82035893]
#  [-0.33271379]]
# Translation Vector:
#  [[   -4.054416  ]
#  [  -55.90414829]
#  [-3506.82963833]]
# used_time:0.064 sec
# t0:0.20373258089257873, t1:-0.7478874568123375
# pitch:2.8756352403742835, yaw:0.6838590637014157, roll:2.8837460726325084
# Y:164, X:39, Z:165
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[-0.31147316]
#  [-3.82035893]
#  [-0.33271379]]
# Translation Vector:
#  [[   -4.054416  ]
#  [  -55.90414829]
#  [-3506.82963833]]
# used_time:0.048 sec
# t0:0.20373258089257873, t1:-0.7478874568123375
# pitch:2.8756352403742835, yaw:0.6838590637014157, roll:2.8837460726325084
# Y:164, X:39, Z:165
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[-0.29985606]
#  [-3.83204166]
#  [-0.29297507]]
# Translation Vector:
#  [[   -7.89699325]
#  [  -53.37537734]
#  [-3498.06861419]]
# used_time:0.046 sec
# t0:0.18357891738095777, t1:-0.7460547626096243
# pitch:2.900319731633682, yaw:0.6946010295603406, roll:2.897707529093604
# Y:166, X:39, Z:166
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[ 2.78164135]
#  [-0.23995719]
#  [-0.99922695]]
# Translation Vector:
#  [[   5.49274287]
#  [  49.86671928]
#  [3429.93870087]]
# used_time:0.045 sec
# t0:0.21853762954673628, t1:-0.7591875462425259
# pitch:2.8613128987722494, yaw:0.659962114322662, roll:-0.2686583246793219
# Y:163, X:37, Z:-15
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[ 2.78626717]
#  [-0.22066726]
#  [-1.02493903]]
# Translation Vector:
#  [[   8.32327572]
#  [  50.18563275]
#  [3420.27385896]]
# used_time:0.047 sec
# t0:0.20405609211163106, t1:-0.7510190602966671
# pitch:2.8762917828034236, yaw:0.6789268181931384, roll:-0.2522367172194324
# Y:164, X:38, Z:-14
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[-0.27824347]
#  [-3.847667  ]
#  [-0.24916504]]
# Translation Vector:
#  [[  -15.4086092 ]
#  [  -56.76081894]
#  [-3536.06412795]]
# used_time:0.045 sec
# t0:0.15989198234584887, t1:-0.7417899126365122
# pitch:2.9292919270075974, yaw:0.7092868447509045, roll:2.9183436969306147
# Y:167, X:40, Z:167
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[-0.29852148]
#  [-3.80252809]
#  [-0.29571446]]
# Translation Vector:
#  [[  -20.65080043]
#  [  -53.26328849]
#  [-3539.72903649]]
# used_time:0.065 sec
# t0:0.18568531339886796, t1:-0.7643944771679374
# pitch:2.9032902607424362, yaw:0.6654736875950318, roll:2.902203236235921
# Y:166, X:38, Z:166
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[-0.29719877]
#  [-3.8105129 ]
#  [-0.29106347]]
# Translation Vector:
#  [[  -30.49389934]
#  [  -53.67113953]
#  [-3486.88659788]]
# used_time:0.047 sec
# t0:0.1830733433738722, t1:-0.7600455373552188
# pitch:2.905223757259303, yaw:0.6732757625025043, roll:2.9028601277102193
# Y:166, X:38, Z:166
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[-0.29719877]
#  [-3.8105129 ]
#  [-0.29106347]]
# Translation Vector:
#  [[  -30.49389934]
#  [  -53.67113953]
#  [-3486.88659788]]
# used_time:0.046 sec
# t0:0.1830733433738722, t1:-0.7600455373552188
# pitch:2.905223757259303, yaw:0.6732757625025043, roll:2.9028601277102193
# Y:166, X:38, Z:166
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[-3.17863981]
#  [ 0.22147458]
#  [ 0.98734485]]
# Translation Vector:
#  [[  54.46212464]
#  [  41.60257187]
#  [3423.93882616]]
# used_time:0.046 sec
# t0:0.22284136269486185, t1:-0.8076333397649864
# pitch:2.872372280512847, yaw:0.5775321189066052, roll:-0.21954730910165784
# Y:164, X:33, Z:-12
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[-3.20126113]
#  [ 0.24330766]
#  [ 0.84031584]]
# Translation Vector:
#  [[  99.22541129]
#  [  38.54486969]
#  [3430.29687743]]
# used_time:0.046 sec
# t0:0.20673681776338987, t1:-0.8571383381190822
# pitch:2.9049187946348614, yaw:0.4913053418839377, roll:-0.21131457790999453
# Y:166, X:28, Z:-12
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[-3.2545268 ]
#  [ 0.23407592]
#  [ 0.57973989]]
# Translation Vector:
#  [[ 163.39392588]
#  [  35.84380391]
#  [3468.58857847]]
# used_time:0.046 sec
# t0:0.193037372006783, t1:-0.9244180355098353
# pitch:2.9357304747464776, yaw:0.3351589114460993, roll:-0.17854392547809947
# Y:168, X:19, Z:-10
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[-3.32132061]
#  [ 0.21256445]
#  [ 0.11531085]]
# Translation Vector:
#  [[ 252.04319243]
#  [  25.44192114]
#  [3465.85223657]]
# used_time:0.047 sec
# t0:0.19129197122891844, t1:-0.9799058808234742
# pitch:2.9488026096636735, yaw:0.05652652673851903, roll:-0.13329288427613023
# Y:168, X:3, Z:-7
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[-3.30376774]
#  [ 0.17465813]
#  [-0.38206629]]
# Translation Vector:
#  [[ 341.1760781 ]
#  [  16.21635771]
#  [3423.61373131]]
# used_time:0.052 sec
# t0:0.17423264995136872, t1:-0.9561460819351266
# pitch:2.9613464649492687, yaw:-0.23766178658762213, roll:-0.0840565364751299
# Y:169, X:-13, Z:-4
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[-3.28935354]
#  [ 0.15528178]
#  [-0.57425812]]
# Translation Vector:
#  [[ 408.66957251]
#  [   9.05092293]
#  [3374.56634446]]
# used_time:0.055 sec
# t0:0.1807784179988024, t1:-0.9214118638306905
# pitch:2.9478563020512567, yaw:-0.3511477912863474, roll:-0.05987131250474106
# Y:168, X:-20, Z:-3
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[-3.28935354]
#  [ 0.15528178]
#  [-0.57425812]]
# Translation Vector:
#  [[ 408.66957251]
#  [   9.05092293]
#  [3374.56634446]]
# used_time:0.045 sec
# t0:0.1807784179988024, t1:-0.9214118638306905
# pitch:2.9478563020512567, yaw:-0.3511477912863474, roll:-0.05987131250474106
# Y:168, X:-20, Z:-3
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[-3.28307917]
#  [ 0.137734  ]
#  [-0.71853639]]
# Translation Vector:
#  [[4.67184987e+02]
#  [1.71495608e+00]
#  [3.37470809e+03]]
# used_time:0.046 sec
# t0:0.19764612911794763, t1:-0.8853077263041891
# pitch:2.921943240630151, yaw:-0.4344496029189165, roll:-0.03519174408239514
# Y:167, X:-24, Z:-2
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[-3.25878912]
#  [ 0.10754532]
#  [-0.91498871]]
# Translation Vector:
#  [[ 512.71312884]
#  [  -5.12348433]
#  [3344.04994567]]
# used_time:0.046 sec
# t0:0.21643018069812608, t1:-0.8263340399670096
# pitch:2.8854306702149923, yaw:-0.5467721834075914, roll:0.006214328975016223
# Y:165, X:-31, Z:0
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[-3.2483434 ]
#  [ 0.10537645]
#  [-0.98989326]]
# Translation Vector:
#  [[ 545.20528747]
#  [  -9.09211149]
#  [3322.35465183]]
# used_time:0.045 sec
# t0:0.22419596455505103, t1:-0.8004235257106429
# pitch:2.8684943102115326, yaw:-0.5894815723562925, roll:0.018521494924541096
# Y:164, X:-33, Z:1
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[-3.25120922]
#  [ 0.04975335]
#  [-1.02301226]]
# Translation Vector:
#  [[ 578.36184992]
#  [  -9.72202517]
#  [3383.24571399]]
# used_time:0.056 sec
# t0:0.24316134347057958, t1:-0.7875877345097655
# pitch:2.84213517684997, yaw:-0.601883737598983, roll:0.06297100478742096
# Y:162, X:-34, Z:3
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[-3.25120922]
#  [ 0.04975335]
#  [-1.02301226]]
# Translation Vector:
#  [[ 578.36184992]
#  [  -9.72202517]
#  [3383.24571399]]
# used_time:0.046 sec
# t0:0.24316134347057958, t1:-0.7875877345097655
# pitch:2.84213517684997, yaw:-0.601883737598983, roll:0.06297100478742096
# Y:162, X:-34, Z:3
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[-0.09133089]
#  [-2.14794952]
#  [-0.32705879]]
# Translation Vector:
#  [[ -595.42583187]
#  [    8.68406482]
#  [-3398.84293995]]
# used_time:0.045 sec
# t0:0.19832918668569027, t1:-0.532335854372217
# pitch:2.7849593442110865, yaw:-0.9666242450626842, roll:-3.037962228978339
# Y:159, X:-55, Z:-174
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[-0.09387409]
#  [-2.12011244]
#  [-0.32425956]]
# Translation Vector:
#  [[ -618.95683319]
#  [    7.50947302]
#  [-3463.99615896]]
# used_time:0.045 sec
# t0:0.19373975015371436, t1:-0.5094529579016134
# pitch:2.7781924577152335, yaw:-0.994349868760993, roll:-3.031352701083522
# Y:159, X:-56, Z:-173
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[-0.07731895]
#  [-2.09436824]
#  [-0.31868151]]
# Translation Vector:
#  [[ -619.80685645]
#  [    6.74577154]
#  [-3410.63649183]]
# used_time:0.048 sec
# t0:0.19492260690837526, t1:-0.48751685966212666
# pitch:2.7612350634860765, yaw:-1.0180336449918341, roll:-3.00135288513643
# Y:158, X:-58, Z:-171
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[-0.07768589]
#  [-2.08711706]
#  [-0.31668431]]
# Translation Vector:
#  [[ -621.8734981 ]
#  [    5.02288465]
#  [-3404.52907635]]
# used_time:0.046 sec
# t0:0.19296660248194536, t1:-0.48148008175650836
# pitch:2.760415805679791, yaw:-1.0254559258119813, roll:-2.9996313260292236
# Y:158, X:-58, Z:-171
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[ 2.73879368]
#  [-0.02873431]
#  [ 0.95841475]]
# Translation Vector:
#  [[ 618.0797363 ]
#  [  -5.46767844]
#  [3367.21746762]]
# used_time:0.057 sec
# t0:0.2177238669201708, t1:-0.7563307917945767
# pitch:2.8613024289648368, yaw:-0.6647920683929692, roll:0.07633654638086655
# Y:163, X:-38, Z:4
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[-0.07829625]
#  [-2.1035068 ]
#  [-0.32414767]]
# Translation Vector:
#  [[ -619.30141238]
#  [    5.58657052]
#  [-3396.04757459]]
# used_time:0.046 sec
# t0:0.19887185842161442, t1:-0.49487212582972706
# pitch:2.7594794280065136, yaw:-1.0082556573951003, roll:-3.0034012188355934
# Y:158, X:-57, Z:-172
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[-0.08789442]
#  [-2.12399181]
#  [-0.31353302]]
# Translation Vector:
#  [[ -623.47712086]
#  [    4.48847467]
#  [-3440.69958873]]
# used_time:0.048 sec
# t0:0.18876497099489264, t1:-0.5134367926389374
# pitch:2.7892814508768957, yaw:-0.9919756829865966, roll:-3.03226751048926
# Y:159, X:-56, Z:-173
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[-0.08789442]
#  [-2.12399181]
#  [-0.31353302]]
# Translation Vector:
#  [[ -623.47712086]
#  [    4.48847467]
#  [-3440.69958873]]
# used_time:0.046 sec
# t0:0.18876497099489264, t1:-0.5134367926389374
# pitch:2.7892814508768957, yaw:-0.9919756829865966, roll:-3.03226751048926
# Y:159, X:-56, Z:-173
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[ 2.77855173]
#  [-0.04604335]
#  [ 0.94207242]]
# Translation Vector:
#  [[ 615.6400693 ]
#  [  -5.52752169]
#  [3378.37713015]]
# used_time:0.046 sec
# t0:0.1849439548919239, t1:-0.7746373800404147
# pitch:2.907230807855669, yaw:-0.6494624091097903, roll:0.04608027411665638
# Y:166, X:-37, Z:2
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[-3.19286194]
#  [ 0.041639  ]
#  [-1.09697513]]
# Translation Vector:
#  [[ 610.71449049]
#  [  -8.7178018 ]
#  [3370.67699622]]
# used_time:0.057 sec
# t0:0.2120260225719076, t1:-0.764350149470219
# pitch:2.8710022742023242, yaw:-0.6547296709787601, roll:0.06630589304004278
# Y:164, X:-37, Z:3
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[0.18133143]
#  [4.06546838]
#  [0.60136306]]
# Translation Vector:
#  [[ -607.60402957]
#  [   13.82818562]
#  [-3434.90808921]]
# used_time:0.046 sec
# t0:0.18947579332542713, t1:-0.5301440744953299
# pitch:2.798336828569254, yaw:-0.9728013591500546, roll:-3.047941938339492
# Y:160, X:-55, Z:-174
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[-0.08769851]
#  [-2.17940904]
#  [-0.36173897]]
# Translation Vector:
#  [[ -602.67591725]
#  [   27.94042067]
#  [-3455.27427644]]
# used_time:0.046 sec
# t0:0.2258000477602581, t1:-0.5545729727352859
# pitch:2.7549289627299984, yaw:-0.9288200196860722, roll:-3.026503287015016
# Y:157, X:-53, Z:-173
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[-3.29724871]
#  [ 0.05001253]
#  [-1.00717116]]
# Translation Vector:
#  [[ 599.40098335]
#  [ -46.69036538]
#  [3424.73805944]]
# used_time:0.046 sec
# t0:0.2801757571006072, t1:-0.7867481321805541
# pitch:2.799477270398284, yaw:-0.5823957191427476, roll:0.07312405519336337
# Y:160, X:-33, Z:4
# ERROR: found no face
# get_image_points failed
# ERROR: found no face
# get_image_points failed
# ERROR: found no face
# get_image_points failed
# ERROR: found no face
# get_image_points failed
# ERROR: found no face
# get_image_points failed
# ERROR: found no face
# get_image_points failed
# ERROR: found no face
# get_image_points failed
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[-3.26703002]
#  [-0.07270615]
#  [-1.05693112]]
# Translation Vector:
#  [[ 594.44381976]
#  [ -58.35824432]
#  [3322.29449836]]
# used_time:0.045 sec
# t0:0.28741975877998155, t1:-0.77203301475392
# pitch:2.7852004569727464, yaw:-0.6027156840884625, roll:0.1563480120814033
# Y:159, X:-34, Z:8
# ERROR: found no face
# get_image_points failed
# ERROR: found no face
# get_image_points failed
# ERROR: found no face
# get_image_points failed
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[-3.22070645]
#  [-0.06447096]
#  [-1.08799208]]
# Translation Vector:
#  [[ 563.38758424]
#  [ -49.12029911]
#  [3120.75206846]]
# used_time:0.046 sec
# t0:0.2541021607276515, t1:-0.7653873901954285
# pitch:2.8210501725978734, yaw:-0.6326473931396664, roll:0.14575716134987868
# Y:161, X:-36, Z:8
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[-3.244378  ]
#  [-0.10103967]
#  [-1.08432347]]
# Translation Vector:
#  [[ 561.26852789]
#  [ -44.6851646 ]
#  [3102.06985157]]
# used_time:0.047 sec
# t0:0.2809533354964682, t1:-0.7640166142034295
# pitch:2.7892091292238734, yaw:-0.6197271623573787, roll:0.17614994599645592
# Y:159, X:-35, Z:10
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[-3.19924169]
#  [-0.07276501]
#  [-1.05009862]]
# Translation Vector:
#  [[ 561.76691617]
#  [ -40.53531955]
#  [3119.23610908]]
# used_time:0.045 sec
# t0:0.22649572901394183, t1:-0.7825414132002892
# pitch:2.8598554717373834, yaw:-0.6186531521608437, roll:0.1360584503694592
# Y:163, X:-35, Z:7
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[-3.26847404]
#  [-0.10448584]
#  [-1.02834777]]
# Translation Vector:
#  [[ 554.23667164]
#  [ -41.54464221]
#  [3077.33403128]]
# used_time:0.048 sec
# t0:0.28729420678898926, t1:-0.7829455895631345
# pitch:2.7899067693452673, yaw:-0.5844938745194279, roll:0.17072506750910474
# Y:159, X:-33, Z:9
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[-3.26847404]
#  [-0.10448584]
#  [-1.02834777]]
# Translation Vector:
#  [[ 554.23667164]
#  [ -41.54464221]
#  [3077.33403128]]
# used_time:0.05 sec
# t0:0.28729420678898926, t1:-0.7829455895631345
# pitch:2.7899067693452673, yaw:-0.5844938745194279, roll:0.17072506750910474
# Y:159, X:-33, Z:9
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[-3.23139369]
#  [-0.09502269]
#  [-1.09676362]]
# Translation Vector:
#  [[ 559.7446885 ]
#  [ -40.82627003]
#  [3093.36169174]]
# used_time:0.047 sec
# t0:0.2720236551806694, t1:-0.7605505468527991
# pitch:2.79810414631946, yaw:-0.6304982458410482, roll:0.1718095606456085
# Y:160, X:-36, Z:9
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[-3.21764605]
#  [-0.08422849]
#  [-1.07314614]]
# Translation Vector:
#  [[ 561.48887455]
#  [ -40.04898448]
#  [3106.158375  ]]
# used_time:0.046 sec
# t0:0.2513093059529183, t1:-0.7716463381506844
# pitch:2.8267463954798924, yaw:-0.6240162506507656, roll:0.1546515928155004
# Y:161, X:-35, Z:8
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[-3.26876394]
#  [-0.12283882]
#  [-1.03867825]]
# Translation Vector:
#  [[ 555.80315207]
#  [ -38.52361268]
#  [3051.20537577]]
# used_time:0.047 sec
# t0:0.29395048433370957, t1:-0.7787713260359639
# pitch:2.78067212033035, yaw:-0.5873697989074536, roll:0.18536587406220364
# Y:159, X:-33, Z:10
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[-3.25494108]
#  [-0.11888985]
#  [-1.08381462]]
# Translation Vector:
#  [[ 557.6050539 ]
#  [ -37.3344031 ]
#  [3073.23253674]]
# used_time:0.046 sec
# t0:0.29356098164727173, t1:-0.7627468802150839
# pitch:2.7741940771993643, yaw:-0.6141063479641931, roll:0.19070700735129703
# Y:158, X:-35, Z:10
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[ 0.01028281]
#  [-2.12175281]
#  [-0.33481954]]
# Translation Vector:
#  [[ -560.97085535]
#  [   35.41605201]
#  [-3102.07169936]]
# used_time:0.054 sec
# t0:0.24199769701658133, t1:-0.5081552405328043
# pitch:2.69714294756221, yaw:-0.9729831753417639, roll:-2.894015695541686
# Y:154, X:-55, Z:-165
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[-3.25206115]
#  [-0.12851693]
#  [-1.11703251]]
# Translation Vector:
#  [[ 557.57523515]
#  [ -36.18916267]
#  [3060.68867913]]
# used_time:0.049 sec
# t0:0.3024326192845091, t1:-0.7494440274044523
# pitch:2.7580360145231695, yaw:-0.6297653562205539, roll:0.20531431566775435
# Y:158, X:-36, Z:11
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[-3.25206115]
#  [-0.12851693]
#  [-1.11703251]]
# Translation Vector:
#  [[ 557.57523515]
#  [ -36.18916267]
#  [3060.68867913]]
# used_time:0.046 sec
# t0:0.3024326192845091, t1:-0.7494440274044523
# pitch:2.7580360145231695, yaw:-0.6297653562205539, roll:0.20531431566775435
# Y:158, X:-36, Z:11
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[-0.29574686]
#  [47.40445105]
#  [ 8.24631822]]
# Translation Vector:
#  [[ -573.51723937]
#  [   36.08117989]
#  [-3202.38754239]]
# used_time:0.047 sec
# t0:0.2661549022975507, t1:-0.5004612738082803
# pitch:2.652814910562814, yaw:-0.9681395178879916, roll:-2.8683642780727823
# Y:151, X:-55, Z:-164
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[0.00486703]
#  [4.01021368]
#  [0.7086248 ]]
# Translation Vector:
#  [[ -595.60843355]
#  [   44.49829115]
#  [-3392.3070692 ]]
# used_time:0.047 sec
# t0:0.2727338352858765, t1:-0.5488686098593987
# pitch:2.680426623673757, yaw:-0.9110769025042676, roll:-2.9150078497195255
# Y:153, X:-52, Z:-167
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[-0.01601529]
#  [-2.25165218]
#  [-0.43031013]]
# Translation Vector:
#  [[ -609.3841062 ]
#  [   50.49283248]
#  [-3595.13132829]]
# used_time:0.046 sec
# t0:0.3009193119133683, t1:-0.6021220045852484
# pitch:2.6781333170184265, yaw:-0.8323638561221858, roll:-2.947972633607065
# Y:153, X:-47, Z:-168
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[-3.35403143]
#  [-0.07219917]
#  [-0.91783217]]
# Translation Vector:
#  [[ 578.99982421]
#  [ -39.93284535]
#  [3531.53747328]]
# used_time:0.045 sec
# t0:0.32905961851443427, t1:-0.8085454102833269
# pitch:2.7550858817097397, yaw:-0.5095974427629327, roll:0.14489910616477808
# Y:157, X:-29, Z:8
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[-3.38456921]
#  [-0.08879718]
#  [-0.70860811]]
# Translation Vector:
#  [[ 537.2066431 ]
#  [ -24.03160188]
#  [3528.53813748]]
# used_time:0.053 sec
# t0:0.3157208270762704, t1:-0.8681863126794844
# pitch:2.7928046474844326, yaw:-0.3928776316475708, roll:0.12255398404874454
# Y:160, X:-22, Z:7
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[-3.36254144]
#  [-0.07391887]
#  [-0.63766372]]
# Translation Vector:
#  [[ 503.04368525]
#  [  -7.14677381]
#  [3538.13664034]]
# used_time:0.058 sec
# t0:0.28092036907201084, t1:-0.8925629477417585
# pitch:2.8366733648490428, yaw:-0.360481995613256, roll:0.09994083867687788
# Y:162, X:-20, Z:5
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[-3.36254144]
#  [-0.07391887]
#  [-0.63766372]]
# Translation Vector:
#  [[ 503.04368525]
#  [  -7.14677381]
#  [3538.13664034]]
# used_time:0.045 sec
# t0:0.28092036907201084, t1:-0.8925629477417585
# pitch:2.8366733648490428, yaw:-0.360481995613256, roll:0.09994083867687788
# Y:162, X:-20, Z:5
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[-3.36680455]
#  [-0.02543716]
#  [-0.49790143]]
# Translation Vector:
#  [[ 450.62761676]
#  [   4.34385012]
#  [3465.71149968]]
# used_time:0.047 sec
# t0:0.25829576525259523, t1:-0.9238217734110981
# pitch:2.8689597305750936, yaw:-0.2864553142679634, roll:0.05466827888000373
# Y:164, X:-16, Z:3
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[-3.36000308]
#  [ 0.0140735 ]
#  [-0.34559268]]
# Translation Vector:
#  [[ 415.10658858]
#  [  14.67712406]
#  [3508.03496163]]
# used_time:0.048 sec
# t0:0.23190604155304217, t1:-0.951596381335502
# pitch:2.9025501476591677, yaw:-0.20309587825753747, roll:0.016096465657995124
# Y:166, X:-11, Z:0
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[-3.34943041]
#  [ 0.03533007]
#  [-0.22406603]]
# Translation Vector:
#  [[ 379.24303362]
#  [  24.64087102]
#  [3464.65985176]]
# used_time:0.047 sec
# t0:0.21196832181890046, t1:-0.9680610312478077
# pitch:2.926032898144324, yaw:-0.1342960742982509, roll:-0.00654303834352674
# Y:167, X:-7, Z:0
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[-3.31988795]
#  [ 0.07059313]
#  [-0.11762269]]
# Translation Vector:
#  [[ 363.10802463]
#  [  31.30605902]
#  [3519.89242692]]
# used_time:0.05 sec
# t0:0.1784940744300436, t1:-0.9811553173247658
# pitch:2.9616383273700593, yaw:-0.07405488887098441, roll:-0.03583668845956361
# Y:169, X:-4, Z:-2
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[-3.31988795]
#  [ 0.07059313]
#  [-0.11762269]]
# Translation Vector:
#  [[ 363.10802463]
#  [  31.30605902]
#  [3519.89242692]]
# used_time:0.047 sec
# t0:0.1784940744300436, t1:-0.9811553173247658
# pitch:2.9616383273700593, yaw:-0.07405488887098441, roll:-0.03583668845956361
# Y:169, X:-4, Z:-2
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[-3.31277415]
#  [ 0.07634349]
#  [-0.11795346]]
# Translation Vector:
#  [[ 351.70335553]
#  [  34.87581658]
#  [3490.45280302]]
# used_time:0.045 sec
# t0:0.171499261299473, t1:-0.9823606611344622
# pitch:2.9687557834634655, yaw:-0.07460464737798303, roll:-0.03961591757278888
# Y:170, X:-4, Z:-2
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[-3.30686963]
#  [ 0.09301436]
#  [-0.10331869]]
# Translation Vector:
#  [[ 349.55159226]
#  [  36.45646918]
#  [3491.94631712]]
# used_time:0.045 sec
# t0:0.16551603222823244, t1:-0.983952921665358
# pitch:2.9749374820366, yaw:-0.0666909369264233, roll:-0.050668260335078256
# Y:170, X:-3, Z:-2
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[-3.33045548]
#  [ 0.09842425]
#  [-0.17431635]]
# Translation Vector:
#  [[ 353.02841702]
#  [  35.31010821]
#  [3481.22403649]]
# used_time:0.047 sec
# t0:0.19024041212809747, t1:-0.9756645680492793
# pitch:2.9490233761113442, yaw:-0.10924577473479298, roll:-0.048526655511975395
# Y:168, X:-6, Z:-2
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[-3.31675782]
#  [ 0.09523952]
#  [-0.14578261]]
# Translation Vector:
#  [[ 349.55720944]
#  [  39.84402677]
#  [3459.05545307]]
# used_time:0.048 sec
# t0:0.17602423148767624, t1:-0.9800692811261167
# pitch:2.9638834442423354, yaw:-0.0922157871738117, roll:-0.049192300357711036
# Y:169, X:-5, Z:-2
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[ 2.96104434]
#  [-0.08768121]
#  [ 0.15186858]]
# Translation Vector:
#  [[ 349.36310046]
#  [  44.33382667]
#  [3442.90282597]]
# used_time:0.052 sec
# t0:0.1711538998474257, t1:-0.9794612769822357
# pitch:2.968596462393827, yaw:-0.10679533433163126, roll:-0.04993641811327792
# Y:170, X:-6, Z:-2
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[ 2.97038883]
#  [-0.05839619]
#  [ 0.15672595]]
# Translation Vector:
#  [[ 350.79708416]
#  [  53.26439343]
#  [3489.81118811]]
# used_time:0.046 sec
# t0:0.16341486014760218, t1:-0.9806592057372596
# pitch:2.976472094985317, yaw:-0.10792711820429132, roll:-0.030374405659529518
# Y:170, X:-6, Z:-1
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[ 2.97556736]
#  [-0.04074325]
#  [ 0.13619278]]
# Translation Vector:
#  [[ 348.23934369]
#  [  62.76761123]
#  [3508.74502452]]
# used_time:0.047 sec
# t0:0.1604887408833966, t1:-0.9826518922646275
# pitch:2.979699933009751, yaw:-0.09307853239616075, roll:-0.019827198216905595
# Y:170, X:-5, Z:-1
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[ 2.97556736]
#  [-0.04074325]
#  [ 0.13619278]]
# Translation Vector:
#  [[ 348.23934369]
#  [  62.76761123]
#  [3508.74502452]]
# used_time:0.046 sec
# t0:0.1604887408833966, t1:-0.9826518922646275
# pitch:2.979699933009751, yaw:-0.09307853239616075, roll:-0.019827198216905595
# Y:170, X:-5, Z:-1
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[ 2.99557629]
#  [-0.02927478]
#  [ 0.08046439]]
# Translation Vector:
#  [[ 335.86215331]
#  [  62.94812499]
#  [3489.25461302]]
# used_time:0.046 sec
# t0:0.1437067466592469, t1:-0.9881014980238589
# pitch:2.9971680301466685, yaw:-0.054834414386958914, roll:-0.01557711424595847
# Y:171, X:-3, Z:0
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[ 3.02473653]
#  [-0.00749817]
#  [ 0.07302535]]
# Translation Vector:
#  [[ 321.81393907]
#  [  64.69640766]
#  [3431.02826228]]
# used_time:0.045 sec
# t0:0.11555241384195612, t1:-0.992122397638026
# pitch:3.0256451382168916, yaw:-0.048400583394960256, roll:-0.0021482294687964754
# Y:173, X:-2, Z:0
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[ 3.02590192]
#  [-0.01943931]
#  [ 0.04200686]]
# Translation Vector:
#  [[ 315.14066237]
#  [  65.67927703]
#  [3456.26736972]]
# used_time:0.084 sec
# t0:0.1148899903131306, t1:-0.9929720161437043
# pitch:3.0264017099132716, yaw:-0.028409195435942263, roll:-0.01121026735938432
# Y:173, X:-1, Z:0
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[ 3.02590192]
#  [-0.01943931]
#  [ 0.04200686]]
# Translation Vector:
#  [[ 315.14066237]
#  [  65.67927703]
#  [3456.26736972]]
# used_time:0.046 sec
# t0:0.1148899903131306, t1:-0.9929720161437043
# pitch:3.0264017099132716, yaw:-0.028409195435942263, roll:-0.01121026735938432
# Y:173, X:-1, Z:0
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[ 3.02243964]
#  [-0.02316213]
#  [ 0.0407503 ]]
# Translation Vector:
#  [[ 308.77346127]
#  [  66.00416542]
#  [3449.55023675]]
# used_time:0.045 sec
# t0:0.11829028767922936, t1:-0.9925906186160913
# pitch:3.022978783421174, yaw:-0.027775349581264208, roll:-0.013677168278340378
# Y:173, X:-1, Z:0
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[-3.25925760e+00]
#  [ 2.77607236e-02]
#  [ 1.92609338e-03]]
# Translation Vector:
#  [[ 301.02675056]
#  [  66.28381106]
#  [3479.43541269]]
# used_time:0.079 sec
# t0:0.11751733976383126, t1:-0.9930708149829162
# pitch:3.0238031249002035, yaw:0.00017687283132233596, roll:-0.017045015158420128
# Y:173, X:0, Z:0
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[-3.25925760e+00]
#  [ 2.77607236e-02]
#  [ 1.92609338e-03]]
# Translation Vector:
#  [[ 301.02675056]
#  [  66.28381106]
#  [3479.43541269]]
# used_time:0.045 sec
# t0:0.11751733976383126, t1:-0.9930708149829162
# pitch:3.0238031249002035, yaw:0.00017687283132233596, roll:-0.017045015158420128
# Y:173, X:0, Z:0
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[-3.25229483]
#  [ 0.01591809]
#  [-0.10130184]]
# Translation Vector:
#  [[ 296.52808885]
#  [  68.192868  ]
#  [3466.63294942]]
# used_time:0.062 sec
# t0:0.1117230738908086, t1:-0.9917665809372209
# pitch:3.0294150022593884, yaw:-0.06262690087802585, roll:-0.006271254355317286
# Y:173, X:-3, Z:0
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[-3.25229483]
#  [ 0.01591809]
#  [-0.10130184]]
# Translation Vector:
#  [[ 296.52808885]
#  [  68.192868  ]
#  [3466.63294942]]
# used_time:0.048 sec
# t0:0.1117230738908086, t1:-0.9917665809372209
# pitch:3.0294150022593884, yaw:-0.06262690087802585, roll:-0.006271254355317286
# Y:173, X:-3, Z:0
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[-3.25487026]
#  [ 0.0218046 ]
#  [-0.12563685]]
# Translation Vector:
#  [[ 292.82142231]
#  [  67.67420803]
#  [3462.51473397]]
# used_time:0.046 sec
# t0:0.1149128053845867, t1:-0.9903402800145558
# pitch:3.0260755805167867, yaw:-0.07767432494381654, roll:-0.008904332361058248
# Y:173, X:-4, Z:0
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[-3.26104464]
#  [ 0.0383997 ]
#  [-0.09346392]]
# Translation Vector:
#  [[ 284.16829831]
#  [  65.89766472]
#  [3479.4010874 ]]
# used_time:0.1 sec
# t0:0.11999212627748845, t1:-0.9910510696627404
# pitch:3.0211035083798388, yaw:-0.05851129905782111, roll:-0.02001920198269982
# Y:173, X:-3, Z:-1
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[-3.26104464]
#  [ 0.0383997 ]
#  [-0.09346392]]
# Translation Vector:
#  [[ 284.16829831]
#  [  65.89766472]
#  [3479.4010874 ]]
# used_time:0.048 sec
# t0:0.11999212627748845, t1:-0.9910510696627404
# pitch:3.0211035083798388, yaw:-0.05851129905782111, roll:-0.02001920198269982
# Y:173, X:-3, Z:-1
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[-3.28192462]
#  [ 0.04533991]
#  [-0.08769628]]
# Translation Vector:
#  [[ 282.42495731]
#  [  64.65934261]
#  [3502.92174124]]
# used_time:0.047 sec
# t0:0.1405437589716321, t1:-0.9885413144855502
# pitch:3.000366247381508, yaw:-0.055105297014078826, roll:-0.023729693676042957
# Y:171, X:-3, Z:-1
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[-3.26270371]
#  [ 0.03974922]
#  [-0.15877665]]
# Translation Vector:
#  [[ 287.08661591]
#  [  63.04276051]
#  [3490.99717239]]
# used_time:0.048 sec
# t0:0.12355204532943108, t1:-0.9874649559167448
# pitch:3.0171190781510107, yaw:-0.09838211524739089, roll:-0.01822877643489747
# Y:172, X:-5, Z:-1
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[-3.28327743]
#  [ 0.03483108]
#  [-0.22617822]]
# Translation Vector:
#  [[ 293.71035447]
#  [  56.4284194 ]
#  [3478.62326681]]
# used_time:0.048 sec
# t0:0.14728514037011098, t1:-0.9794308412343129
# pitch:2.9923327554733743, yaw:-0.13836245757207496, roll:-0.010854828540539653
# Y:171, X:-7, Z:0
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[-3.25535409]
#  [ 0.02275428]
#  [-0.33575154]]
# Translation Vector:
#  [[ 298.23524089]
#  [  58.86831286]
#  [3468.57702414]]
# used_time:0.048 sec
# t0:0.12862040817256817, t1:-0.9704577793054554
# pitch:3.009824795479439, yaw:-0.20557349137470313, roll:-0.0003679939359825929
# Y:172, X:-11, Z:0
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[-3.24046147]
#  [ 0.04639823]
#  [-0.48587037]]
# Translation Vector:
#  [[ 299.70615552]
#  [  56.43560904]
#  [3470.61105475]]
# used_time:0.047 sec
# t0:0.1293215484644595, t1:-0.9470801920131884
# pitch:3.005884316766506, yaw:-0.2981938301492129, roll:-0.008219245560906625
# Y:172, X:-17, Z:0
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[-3.26447561]
#  [ 0.0423473 ]
#  [-0.4810575 ]]
# Translation Vector:
#  [[ 283.50951286]
#  [  51.9789015 ]
#  [3486.65725999]]
# used_time:0.046 sec
# t0:0.1523311675768762, t1:-0.9452449210452756
# pitch:2.9818111954666997, yaw:-0.2927955902100297, roll:-0.0023334990410474855
# Y:170, X:-16, Z:0
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[-3.25061954]
#  [ 0.05525262]
#  [-0.43880216]]
# Translation Vector:
#  [[ 253.01806427]
#  [  54.18960286]
#  [3498.25927148]]
# used_time:0.049 sec
# t0:0.13278006395298664, t1:-0.954748540555195
# pitch:3.0034056786833285, yaw:-0.26937503795820533, roll:-0.01523712278832921
# Y:172, X:-15, Z:0
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[-3.25061954]
#  [ 0.05525262]
#  [-0.43880216]]
# Translation Vector:
#  [[ 253.01806427]
#  [  54.18960286]
#  [3498.25927148]]
# used_time:0.046 sec
# t0:0.13278006395298664, t1:-0.954748540555195
# pitch:3.0034056786833285, yaw:-0.26937503795820533, roll:-0.01523712278832921
# Y:172, X:-15, Z:0
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[-3.27744435]
#  [ 0.07801827]
#  [-0.412162  ]]
# Translation Vector:
#  [[ 226.52664802]
#  [  54.91028855]
#  [3508.40484206]]
# used_time:0.047 sec
# t0:0.15471038457187694, t1:-0.9558970474110298
# pitch:2.981135674382079, yaw:-0.2523196398106558, roll:-0.027205839825148976
# Y:170, X:-14, Z:-1
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[-3.26054917]
#  [ 0.08082623]
#  [-0.39748856]]
# Translation Vector:
#  [[ 195.17411947]
#  [  60.27065362]
#  [3529.83703502]]
# used_time:0.049 sec
# t0:0.13657252706456094, t1:-0.9605182832649892
# pitch:3.0003531006368642, yaw:-0.24482783674632347, roll:-0.03216306399765176
# Y:171, X:-14, Z:-1
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[-3.28406818]
#  [ 0.10079319]
#  [-0.26723846]]
# Translation Vector:
#  [[ 163.66086958]
#  [  61.50317284]
#  [3565.30521847]]
# used_time:0.047 sec
# t0:0.14874575815850338, t1:-0.9749658294358556
# pitch:2.9901950007363745, yaw:-0.16603838924769282, roll:-0.04874204787338085
# Y:171, X:-9, Z:-2
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[-3.30837181]
#  [ 0.11048736]
#  [-0.21252475]]
# Translation Vector:
#  [[ 146.05134986]
#  [  63.83219849]
#  [3578.26424525]]
# used_time:0.045 sec
# t0:0.16984911201514644, t1:-0.9765029168573753
# pitch:2.9693794565207225, yaw:-0.13303190152995123, roll:-0.05526761799512256
# Y:170, X:-7, Z:-3
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[-3.29425773]
#  [ 0.11664813]
#  [-0.22326516]]
# Translation Vector:
#  [[ 135.18520437]
#  [  67.94805505]
#  [3578.14922561]]
# used_time:0.053 sec
# t0:0.15635995304446754, t1:-0.9777879017708211
# pitch:2.9830232617333263, yaw:-0.1400365547286109, roll:-0.05964531016178574
# Y:170, X:-8, Z:-3
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[-3.29425773]
#  [ 0.11664813]
#  [-0.22326516]]
# Translation Vector:
#  [[ 135.18520437]
#  [  67.94805505]
#  [3578.14922561]]
# used_time:0.046 sec
# t0:0.15635995304446754, t1:-0.9777879017708211
# pitch:2.9830232617333263, yaw:-0.1400365547286109, roll:-0.05964531016178574
# Y:170, X:-8, Z:-3
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[-3.3100137 ]
#  [ 0.13831669]
#  [-0.19593464]]
# Translation Vector:
#  [[ 127.45964117]
#  [  66.20060556]
#  [3594.88318989]]
# used_time:0.047 sec
# t0:0.17083094515741976, t1:-0.9774421026266726
# pitch:2.9685667970767176, yaw:-0.12451377479977636, roll:-0.07271322268587038
# Y:170, X:-7, Z:-4
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[-3.32324508]
#  [ 0.13061602]
#  [-0.18678019]]
# Translation Vector:
#  [[ 124.73707696]
#  [  62.79782377]
#  [3612.70149852]]
# used_time:0.05 sec
# t0:0.18352821915226875, t1:-0.9758742832878116
# ...
# pitch:2.9950051962594526, yaw:-0.13923272312776466, roll:-0.07211258628810976
# Y:171, X:-7, Z:-4
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[-3.29099289]
#  [ 0.13511635]
#  [-0.17075964]]
# Translation Vector:
#  [[ 130.44669255]
#  [  73.36582608]
#  [3603.12793663]]
# used_time:0.047 sec
# t0:0.15140060930059127, t1:-0.9824356105703722
# pitch:2.9886881178181732, yaw:-0.10929600546681574, roll:-0.07368618931536106
# Y:171, X:-6, Z:-4
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[-3.30731383]
#  [ 0.14423056]
#  [-0.10868089]]
# Translation Vector:
#  [[ 125.36410982]
#  [  70.35289737]
#  [3632.54401751]]
# used_time:0.045 sec
# t0:0.16673163861274992, t1:-0.9833373120847808
# pitch:2.9736331698633127, yaw:-0.07250861090242315, roll:-0.08105766190327925
# Y:170, X:-4, Z:-4
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[-3.32753249]
#  [ 0.14755902]
#  [-0.14347638]]
# Translation Vector:
#  [[ 124.94786026]
#  [  71.02928045]
#  [3656.59388136]]
# used_time:0.051 sec
# t0:0.18697677574355026, t1:-0.9778975031780057
# pitch:2.9526700372409866, yaw:-0.09371144757642978, roll:-0.07974671400004744
# Y:169, X:-5, Z:-4
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[-3.32753249]
#  [ 0.14755902]
#  [-0.14347638]]
# Translation Vector:
#  [[ 124.94786026]
#  [  71.02928045]
#  [3656.59388136]]
# used_time:0.045 sec
# t0:0.18697677574355026, t1:-0.9778975031780057
# pitch:2.9526700372409866, yaw:-0.09371144757642978, roll:-0.07974671400004744
# Y:169, X:-5, Z:-4
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[-3.31636929]
#  [ 0.13914847]
#  [-0.17856951]]
# Translation Vector:
#  [[ 125.07699811]
#  [  76.7514866 ]
#  [3706.89503757]]
# used_time:0.046 sec
# t0:0.17660157942763643, t1:-0.977670338445962
# pitch:2.9628846149324204, yaw:-0.11414499064404747, roll:-0.07362938060306608
# Y:169, X:-6, Z:-4
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[-3.32273493]
#  [ 0.14261725]
#  [-0.2475312 ]]
# Translation Vector:
#  [[ 121.24357176]
#  [  75.3698995 ]
#  [3651.87798125]]
# used_time:0.048 sec
# t0:0.18520168232747622, t1:-0.9704411361745815
# pitch:2.9530174191705476, yaw:-0.1553638544959183, roll:-0.07106882313828662
# Y:169, X:-8, Z:-4
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[-3.3018433 ]
#  [ 0.1438584 ]
#  [-0.30100424]]
# Translation Vector:
#  [[ 117.11420969]
#  [  91.43556807]
#  [3630.03760489]]
# used_time:0.047 sec
# t0:0.1674439164931753, t1:-0.9680408447942794
# pitch:2.9703154450966838, yaw:-0.18780900421287272, roll:-0.07091281796831796
# Y:170, X:-10, Z:-4
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[-3.29729591]
#  [ 0.16695024]
#  [-0.27953813]]
# Translation Vector:
#  [[  96.62442238]
#  [ 107.14717533]
#  [3624.05050129]]
# used_time:0.046 sec
# t0:0.16163039577799357, t1:-0.9711577814155525
# pitch:2.976673647882494, yaw:-0.17620494127473443, roll:-0.08657820727609963
# Y:170, X:-10, Z:-4
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[-3.27772324]
#  [ 0.20237584]
#  [-0.35430704]]
# Translation Vector:
#  [[  80.77478018]
#  [ 106.34831877]
#  [3633.28479515]]
# used_time:0.045 sec
# t0:0.1464396457954665, t1:-0.9641353984987906
# pitch:2.9908577293306946, yaw:-0.2232044785484386, roll:-0.10640485933665488
# Y:171, X:-12, Z:-6
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[-3.26269769]
#  [ 0.24103498]
#  [-0.49964984]]
# Translation Vector:
#  [[  72.30113206]
#  [  95.82375126]
#  [3643.58594391]]
# used_time:0.068 sec
# t0:0.14294122865149841, t1:-0.9406674891032631
# pitch:2.9907890936311023, yaw:-0.3128314846287178, roll:-0.12365767436202313
# Y:171, X:-17, Z:-7
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[-3.2502894 ]
#  [ 0.269073  ]
#  [-0.58437585]]
# Translation Vector:
#  [[  65.12168324]
#  [  90.27413356]
#  [3624.68279667]]
# used_time:0.046 sec
# t0:0.13922473564228033, t1:-0.9235310396971885
# pitch:2.991966716244678, yaw:-0.365440787994086, roll:-0.13749394665279308
# Y:171, X:-20, Z:-7
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[-3.2502894 ]
#  [ 0.269073  ]
#  [-0.58437585]]
# Translation Vector:
#  [[  65.12168324]
#  [  90.27413356]
#  [3624.68279667]]
# used_time:0.046 sec
# t0:0.13922473564228033, t1:-0.9235310396971885
# pitch:2.991966716244678, yaw:-0.365440787994086, roll:-0.13749394665279308
# Y:171, X:-20, Z:-7
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[-3.23236115]
#  [ 0.2727749 ]
#  [-0.67500264]]
# Translation Vector:
#  [[  63.36612574]
#  [  88.5096145 ]
#  [3638.43664732]]
# used_time:0.046 sec
# t0:0.13342656346865708, t1:-0.902892848474177
# pitch:2.9948777474527626, yaw:-0.4209570468282585, roll:-0.1369801998289329
# Y:171, X:-24, Z:-7
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[-3.28575283]
#  [ 0.30497744]
#  [-0.68773447]]
# Translation Vector:
#  [[  50.50558293]
#  [  83.32571283]
#  [3645.68038244]]
# used_time:0.047 sec
# t0:0.18501902172601964, t1:-0.8916846665520222
# pitch:2.937002029607661, yaw:-0.4258751523848801, roll:-0.14072259775302098
# Y:168, X:-24, Z:-8
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[-3.23904096]
#  [ 0.31884502]
#  [-0.82552759]]
# Translation Vector:
#  [[  46.01047597]
#  [  82.2330324 ]
#  [3654.72980543]]
# used_time:0.048 sec
# t0:0.16075451525404513, t1:-0.857242623644624
# pitch:2.956220448797569, yaw:-0.5111446445349491, roll:-0.14767914287588263
# Y:169, X:-29, Z:-8
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[-3.21416047]
#  [ 0.32949941]
#  [-0.95106657]]
# Translation Vector:
#  [[  36.94968362]
#  [  82.41671526]
#  [3672.16031037]]
# used_time:0.058 sec
# t0:0.1597444874026854, t1:-0.8170252529777711
# pitch:2.9485088157239328, yaw:-0.5871997222477485, roll:-0.14577430997835553
# Y:168, X:-33, Z:-8
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[-3.21416047]
#  [ 0.32949941]
#  [-0.95106657]]
# Translation Vector:
#  [[  36.94968362]
#  [  82.41671526]
#  [3672.16031037]]
# used_time:0.046 sec
# t0:0.1597444874026854, t1:-0.8170252529777711
# pitch:2.9485088157239328, yaw:-0.5871997222477485, roll:-0.14577430997835553
# Y:168, X:-33, Z:-8
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[-3.18847279]
#  [ 0.35571418]
#  [-1.04350048]]
# Translation Vector:
#  [[  29.59798186]
#  [  83.30985817]
#  [3651.76129291]]
# used_time:0.046 sec
# t0:0.1530405812244124, t1:-0.7844117419640155
# pitch:2.948910768721681, yaw:-0.6448305943794989, roll:-0.15765916290254742
# Y:168, X:-36, Z:-9
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[-3.19286791]
#  [ 0.34298393]
#  [-1.01087853]]
# Translation Vector:
#  [[  17.06206482]
#  [  90.70825457]
#  [3667.62163469]]
# used_time:0.046 sec
# t0:0.15117920823654368, t1:-0.7967458766745206
# pitch:2.9540760319767387, yaw:-0.6250021456568037, roll:-0.1532793461869388
# Y:169, X:-35, Z:-8
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[-3.2070708 ]
#  [ 0.36377935]
#  [-0.88372874]]
# Translation Vector:
#  [[-1.21811029e+00]
#  [ 1.00337010e+02]
#  [ 3.70253028e+03]]
# used_time:0.046 sec
# t0:0.13812548393816637, t1:-0.8410740964898389
# pitch:2.978820483680239, yaw:-0.5503520162039351, roll:-0.17984482128880783
# Y:170, X:-31, Z:-10
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[-3.20158135]
#  [ 0.3569358 ]
#  [-0.96996126]]
# Translation Vector:
#  [[-1.24258668e+00]
#  [ 1.00181531e+02]
#  [ 3.69829227e+03]]
# used_time:0.045 sec
# t0:0.1497450314439694, t1:-0.8111131867595915
# pitch:2.9590315384700854, yaw:-0.6009124079527919, roll:-0.16535123753678038
# Y:169, X:-34, Z:-9
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[-3.23063788]
#  [ 0.36077506]
#  [-0.94759354]]
# Translation Vector:
#  [[-2.23098633e-02]
#  [ 9.57215265e+01]
#  [ 3.66197537e+03]]
# used_time:0.059 sec
# t0:0.17214323684323862, t1:-0.8159670764444693
# pitch:2.933673180113008, yaw:-0.584609252184628, roll:-0.1596506704618879
# Y:168, X:-33, Z:-9
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[-3.1791603 ]
#  [ 0.33838397]
#  [-0.94606904]]
# Translation Vector:
#  [[3.38251961e-01]
#  [1.01455922e+02]
#  [3.70545965e+03]]
# used_time:0.045 sec
# t0:0.1254174290512102, t1:-0.821975983130582
# pitch:2.9901800420328306, yaw:-0.5890136259512984, roll:-0.16607039066462428
# Y:171, X:-33, Z:-9
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[-3.24181034]
#  [ 0.31852961]
#  [-0.90483427]]
# Translation Vector:
#  [[-1.87113616e+00]
#  [ 1.00834653e+02]
#  [ 3.70765642e+03]]
# used_time:0.054 sec
# t0:0.1774391957692637, t1:-0.8303101277347109
# pitch:2.9310571744222957, yaw:-0.5565965758846403, roll:-0.1355271156695221
# Y:167, X:-31, Z:-7
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[-3.24181034]
#  [ 0.31852961]
#  [-0.90483427]]
# Translation Vector:
#  [[-1.87113616e+00]
#  [ 1.00834653e+02]
#  [ 3.70765642e+03]]
# used_time:0.047 sec
# t0:0.1774391957692637, t1:-0.8303101277347109
# pitch:2.9310571744222957, yaw:-0.5565965758846403, roll:-0.1355271156695221
# Y:167, X:-31, Z:-7
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[-3.23387668]
#  [ 0.31535662]
#  [-0.90427501]]
# Translation Vector:
#  [[   3.78091829]
#  [ 101.84198164]
#  [3672.24134122]]
# used_time:0.046 sec
# t0:0.17015696668870084, t1:-0.8315518187852093
# pitch:2.9397531794444784, yaw:-0.5571178427712864, roll:-0.13651284203241953
# Y:168, X:-31, Z:-7
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[-3.24813636]
#  [ 0.30905347]
#  [-0.84860013]]
# Translation Vector:
#  [[   4.10193464]
#  [ 102.65736417]
#  [3680.95336096]]
# used_time:0.047 sec
# t0:0.17387901943120637, t1:-0.8486709574545976
# pitch:2.9395054725686247, yaw:-0.5230486082921881, roll:-0.135463675066569
# Y:168, X:-29, Z:-7
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[-3.2674979 ]
#  [ 0.28891101]
#  [-0.7864015 ]]
# Translation Vector:
#  [[   5.62557353]
#  [ 104.03762961]
#  [3663.75552883]]
# used_time:0.046 sec
# t0:0.1829422459465897, t1:-0.8660495782395987
# pitch:2.933415415049505, yaw:-0.48395671892100545, roll:-0.12482447560683457
# Y:168, X:-27, Z:-7
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[-3.2569574 ]
#  [ 0.27130634]
#  [-0.79374609]]
# Translation Vector:
#  [[   6.87818744]
#  [ 108.55303411]
#  [3675.89541348]]
# used_time:0.046 sec
# t0:0.17528299046272516, t1:-0.8655005952084773
# pitch:2.941773186449806, yaw:-0.488428035647819, roll:-0.1162688364751128
# Y:168, X:-27, Z:-6
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[-3.28209039]
#  [ 0.2573438 ]
#  [-0.79640214]]
# Translation Vector:
#  [[  10.30734902]
#  [ 113.77123512]
#  [3722.10885344]]
# used_time:0.045 sec
# t0:0.2003402934051319, t1:-0.8610977997976696
# pitch:2.9130023796201714, yaw:-0.4862404661367459, roll:-0.09956761833118362
# Y:166, X:-27, Z:-5
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[-3.31071959]
#  [ 0.23271035]
#  [-0.73303882]]
# Translation Vector:
#  [[  10.3381956 ]
#  [ 114.89088227]
#  [3756.99211381]]
# used_time:0.06 sec
# t0:0.21880871606573, t1:-0.8755877361160005
# pitch:2.896708818926154, yaw:-0.44522500311633206, roll:-0.08465187294220035
# Y:165, X:-25, Z:-4
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[-3.31071959]
#  [ 0.23271035]
#  [-0.73303882]]
# Translation Vector:
#  [[  10.3381956 ]
#  [ 114.89088227]
#  [3756.99211381]]
# used_time:0.045 sec
# t0:0.21880871606573, t1:-0.8755877361160005
# pitch:2.896708818926154, yaw:-0.44522500311633206, roll:-0.08465187294220035
# Y:165, X:-25, Z:-4
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[-3.2980503 ]
#  [ 0.17547077]
#  [-0.65727343]]
# Translation Vector:
#  [[  32.30719144]
#  [ 114.11332837]
#  [3692.83261868]]
# used_time:0.062 sec
# t0:0.19927261304911828, t1:-0.8993707607626475
# pitch:2.9235463471631498, yaw:-0.39968766846136056, roll:-0.06197527819920668
# Y:167, X:-22, Z:-3
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[-3.2980503 ]
#  [ 0.17547077]
#  [-0.65727343]]
# Translation Vector:
#  [[  32.30719144]
#  [ 114.11332837]
#  [3692.83261868]]
# used_time:0.048 sec
# t0:0.19927261304911828, t1:-0.8993707607626475
# pitch:2.9235463471631498, yaw:-0.39968766846136056, roll:-0.06197527819920668
# Y:167, X:-22, Z:-3
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[-3.29690481]
#  [ 0.15644486]
#  [-0.63762043]]
# Translation Vector:
#  [[  44.86927198]
#  [ 119.92393755]
#  [3696.19748817]]
# used_time:0.047 sec
# t0:0.19663001726632034, t1:-0.9048012853935634
# pitch:2.927601533166324, yaw:-0.3873310270172374, roll:-0.05270957183253644
# Y:167, X:-22, Z:-3
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[-3.29582237]
#  [ 0.14911513]
#  [-0.61512921]]
# Translation Vector:
#  [[  54.94204302]
#  [ 121.04267843]
#  [3705.96803019]]
# used_time:0.047 sec
# t0:0.19289584583978514, t1:-0.910671611480024
# pitch:2.9328607190334073, yaw:-0.3739908107253364, roll:-0.05079354899126238
# Y:168, X:-21, Z:-2
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[-3.27485337]
#  [ 0.13443582]
#  [-0.61127146]]
# Translation Vector:
#  [[  66.359415  ]
#  [ 119.54114066]
#  [3672.6633849 ]]
# used_time:0.046 sec
# t0:0.17329538240261158, t1:-0.9149183128754046
# pitch:2.9543994681148003, yaw:-0.3731443296438516, roll:-0.04661997795365144
# Y:169, X:-21, Z:-2
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[-3.26961837]
#  [ 0.12381674]
#  [-0.63879517]]
# Translation Vector:
#  [[  75.02552673]
#  [ 117.42315739]
#  [3667.90711473]]
# used_time:0.051 sec
# t0:0.17318779771887322, t1:-0.9088399824579712
# pitch:2.953291069866344, yaw:-0.3892495749019018, roll:-0.03847778580438667
# Y:169, X:-22, Z:-2
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[-3.27209216]
#  [ 0.13303398]
#  [-0.65876037]]
# Translation Vector:
#  [[  83.38870291]
#  [ 122.49154672]
#  [3667.03431758]]
# used_time:0.046 sec
# t0:0.1779052660471339, t1:-0.903285763576827
# pitch:2.947128157803967, yaw:-0.4010832602822173, roll:-0.04162013995872509
# Y:168, X:-22, Z:-2
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[-3.26814435]
#  [ 0.11049873]
#  [-0.66022859]]
# Translation Vector:
#  [[  91.96981102]
#  [ 117.52923671]
#  [3653.23195557]]
# used_time:0.047 sec
# t0:0.17626599714766608, t1:-0.9035635917748506
# pitch:2.9489335748041188, yaw:-0.4011925715686553, roll:-0.028305835116103763
# Y:168, X:-22, Z:-1
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[-3.27351666]
#  [ 0.10261169]
#  [-0.64716852]]
# Translation Vector:
#  [[  98.48405215]
#  [ 112.17462276]
#  [3665.78480948]]
# used_time:0.045 sec
# t0:0.1799851628092437, t1:-0.9062535062924404
# pitch:2.945540194790092, yaw:-0.39250574125198073, roll:-0.023573597409025638
# Y:168, X:-22, Z:-1
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[-3.27870899]
#  [ 0.10103617]
#  [-0.64323506]]
# Translation Vector:
#  [[ 102.07915284]
#  [ 119.50815867]
#  [3664.13492801]]
# used_time:0.063 sec
# t0:0.1844488869990829, t1:-0.906528287506611
# pitch:2.9408653599261836, yaw:-0.38949046768526563, roll:-0.021891449898725407
# Y:168, X:-22, Z:-1
# Camera Matrix :[[640.   0. 320.]
#  [  0. 640. 240.]
#  [  0.   0.   1.]]
# Rotation Vector:
#  [[-3.27870899]
#  [ 0.10103617]
#  [-0.64323506]]
# Translation Vector:
#  [[ 102.07915284]
#  [ 119.50815867]
#  [3664.13492801]]
# used_time:0.045 sec
# t0:0.1844488869990829, t1:-0.906528287506611
# pitch:2.9408653599261836, yaw:-0.38949046768526563, roll:-0.021891449898725407
# Y:168, X:-22, Z:-1

# %%
# 参考https://github.com/lincolnhard/head-pose-estimation
import cv2
import dlib
import numpy as np
from imutils import face_utils
"""
思路：
    第一步：2D人脸关键点检测；第二步：3D人脸模型匹配；
    第三步：求解3D点和对应2D点的转换关系；第四步：根据旋转矩阵求解欧拉角。
"""

# 加载人脸检测和姿势估计模型（dlib）
face_landmark_path = 'D:/myworkspace/JupyterNotebook/fatigue_detecting/model/shape_predictor_68_face_landmarks.dat'

"""
只要知道世界坐标系内点的位置、像素坐标位置和相机参数就可以搞定旋转和平移矩阵(OpenCV自带函数solvePnp())
"""

# 世界坐标系(UVW)：填写3D参考点，该模型参考http://aifi.isr.uc.pt/Downloads/OpenGL/glAnthropometric3DModel.cpp
object_pts = np.float32([[6.825897, 6.760612, 4.402142],  #33左眉左上角
                         [1.330353, 7.122144, 6.903745],  #29左眉右角
                         [-1.330353, 7.122144, 6.903745], #34右眉左角
                         [-6.825897, 6.760612, 4.402142], #38右眉右上角
                         [5.311432, 5.485328, 3.987654],  #13左眼左上角
                         [1.789930, 5.393625, 4.413414],  #17左眼右上角
                         [-1.789930, 5.393625, 4.413414], #25右眼左上角
                         [-5.311432, 5.485328, 3.987654], #21右眼右上角
                         [2.005628, 1.409845, 6.165652],  #55鼻子左上角
                         [-2.005628, 1.409845, 6.165652], #49鼻子右上角
                         [2.774015, -2.080775, 5.048531], #43嘴左上角
                         [-2.774015, -2.080775, 5.048531],#39嘴右上角
                         [0.000000, -3.116408, 6.097667], #45嘴中央下角
                         [0.000000, -7.415691, 4.070434]])#6下巴角

# 相机坐标系(XYZ)：添加相机内参
K = [6.5308391993466671e+002, 0.0, 3.1950000000000000e+002,
     0.0, 6.5308391993466671e+002, 2.3950000000000000e+002,
     0.0, 0.0, 1.0]# 等价于矩阵[fx, 0, cx; 0, fy, cy; 0, 0, 1]
# 图像中心坐标系(uv)：相机畸变参数[k1, k2, p1, p2, k3]
D = [7.0834633684407095e-002, 6.9140193737175351e-002, 0.0, 0.0, -1.3073460323689292e+000]

# 像素坐标系(xy)：填写凸轮的本征和畸变系数
cam_matrix = np.array(K).reshape(3, 3).astype(np.float32)
dist_coeffs = np.array(D).reshape(5, 1).astype(np.float32)



# 重新投影3D点的世界坐标轴以验证结果姿势
reprojectsrc = np.float32([[10.0, 10.0, 10.0],
                           [10.0, 10.0, -10.0],
                           [10.0, -10.0, -10.0],
                           [10.0, -10.0, 10.0],
                           [-10.0, 10.0, 10.0],
                           [-10.0, 10.0, -10.0],
                           [-10.0, -10.0, -10.0],
                           [-10.0, -10.0, 10.0]])
# 绘制正方体12轴
line_pairs = [[0, 1], [1, 2], [2, 3], [3, 0],
              [4, 5], [5, 6], [6, 7], [7, 4],
              [0, 4], [1, 5], [2, 6], [3, 7]]

def get_head_pose(shape):
    # 填写2D参考点，注释遵循https://ibug.doc.ic.ac.uk/resources/300-W/
    """
      17左眉左上角/21左眉右角/22右眉左上角/26右眉右上角/36左眼左上角/39左眼右上角/42右眼左上角/
      45右眼右上角/31鼻子左上角/35鼻子右上角/48左上角/54嘴右上角/57嘴中央下角/8下巴角
    """
    # 像素坐标集合
    image_pts = np.float32([shape[17], shape[21], shape[22], shape[26], shape[36],
                            shape[39], shape[42], shape[45], shape[31], shape[35],
                            shape[48], shape[54], shape[57], shape[8]])
    """
    用solvepnp或sovlepnpRansac，输入3d点、2d点、相机内参、相机畸变，输出r、t之后
    用projectPoints，输入3d点、相机内参、相机畸变、r、t，输出重投影2d点
    计算原2d点和重投影2d点的距离作为重投影误差
    """
    # solvePnP计算姿势——求解旋转和平移矩阵：
    # rotation_vec表示旋转矩阵，translation_vec表示平移矩阵，cam_matrix与K矩阵对应，dist_coeffs与D矩阵对应。
    _, rotation_vec, translation_vec = cv2.solvePnP(object_pts, image_pts, cam_matrix, dist_coeffs)
    # projectPoints重新投影误差
    reprojectdst, _ = cv2.projectPoints(reprojectsrc, rotation_vec, translation_vec, cam_matrix,dist_coeffs)

    reprojectdst = tuple(map(tuple, reprojectdst.reshape(8, 2)))# 以8行2列显示

    # 计算欧拉角calc euler angle
    # 参考https://docs.opencv.org/2.4/modules/calib3d/doc/camera_calibration_and_3d_reconstruction.html#decomposeprojectionmatrix
    rotation_mat, _ = cv2.Rodrigues(rotation_vec)#罗德里格斯公式（将旋转矩阵转换为旋转向量）
    pose_mat = cv2.hconcat((rotation_mat, translation_vec))# 水平拼接，vconcat垂直拼接
    # eulerAngles –可选的三元素矢量，包含三个以度为单位的欧拉旋转角度
    _, _, _, _, _, _, euler_angle = cv2.decomposeProjectionMatrix(pose_mat)# 将投影矩阵分解为旋转矩阵和相机矩阵

    return reprojectdst, euler_angle


def main():
    # return
    cap = cv2.VideoCapture(0)
    if not cap.isOpened():
        print("Unable to connect to camera.")
        return
    # 检测人脸
    detector = dlib.get_frontal_face_detector()
    # 检测第一个人脸的关键点
    predictor = dlib.shape_predictor(face_landmark_path)

    while cap.isOpened():
        ret, frame = cap.read()
        if ret:
            face_rects = detector(frame, 0)

            if len(face_rects) > 0:
                # 循环脸部位置信息，使用predictor(gray, rect)获得脸部特征位置的信息
                shape = predictor(frame, face_rects[0])
                # 将脸部特征信息转换为数组array的格式
                shape = face_utils.shape_to_np(shape)
                # 获取头部姿态
                reprojectdst, euler_angle = get_head_pose(shape)
                pitch = format(euler_angle[0, 0])
                yaw = format(euler_angle[1, 0])
                roll = format(euler_angle[2, 0])
                print('pitch:{}, yaw:{}, roll:{}'.format(pitch, yaw, roll))
                
                # 标出68个特征点
                for (x, y) in shape:
                    cv2.circle(frame, (x, y), 1, (0, 0, 255), -1)
                    
                # 绘制正方体12轴
                for start, end in line_pairs:
                    cv2.line(frame, reprojectdst[start], reprojectdst[end], (0, 0, 255))
                # 显示角度结果
                cv2.putText(frame, "X: " + "{:7.2f}".format(euler_angle[0, 0]), (20, 20), cv2.FONT_HERSHEY_SIMPLEX,0.75, (0, 0, 255), thickness=2)
                cv2.putText(frame, "Y: " + "{:7.2f}".format(euler_angle[1, 0]), (20, 50), cv2.FONT_HERSHEY_SIMPLEX,0.75, (0, 0, 255), thickness=2)
                cv2.putText(frame, "Z: " + "{:7.2f}".format(euler_angle[2, 0]), (20, 80), cv2.FONT_HERSHEY_SIMPLEX,0.75, (0, 0, 255), thickness=2)    
    
            # 按q退出提示
            cv2.putText(frame, "Press 'q': Quit", (20, 450),cv2.FONT_HERSHEY_SIMPLEX, 0.7, (84, 255, 159), 2)
            # 窗口显示 show with opencv
            cv2.imshow("Head_Posture", frame)

            if cv2.waitKey(1) & 0xFF == ord('q'):
                break
    # 释放摄像头 release camera
    cap.release()
    # do a bit of cleanup
    cv2.destroyAllWindows()


if __name__ == '__main__':
    main()
# Out:
# pitch:-1.52592486482225, yaw:-3.641155633231405, roll:-1.7343345663356509
# pitch:-0.95245073834262, yaw:-0.9839147796335558, roll:-1.2506715126638224
# pitch:-0.9174671700786005, yaw:-1.5239128012326761, roll:-1.324680110854094
# pitch:-0.45865802124326294, yaw:-2.078850407172968, roll:-1.806950616178291
# pitch:-0.5285176270195822, yaw:-1.3066623687256034, roll:-1.4783328399909006
# pitch:-1.1614956033115056, yaw:-2.6926970018811933, roll:-1.4442059039867419
# pitch:-2.2354935743612674, yaw:-2.715603409927391, roll:-1.3090854510909937
# pitch:-2.274517207168189, yaw:-2.215332515744181, roll:-1.357885150152115
# pitch:-0.6695672299130452, yaw:-3.064056104936772, roll:-1.3580953659016977
# pitch:-1.4596007667679474, yaw:-4.228628583862223, roll:-1.4342447814158774
# pitch:-0.6094586134123463, yaw:-2.5001888584668626, roll:-1.426960264223968
# pitch:-0.6094586134123463, yaw:-2.5001888584668626, roll:-1.426960264223968
# pitch:-1.709734387659002, yaw:-2.822636852142856, roll:-1.3122006468925178
# pitch:-2.9688797169442065, yaw:-4.3124001425958784, roll:-1.4336661317886685
# pitch:-3.4517066551128406, yaw:-5.028901525387876, roll:-1.2053811485111436
# pitch:-3.463652358604974, yaw:-7.159567110832623, roll:-0.5899449682332806
# pitch:-3.2959718404663, yaw:-11.354241163807238, roll:-0.675864949694765
# pitch:-3.2959718404663, yaw:-11.354241163807238, roll:-0.675864949694765
# pitch:-3.7632578673865824, yaw:-12.674962095905194, roll:-0.6089654979505745
# pitch:-5.031891695560308, yaw:-15.018700275750087, roll:-0.8145268440588493
# pitch:-5.098389222302678, yaw:-16.55473505283938, roll:-0.9616989021640069
# pitch:-6.197653556590163, yaw:-16.137886244688545, roll:-0.7556548397799799
# pitch:-5.857631285627166, yaw:-17.80626536481133, roll:-0.352371423618915
# pitch:-7.354029216444776, yaw:-15.287832733867141, roll:-0.07928938542233598
# pitch:-7.826914411381859, yaw:-16.813837185726875, roll:0.1785736393119312
# pitch:-8.57648490022489, yaw:-17.813165597202918, roll:-0.478626261281799
# pitch:-8.57648490022489, yaw:-17.813165597202918, roll:-0.478626261281799
# pitch:-8.62598405342675, yaw:-16.867275143324544, roll:0.09027968980383101
# pitch:-8.295079252272958, yaw:-17.969789528381874, roll:-0.2519588968308675
# pitch:-8.78924881865578, yaw:-17.79050508183727, roll:-0.12886379336976894
# pitch:-9.218187263047943, yaw:-16.768603325287554, roll:0.12653958850745148
# pitch:-8.63869946899657, yaw:-17.100365968451833, roll:0.5524177275630049
# pitch:-8.63869946899657, yaw:-17.100365968451833, roll:0.5524177275630049
# pitch:-9.572433076886627, yaw:-17.249676024029934, roll:0.5806116508694061
# pitch:-8.254153705371506, yaw:-14.91464922221505, roll:0.49165618911604686
# pitch:-7.925085838191192, yaw:-17.842091899895156, roll:0.23262475315415174
# pitch:-7.925085838191192, yaw:-17.842091899895156, roll:0.23262475315415174
# pitch:-7.793480729059369, yaw:-16.19948578273013, roll:0.4229962960125677
# pitch:-7.825549720315549, yaw:-15.54834966423041, roll:-0.0019562933459841532
# pitch:-7.961171357288482, yaw:-15.685297692236691, roll:0.4411608029952313
# pitch:-8.973591887548281, yaw:-16.461673291061956, roll:0.4156616547559597
# pitch:-9.758971700834355, yaw:-14.071357287185778, roll:-0.14458957155086827
# pitch:-10.10757527734896, yaw:-9.880016220869354, roll:-0.39564056105204265
# pitch:-10.095086706089845, yaw:-11.326507899411984, roll:-0.9634391901375241
# pitch:-10.095086706089845, yaw:-11.326507899411984, roll:-0.9634391901375241
# pitch:-12.802446064581767, yaw:-8.064815110988713, roll:-0.9494891851228191
# pitch:-9.901723351100664, yaw:-8.927865248221183, roll:-0.9405795621895291
# pitch:-11.7970025509101, yaw:-8.296399613406734, roll:-0.889845044089612
# pitch:-10.805933834712802, yaw:-7.737920350772438, roll:-0.904833331808418
# pitch:-10.44427363726284, yaw:-7.838882107694402, roll:-0.6639065943038265
# pitch:-10.44427363726284, yaw:-7.838882107694402, roll:-0.6639065943038265
# pitch:-9.915705256880743, yaw:-8.131250699371039, roll:-1.1939399803300488
# pitch:-11.155485501923609, yaw:-6.478059536219652, roll:-0.7702457666069364
# pitch:-10.959836315417373, yaw:-6.78403629012659, roll:-0.7131500697149352
# pitch:-10.070312566516177, yaw:-7.610044233043805, roll:-0.8847356879545837
# pitch:-10.070312566516177, yaw:-7.610044233043805, roll:-0.8847356879545837
# pitch:-8.288233523399523, yaw:-7.09586953638027, roll:-1.4775969190901146
# pitch:-8.283145859348327, yaw:-6.648635479418828, roll:-2.703644394040068
# pitch:-10.21261438914622, yaw:-6.477518728908205, roll:-4.150074955575
# pitch:-7.434840930040767, yaw:-4.941406717090552, roll:-4.534048496726234
# pitch:-6.101808144755771, yaw:-4.547325824480133, roll:-4.85673002702479
# pitch:-5.474893990383474, yaw:-5.743323564221713, roll:-5.099140201529743
# pitch:-5.935556544931166, yaw:-5.067996431294465, roll:-4.996753411872619
# pitch:-5.935556544931166, yaw:-5.067996431294465, roll:-4.996753411872619
# pitch:-7.017215185742234, yaw:-5.666869106098982, roll:-4.393579363807628
# pitch:-7.9884310064769615, yaw:-6.682304289142254, roll:-4.156139380557045
# pitch:-5.8314713229858155, yaw:-4.769989965214758, roll:-4.216490729011189
# pitch:-4.813215841104321, yaw:-5.784303340013523, roll:-4.24926531895325
# pitch:-4.813215841104321, yaw:-5.784303340013523, roll:-4.24926531895325
# pitch:-7.4410389752573955, yaw:-6.1819942619000585, roll:-3.499945594139011
# pitch:-7.4410389752573955, yaw:-6.1819942619000585, roll:-3.499945594139011
# pitch:-6.5007868382106855, yaw:-7.405850006237912, roll:-3.6399722634730503

# %%
# -*- coding: utf-8 -*-
# import the necessary packages
from scipy.spatial import distance as dist
from imutils.video import FileVideoStream
from imutils.video import VideoStream
from imutils import face_utils
import numpy as np # 数据处理的库 numpy
import argparse
import imutils
import time
import dlib
import cv2
import math
import time
from threading import Thread,Event
 
# 世界坐标系(UVW)：填写3D参考点，该模型参考http://aifi.isr.uc.pt/Downloads/OpenGL/glAnthropometric3DModel.cpp
object_pts = np.float32([[6.825897, 6.760612, 4.402142],  #33左眉左上角
                         [1.330353, 7.122144, 6.903745],  #29左眉右角
                         [-1.330353, 7.122144, 6.903745], #34右眉左角
                         [-6.825897, 6.760612, 4.402142], #38右眉右上角
                         [5.311432, 5.485328, 3.987654],  #13左眼左上角
                         [1.789930, 5.393625, 4.413414],  #17左眼右上角
                         [-1.789930, 5.393625, 4.413414], #25右眼左上角
                         [-5.311432, 5.485328, 3.987654], #21右眼右上角
                         [2.005628, 1.409845, 6.165652],  #55鼻子左上角
                         [-2.005628, 1.409845, 6.165652], #49鼻子右上角
                         [2.774015, -2.080775, 5.048531], #43嘴左上角
                         [-2.774015, -2.080775, 5.048531],#39嘴右上角
                         [0.000000, -3.116408, 6.097667], #45嘴中央下角
                         [0.000000, -7.415691, 4.070434]])#6下巴角

# 相机坐标系(XYZ)：添加相机内参
K = [6.5308391993466671e+002, 0.0, 3.1950000000000000e+002,
     0.0, 6.5308391993466671e+002, 2.3950000000000000e+002,
     0.0, 0.0, 1.0]# 等价于矩阵[fx, 0, cx; 0, fy, cy; 0, 0, 1]
# 图像中心坐标系(uv)：相机畸变参数[k1, k2, p1, p2, k3]
D = [7.0834633684407095e-002, 6.9140193737175351e-002, 0.0, 0.0, -1.3073460323689292e+000]

# 像素坐标系(xy)：填写凸轮的本征和畸变系数
cam_matrix = np.array(K).reshape(3, 3).astype(np.float32)
dist_coeffs = np.array(D).reshape(5, 1).astype(np.float32)



# 重新投影3D点的世界坐标轴以验证结果姿势
reprojectsrc = np.float32([[10.0, 10.0, 10.0],
                           [10.0, 10.0, -10.0],
                           [10.0, -10.0, -10.0],
                           [10.0, -10.0, 10.0],
                           [-10.0, 10.0, 10.0],
                           [-10.0, 10.0, -10.0],
                           [-10.0, -10.0, -10.0],
                           [-10.0, -10.0, 10.0]])
# 绘制正方体12轴
line_pairs = [[0, 1], [1, 2], [2, 3], [3, 0],
              [4, 5], [5, 6], [6, 7], [7, 4],
              [0, 4], [1, 5], [2, 6], [3, 7]]

def get_head_pose(shape):# 头部姿态估计
    # （像素坐标集合）填写2D参考点，注释遵循https://ibug.doc.ic.ac.uk/resources/300-W/
    # 17左眉左上角/21左眉右角/22右眉左上角/26右眉右上角/36左眼左上角/39左眼右上角/42右眼左上角/
    # 45右眼右上角/31鼻子左上角/35鼻子右上角/48左上角/54嘴右上角/57嘴中央下角/8下巴角
    image_pts = np.float32([shape[17], shape[21], shape[22], shape[26], shape[36],
                            shape[39], shape[42], shape[45], shape[31], shape[35],
                            shape[48], shape[54], shape[57], shape[8]])
    # solvePnP计算姿势——求解旋转和平移矩阵：
    # rotation_vec表示旋转矩阵，translation_vec表示平移矩阵，cam_matrix与K矩阵对应，dist_coeffs与D矩阵对应。
    _, rotation_vec, translation_vec = cv2.solvePnP(object_pts, image_pts, cam_matrix, dist_coeffs)
    # projectPoints重新投影误差：原2d点和重投影2d点的距离（输入3d点、相机内参、相机畸变、r、t，输出重投影2d点）
    reprojectdst, _ = cv2.projectPoints(reprojectsrc, rotation_vec, translation_vec, cam_matrix,dist_coeffs)
    reprojectdst = tuple(map(tuple, reprojectdst.reshape(8, 2)))# 以8行2列显示

    # 计算欧拉角calc euler angle
    # 参考https://docs.opencv.org/2.4/modules/calib3d/doc/camera_calibration_and_3d_reconstruction.html#decomposeprojectionmatrix
    rotation_mat, _ = cv2.Rodrigues(rotation_vec)#罗德里格斯公式（将旋转矩阵转换为旋转向量）
    pose_mat = cv2.hconcat((rotation_mat, translation_vec))# 水平拼接，vconcat垂直拼接
    # decomposeProjectionMatrix将投影矩阵分解为旋转矩阵和相机矩阵
    _, _, _, _, _, _, euler_angle = cv2.decomposeProjectionMatrix(pose_mat)
    
    pitch, yaw, roll = [math.radians(_) for _ in euler_angle]
 
 
    pitch = math.degrees(math.asin(math.sin(pitch)))
    roll = -math.degrees(math.asin(math.sin(roll)))
    yaw = math.degrees(math.asin(math.sin(yaw)))
    print('pitch:{}, yaw:{}, roll:{}'.format(pitch, yaw, roll))

    return reprojectdst, euler_angle# 投影误差，欧拉角

def eye_aspect_ratio(eye):
    # 垂直眼标志（X，Y）坐标
    A = dist.euclidean(eye[1], eye[5])# 计算两个集合之间的欧式距离
    B = dist.euclidean(eye[2], eye[4])
    # 计算水平之间的欧几里得距离
    # 水平眼标志（X，Y）坐标
    C = dist.euclidean(eye[0], eye[3])
    # 眼睛长宽比的计算
    ear = (A + B) / (2.0 * C)
    # 返回眼睛的长宽比
    return ear
 
def mouth_aspect_ratio(mouth):# 嘴部
    A = np.linalg.norm(mouth[2] - mouth[9])  # 51, 59
    B = np.linalg.norm(mouth[4] - mouth[7])  # 53, 57
    C = np.linalg.norm(mouth[0] - mouth[6])  # 49, 55
    mar = (A + B) / (2.0 * C)
    return mar

# 定义常数
# 眼睛长宽比
# 闪烁阈值
EYE_AR_THRESH = 0.2
EYE_AR_CONSEC_FRAMES = 3
# 打哈欠长宽比
# 闪烁阈值
MAR_THRESH = 0.5
MOUTH_AR_CONSEC_FRAMES = 3
# 瞌睡点头
HAR_THRESH = 0.3
NOD_AR_CONSEC_FRAMES = 3
# 初始化帧计数器和眨眼总数
COUNTER = 0
TOTAL = 0
# 初始化帧计数器和打哈欠总数
mCOUNTER = 0
mTOTAL = 0
# 初始化帧计数器和点头总数
hCOUNTER = 0
hTOTAL = 0

# 初始化DLIB的人脸检测器（HOG），然后创建面部标志物预测
print("[INFO] loading facial landmark predictor...")
# 第一步：使用dlib.get_frontal_face_detector() 获得脸部位置检测器
detector = dlib.get_frontal_face_detector()
# 第二步：使用dlib.shape_predictor获得脸部特征位置检测器
predictor = dlib.shape_predictor('D:/myworkspace/JupyterNotebook/fatigue_detecting/model/shape_predictor_68_face_landmarks.dat')
 
# 第三步：分别获取左右眼面部标志的索引
(lStart, lEnd) = face_utils.FACIAL_LANDMARKS_IDXS["left_eye"]
(rStart, rEnd) = face_utils.FACIAL_LANDMARKS_IDXS["right_eye"]
(mStart, mEnd) = face_utils.FACIAL_LANDMARKS_IDXS["mouth"]

# 第四步：打开cv2 本地摄像头
cap = cv2.VideoCapture(0)
 
# 从视频流循环帧
while True:
    # 第五步：进行循环，读取图片，并对图片做维度扩大，并进灰度化
    ret, frame = cap.read()
    frame = imutils.resize(frame, width=720)
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    # 第六步：使用detector(gray, 0) 进行脸部位置检测
    rects = detector(gray, 0)
    
    # 第七步：循环脸部位置信息，使用predictor(gray, rect)获得脸部特征位置的信息
    for rect in rects:
        shape = predictor(gray, rect)
        
        # 第八步：将脸部特征信息转换为数组array的格式
        shape = face_utils.shape_to_np(shape)
        
        # 第九步：提取左眼和右眼坐标
        leftEye = shape[lStart:lEnd]
        rightEye = shape[rStart:rEnd]
        # 嘴巴坐标
        mouth = shape[mStart:mEnd]        
        
        # 第十步：构造函数计算左右眼的EAR值，使用平均值作为最终的EAR
        leftEAR = eye_aspect_ratio(leftEye)
        rightEAR = eye_aspect_ratio(rightEye)
        ear = (leftEAR + rightEAR) / 2.0
        # 打哈欠
        mar = mouth_aspect_ratio(mouth)
 
        # 第十一步：使用cv2.convexHull获得凸包位置，使用drawContours画出轮廓位置进行画图操作
        leftEyeHull = cv2.convexHull(leftEye)
        rightEyeHull = cv2.convexHull(rightEye)
        cv2.drawContours(frame, [leftEyeHull], -1, (0, 255, 0), 1)
        cv2.drawContours(frame, [rightEyeHull], -1, (0, 255, 0), 1)
        mouthHull = cv2.convexHull(mouth)
        cv2.drawContours(frame, [mouthHull], -1, (0, 255, 0), 1)
 
        # 第十二步：进行画图操作，用矩形框标注人脸
        left = rect.left()
        top = rect.top()
        right = rect.right()
        bottom = rect.bottom()
        cv2.rectangle(frame, (left, top), (right, bottom), (0, 255, 0), 1)    
 
        '''
            分别计算左眼和右眼的评分求平均作为最终的评分，如果小于阈值，则加1，如果连续3次都小于阈值，则表示进行了一次眨眼活动
        '''
        # 第十三步：循环，满足条件的，眨眼次数+1
        if ear < EYE_AR_THRESH:# 眼睛长宽比：0.2
            COUNTER += 1
           
        else:
            # 如果连续3次都小于阈值，则表示进行了一次眨眼活动
            if COUNTER >= EYE_AR_CONSEC_FRAMES:# 阈值：3
                TOTAL += 1
            # 重置眼帧计数器
            COUNTER = 0
            
        # 第十四步：进行画图操作，同时使用cv2.putText将眨眼次数进行显示
        cv2.putText(frame, "Faces: {}".format(len(rects)), (10, 30),cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 0, 255), 2)     
        cv2.putText(frame, "COUNTER: {}".format(COUNTER), (150, 30),cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 0, 255), 2) 
        cv2.putText(frame, "EAR: {:.2f}".format(ear), (300, 30),cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 0, 255), 2)
        cv2.putText(frame, "Blinks: {}".format(TOTAL), (450, 30),cv2.FONT_HERSHEY_SIMPLEX, 0.7, (255,255,0), 2)
        
        '''
            计算张嘴评分，如果小于阈值，则加1，如果连续3次都小于阈值，则表示打了一次哈欠，同一次哈欠大约在3帧
        '''
        # 同理，判断是否打哈欠    
        if mar > MAR_THRESH:# 张嘴阈值0.5
            mCOUNTER += 1
            cv2.putText(frame, "Yawning!", (10, 60),cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 0, 255), 2)
        else:
            # 如果连续3次都小于阈值，则表示打了一次哈欠
            if mCOUNTER >= MOUTH_AR_CONSEC_FRAMES:# 阈值：3
                mTOTAL += 1
            # 重置嘴帧计数器
            mCOUNTER = 0
        cv2.putText(frame, "COUNTER: {}".format(mCOUNTER), (150, 60),cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 0, 255), 2) 
        cv2.putText(frame, "MAR: {:.2f}".format(mar), (300, 60),cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 0, 255), 2)
        cv2.putText(frame, "Yawning: {}".format(mTOTAL), (480, 60),cv2.FONT_HERSHEY_SIMPLEX, 0.7, (255,255,0), 2)
        """
        瞌睡点头
        """
        # 第十五步：获取头部姿态
        reprojectdst, euler_angle = get_head_pose(shape)
        
        har = euler_angle[0, 0]# 取pitch旋转角度
        if har > HAR_THRESH:# 点头阈值0.3
            hCOUNTER += 1
        else:
            # 如果连续3次都小于阈值，则表示瞌睡点头一次
            if hCOUNTER >= NOD_AR_CONSEC_FRAMES:# 阈值：3
                hTOTAL += 1
            # 重置点头帧计数器
            hCOUNTER = 0
        
        # 绘制正方体12轴
        for start, end in line_pairs:
            cv2.line(frame, reprojectdst[start], reprojectdst[end], (0, 0, 255))
        # 显示角度结果
        cv2.putText(frame, "X: " + "{:7.2f}".format(euler_angle[0, 0]), (10, 90), cv2.FONT_HERSHEY_SIMPLEX,0.75, (0, 255, 0), thickness=2)# GREEN
        cv2.putText(frame, "Y: " + "{:7.2f}".format(euler_angle[1, 0]), (150, 90), cv2.FONT_HERSHEY_SIMPLEX,0.75, (255, 0, 0), thickness=2)# BLUE
        cv2.putText(frame, "Z: " + "{:7.2f}".format(euler_angle[2, 0]), (300, 90), cv2.FONT_HERSHEY_SIMPLEX,0.75, (0, 0, 255), thickness=2)# RED    
        cv2.putText(frame, "Nod: {:.2f}".format(hTOTAL), (480, 90),cv2.FONT_HERSHEY_SIMPLEX, 0.7, (255,255,0), 2)
        
            
        # 第十六步：进行画图操作，68个特征点标识
        for (x, y) in shape:
            cv2.circle(frame, (x, y), 1, (0, 0, 255), -1)

    print('嘴巴实时长宽比:{:.2f} '.format(mar)+"\t是否张嘴："+str([False,True][mar > MAR_THRESH]))
    print('眼睛实时长宽比:{:.2f} '.format(ear)+"\t是否眨眼："+str([False,True][COUNTER>=1]))
    
    # 确定疲劳提示:眨眼50次，打哈欠15次，瞌睡点头15次
    if TOTAL >= 50 or mTOTAL>=15 or hTOTAL>=15:
        cv2.putText(frame, "SLEEP!!!", (100, 200),cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 255), 3)
        
    # 按q退出
    cv2.putText(frame, "Press 'q': Quit", (20, 500),cv2.FONT_HERSHEY_SIMPLEX, 0.7, (84, 255, 159), 2)
    # 窗口显示 show with opencv
    cv2.imshow("Frame", frame)
    
    # if the `q` key was pressed, break from the loop
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
        
# 释放摄像头 release camera
cap.release()
# do a bit of cleanup
cv2.destroyAllWindows()
# Out:
# [INFO] loading facial landmark predictor...
# D:\mydownload\Anaconda3\lib\site-packages\ipykernel_launcher.py:274: DeprecationWarning: In future, it will be an error for 'np.bool_' scalars to be interpreted as an index
# 嘴巴实时长宽比:0.47 	是否张嘴：False
# 眼睛实时长宽比:0.23 	是否眨眼：False
# 嘴巴实时长宽比:0.47 	是否张嘴：False
# 眼睛实时长宽比:0.23 	是否眨眼：False
# 嘴巴实时长宽比:0.47 	是否张嘴：False
# 眼睛实时长宽比:0.23 	是否眨眼：False
# 嘴巴实时长宽比:0.47 	是否张嘴：False
# 眼睛实时长宽比:0.23 	是否眨眼：False
# 嘴巴实时长宽比:0.47 	是否张嘴：False
# 眼睛实时长宽比:0.23 	是否眨眼：False
# 嘴巴实时长宽比:0.47 	是否张嘴：False
# 眼睛实时长宽比:0.23 	是否眨眼：False
# 嘴巴实时长宽比:0.47 	是否张嘴：False
# 眼睛实时长宽比:0.23 	是否眨眼：False
# 嘴巴实时长宽比:0.47 	是否张嘴：False
# 眼睛实时长宽比:0.23 	是否眨眼：False
# 嘴巴实时长宽比:0.47 	是否张嘴：False
# 眼睛实时长宽比:0.23 	是否眨眼：False
# 嘴巴实时长宽比:0.47 	是否张嘴：False
# 眼睛实时长宽比:0.23 	是否眨眼：False
# 嘴巴实时长宽比:0.47 	是否张嘴：False
# 眼睛实时长宽比:0.23 	是否眨眼：False
# 嘴巴实时长宽比:0.47 	是否张嘴：False
# 眼睛实时长宽比:0.23 	是否眨眼：False
# 嘴巴实时长宽比:0.47 	是否张嘴：False
# 眼睛实时长宽比:0.23 	是否眨眼：False
# 嘴巴实时长宽比:0.47 	是否张嘴：False
# 眼睛实时长宽比:0.23 	是否眨眼：False
# 嘴巴实时长宽比:0.47 	是否张嘴：False
# 眼睛实时长宽比:0.23 	是否眨眼：False
# 嘴巴实时长宽比:0.47 	是否张嘴：False
# 眼睛实时长宽比:0.23 	是否眨眼：False
# 嘴巴实时长宽比:0.47 	是否张嘴：False
# 眼睛实时长宽比:0.23 	是否眨眼：False
# 嘴巴实时长宽比:0.47 	是否张嘴：False
# 眼睛实时长宽比:0.23 	是否眨眼：False
# 嘴巴实时长宽比:0.47 	是否张嘴：False
# 眼睛实时长宽比:0.23 	是否眨眼：False
# 嘴巴实时长宽比:0.47 	是否张嘴：False
# 眼睛实时长宽比:0.23 	是否眨眼：False
# 嘴巴实时长宽比:0.47 	是否张嘴：False
# 眼睛实时长宽比:0.23 	是否眨眼：False
# 嘴巴实时长宽比:0.47 	是否张嘴：False
# 眼睛实时长宽比:0.23 	是否眨眼：False
# 嘴巴实时长宽比:0.47 	是否张嘴：False
# 眼睛实时长宽比:0.23 	是否眨眼：False
# 嘴巴实时长宽比:0.47 	是否张嘴：False
# 眼睛实时长宽比:0.23 	是否眨眼：False
# 嘴巴实时长宽比:0.47 	是否张嘴：False
# 眼睛实时长宽比:0.23 	是否眨眼：False
# 嘴巴实时长宽比:0.47 	是否张嘴：False
# 眼睛实时长宽比:0.23 	是否眨眼：False
# 嘴巴实时长宽比:0.47 	是否张嘴：False
# 眼睛实时长宽比:0.23 	是否眨眼：False
# 嘴巴实时长宽比:0.47 	是否张嘴：False
# 眼睛实时长宽比:0.23 	是否眨眼：False
# 嘴巴实时长宽比:0.47 	是否张嘴：False
# 眼睛实时长宽比:0.23 	是否眨眼：False
# 嘴巴实时长宽比:0.47 	是否张嘴：False
# 眼睛实时长宽比:0.23 	是否眨眼：False
# 嘴巴实时长宽比:0.47 	是否张嘴：False
# 眼睛实时长宽比:0.23 	是否眨眼：False
# 嘴巴实时长宽比:0.47 	是否张嘴：False
# 眼睛实时长宽比:0.23 	是否眨眼：False
# 嘴巴实时长宽比:0.47 	是否张嘴：False
# 眼睛实时长宽比:0.23 	是否眨眼：False
# 嘴巴实时长宽比:0.47 	是否张嘴：False
# 眼睛实时长宽比:0.23 	是否眨眼：False
# 嘴巴实时长宽比:0.47 	是否张嘴：False
# 眼睛实时长宽比:0.23 	是否眨眼：False
# 嘴巴实时长宽比:0.47 	是否张嘴：False
# 眼睛实时长宽比:0.23 	是否眨眼：False
# 嘴巴实时长宽比:0.47 	是否张嘴：False
# 眼睛实时长宽比:0.23 	是否眨眼：False
# 嘴巴实时长宽比:0.47 	是否张嘴：False
# 眼睛实时长宽比:0.23 	是否眨眼：False
# 嘴巴实时长宽比:0.47 	是否张嘴：False
# 眼睛实时长宽比:0.23 	是否眨眼：False
# 嘴巴实时长宽比:0.47 	是否张嘴：False
# 眼睛实时长宽比:0.23 	是否眨眼：False
# 嘴巴实时长宽比:0.47 	是否张嘴：False
# 眼睛实时长宽比:0.23 	是否眨眼：False
# 嘴巴实时长宽比:0.47 	是否张嘴：False
# 眼睛实时长宽比:0.23 	是否眨眼：False
# 嘴巴实时长宽比:0.47 	是否张嘴：False
# 眼睛实时长宽比:0.23 	是否眨眼：False
# 嘴巴实时长宽比:0.47 	是否张嘴：False
# 眼睛实时长宽比:0.23 	是否眨眼：False
# 嘴巴实时长宽比:0.47 	是否张嘴：False
# 眼睛实时长宽比:0.23 	是否眨眼：False
# 嘴巴实时长宽比:0.47 	是否张嘴：False
# 眼睛实时长宽比:0.23 	是否眨眼：False
# 嘴巴实时长宽比:0.47 	是否张嘴：False
# 眼睛实时长宽比:0.23 	是否眨眼：False
# 嘴巴实时长宽比:0.47 	是否张嘴：False
# 眼睛实时长宽比:0.23 	是否眨眼：False
# 嘴巴实时长宽比:0.47 	是否张嘴：False
# 眼睛实时长宽比:0.23 	是否眨眼：False
# 嘴巴实时长宽比:0.47 	是否张嘴：False
# 眼睛实时长宽比:0.23 	是否眨眼：False
# 嘴巴实时长宽比:0.47 	是否张嘴：False
# 眼睛实时长宽比:0.23 	是否眨眼：False
# 嘴巴实时长宽比:0.47 	是否张嘴：False
# 眼睛实时长宽比:0.23 	是否眨眼：False
# 嘴巴实时长宽比:0.47 	是否张嘴：False
# 眼睛实时长宽比:0.23 	是否眨眼：False
# 嘴巴实时长宽比:0.47 	是否张嘴：False
# 眼睛实时长宽比:0.23 	是否眨眼：False
# 嘴巴实时长宽比:0.47 	是否张嘴：False
# 眼睛实时长宽比:0.23 	是否眨眼：False
# 嘴巴实时长宽比:0.47 	是否张嘴：False
# 眼睛实时长宽比:0.23 	是否眨眼：False
# 嘴巴实时长宽比:0.47 	是否张嘴：False
# 眼睛实时长宽比:0.23 	是否眨眼：False
# 嘴巴实时长宽比:0.47 	是否张嘴：False
# 眼睛实时长宽比:0.23 	是否眨眼：False
# 嘴巴实时长宽比:0.47 	是否张嘴：False
# 眼睛实时长宽比:0.23 	是否眨眼：False
# 嘴巴实时长宽比:0.47 	是否张嘴：False
# 眼睛实时长宽比:0.23 	是否眨眼：False
# 嘴巴实时长宽比:0.47 	是否张嘴：False
# 眼睛实时长宽比:0.23 	是否眨眼：False
# 嘴巴实时长宽比:0.47 	是否张嘴：False
# 眼睛实时长宽比:0.23 	是否眨眼：False
# 嘴巴实时长宽比:0.47 	是否张嘴：False
# 眼睛实时长宽比:0.23 	是否眨眼：False
# pitch:17.954795564960445, yaw:7.815289681251287, roll:8.332429022935827
# 嘴巴实时长宽比:0.28 	是否张嘴：False
# 眼睛实时长宽比:0.37 	是否眨眼：False
# pitch:19.82055973125464, yaw:8.816667160723938, roll:7.963538603312287
# 嘴巴实时长宽比:0.29 	是否张嘴：False
# 眼睛实时长宽比:0.36 	是否眨眼：False
# pitch:18.803820742416136, yaw:8.426465567949672, roll:7.686947863299146
# 嘴巴实时长宽比:0.29 	是否张嘴：False
# 眼睛实时长宽比:0.38 	是否眨眼：False
# pitch:17.404986927355925, yaw:7.730307820201686, roll:9.000896616317322
# 嘴巴实时长宽比:0.28 	是否张嘴：False
# 眼睛实时长宽比:0.37 	是否眨眼：False
# pitch:19.001886231807926, yaw:8.161905574745372, roll:8.84053832540436
# 嘴巴实时长宽比:0.29 	是否张嘴：False
# 眼睛实时长宽比:0.35 	是否眨眼：False
# pitch:18.66016731043682, yaw:8.447805287701769, roll:8.632489490241687
# 嘴巴实时长宽比:0.29 	是否张嘴：False
# 眼睛实时长宽比:0.37 	是否眨眼：False
# pitch:9.096624978491452, yaw:4.430794894962687, roll:8.26038981830803
# 嘴巴实时长宽比:0.27 	是否张嘴：False
# 眼睛实时长宽比:0.39 	是否眨眼：False
# 嘴巴实时长宽比:0.27 	是否张嘴：False
# 眼睛实时长宽比:0.39 	是否眨眼：False
# pitch:19.24667264550136, yaw:9.065717616067573, roll:8.60390299516693
# 嘴巴实时长宽比:0.27 	是否张嘴：False
# 眼睛实时长宽比:0.35 	是否眨眼：False
# pitch:23.43439921829004, yaw:9.13068324011009, roll:7.9532470881286494
# 嘴巴实时长宽比:0.24 	是否张嘴：False
# 眼睛实时长宽比:0.36 	是否眨眼：False
# pitch:18.890355150832452, yaw:9.903762766681107, roll:8.632110232829225
# 嘴巴实时长宽比:0.28 	是否张嘴：False
# 眼睛实时长宽比:0.37 	是否眨眼：False
# pitch:17.430942012156848, yaw:8.119000868843992, roll:8.366344554920053
# 嘴巴实时长宽比:0.27 	是否张嘴：False
# 眼睛实时长宽比:0.36 	是否眨眼：False
# pitch:16.68293402155761, yaw:7.003632815200518, roll:8.299808057428317
# 嘴巴实时长宽比:0.28 	是否张嘴：False
# 眼睛实时长宽比:0.36 	是否眨眼：False
# pitch:19.56412449247435, yaw:9.59755646945317, roll:8.988508501121835
# 嘴巴实时长宽比:0.27 	是否张嘴：False
# 眼睛实时长宽比:0.36 	是否眨眼：False
# pitch:18.135308339087874, yaw:7.393838183917936, roll:9.16210448753422
# 嘴巴实时长宽比:0.28 	是否张嘴：False
# 眼睛实时长宽比:0.37 	是否眨眼：False
# pitch:18.274280003784046, yaw:7.727137289910373, roll:9.240800252688812
# 嘴巴实时长宽比:0.28 	是否张嘴：False
# 眼睛实时长宽比:0.36 	是否眨眼：False
# pitch:12.549218422649728, yaw:4.349427623723687, roll:9.07623624022879
# 嘴巴实时长宽比:0.29 	是否张嘴：False
# 眼睛实时长宽比:0.35 	是否眨眼：False
# pitch:19.13824791018363, yaw:7.284079436218231, roll:9.394163308799676
# 嘴巴实时长宽比:0.29 	是否张嘴：False
# 眼睛实时长宽比:0.34 	是否眨眼：False
# pitch:12.476077638029222, yaw:4.716185120944881, roll:10.126999817420668
# 嘴巴实时长宽比:0.27 	是否张嘴：False
# 眼睛实时长宽比:0.36 	是否眨眼：False
# 嘴巴实时长宽比:0.27 	是否张嘴：False
# 眼睛实时长宽比:0.36 	是否眨眼：False
# 嘴巴实时长宽比:0.27 	是否张嘴：False
# 眼睛实时长宽比:0.36 	是否眨眼：False
# pitch:15.09388288608706, yaw:4.377470896759709, roll:10.932784316905073
# 嘴巴实时长宽比:0.28 	是否张嘴：False
# 眼睛实时长宽比:0.36 	是否眨眼：False
# 嘴巴实时长宽比:0.28 	是否张嘴：False
# 眼睛实时长宽比:0.36 	是否眨眼：False
# pitch:14.036911721190837, yaw:4.769983852177027, roll:11.994448751994549
# 嘴巴实时长宽比:0.26 	是否张嘴：False
# 眼睛实时长宽比:0.36 	是否眨眼：False
# pitch:12.082825564166832, yaw:3.9941538075841123, roll:12.683415612685708
# 嘴巴实时长宽比:0.28 	是否张嘴：False
# 眼睛实时长宽比:0.36 	是否眨眼：False
# pitch:12.319318517390734, yaw:3.3945776174449738, roll:12.154379887195804
# 嘴巴实时长宽比:0.29 	是否张嘴：False
# 眼睛实时长宽比:0.37 	是否眨眼：False
# pitch:12.716674294262798, yaw:3.5373054965840764, roll:11.778424892505228
# 嘴巴实时长宽比:0.28 	是否张嘴：False
# 眼睛实时长宽比:0.34 	是否眨眼：False
# pitch:13.725867378216803, yaw:4.366881545624315, roll:11.483354769538568
# 嘴巴实时长宽比:0.28 	是否张嘴：False
# 眼睛实时长宽比:0.36 	是否眨眼：False
# pitch:11.70209738727235, yaw:2.867050277035886, roll:12.452722236232946
# 嘴巴实时长宽比:0.27 	是否张嘴：False
# 眼睛实时长宽比:0.35 	是否眨眼：False
# pitch:12.321676584492854, yaw:4.321297175271014, roll:12.257049226948515
# 嘴巴实时长宽比:0.27 	是否张嘴：False
# 眼睛实时长宽比:0.37 	是否眨眼：False
# 嘴巴实时长宽比:0.27 	是否张嘴：False
# 眼睛实时长宽比:0.37 	是否眨眼：False
# 嘴巴实时长宽比:0.27 	是否张嘴：False
# 眼睛实时长宽比:0.37 	是否眨眼：False
# 嘴巴实时长宽比:0.27 	是否张嘴：False
# 眼睛实时长宽比:0.37 	是否眨眼：False
# 嘴巴实时长宽比:0.27 	是否张嘴：False
# 眼睛实时长宽比:0.37 	是否眨眼：False
# 嘴巴实时长宽比:0.27 	是否张嘴：False
# 眼睛实时长宽比:0.37 	是否眨眼：False
# 嘴巴实时长宽比:0.27 	是否张嘴：False
# 眼睛实时长宽比:0.37 	是否眨眼：False
# 嘴巴实时长宽比:0.27 	是否张嘴：False
# 眼睛实时长宽比:0.37 	是否眨眼：False
# 嘴巴实时长宽比:0.27 	是否张嘴：False
# 眼睛实时长宽比:0.37 	是否眨眼：False
# 嘴巴实时长宽比:0.27 	是否张嘴：False
# 眼睛实时长宽比:0.37 	是否眨眼：False
# pitch:12.276635742514712, yaw:3.1852116308235208, roll:11.992683886424452
# 嘴巴实时长宽比:0.28 	是否张嘴：False
# 眼睛实时长宽比:0.36 	是否眨眼：False
# pitch:13.469079950051555, yaw:4.245148363048189, roll:12.446359213392986
# 嘴巴实时长宽比:0.27 	是否张嘴：False
# 眼睛实时长宽比:0.36 	是否眨眼：False
# pitch:14.092535455330365, yaw:3.836817798185149, roll:13.22142459098717
# 嘴巴实时长宽比:0.29 	是否张嘴：False
# 眼睛实时长宽比:0.37 	是否眨眼：False
# pitch:18.360478109720372, yaw:10.30897478621827, roll:13.426094657011328
# 嘴巴实时长宽比:0.28 	是否张嘴：False
# 眼睛实时长宽比:0.36 	是否眨眼：False
# 嘴巴实时长宽比:0.28 	是否张嘴：False
# 眼睛实时长宽比:0.36 	是否眨眼：False
# pitch:15.104826172210565, yaw:7.213855090524173, roll:13.636772097883638
# 嘴巴实时长宽比:0.27 	是否张嘴：False
# 眼睛实时长宽比:0.33 	是否眨眼：False
# pitch:13.732863606526813, yaw:6.26906373867693, roll:13.640387849435939
# 嘴巴实时长宽比:0.27 	是否张嘴：False
# 眼睛实时长宽比:0.36 	是否眨眼：False
# pitch:12.115559758231731, yaw:5.171077840794553, roll:13.717425186225421
# 嘴巴实时长宽比:0.28 	是否张嘴：False
# 眼睛实时长宽比:0.36 	是否眨眼：False
# 嘴巴实时长宽比:0.28 	是否张嘴：False
# 眼睛实时长宽比:0.36 	是否眨眼：False
# 嘴巴实时长宽比:0.28 	是否张嘴：False
# 眼睛实时长宽比:0.36 	是否眨眼：False
# 嘴巴实时长宽比:0.28 	是否张嘴：False
# 眼睛实时长宽比:0.36 	是否眨眼：False
# 嘴巴实时长宽比:0.28 	是否张嘴：False
# 眼睛实时长宽比:0.36 	是否眨眼：False
# 嘴巴实时长宽比:0.28 	是否张嘴：False
# 眼睛实时长宽比:0.36 	是否眨眼：False
# 嘴巴实时长宽比:0.28 	是否张嘴：False
# 眼睛实时长宽比:0.36 	是否眨眼：False
# 嘴巴实时长宽比:0.28 	是否张嘴：False
# 眼睛实时长宽比:0.36 	是否眨眼：False
# 嘴巴实时长宽比:0.28 	是否张嘴：False
# 眼睛实时长宽比:0.36 	是否眨眼：False
# pitch:11.725492276837373, yaw:5.315892208676956, roll:13.255163098645683
# 嘴巴实时长宽比:0.28 	是否张嘴：False
# 眼睛实时长宽比:0.36 	是否眨眼：False
# pitch:11.34072166932517, yaw:5.423798664946369, roll:13.237691400516827
# 嘴巴实时长宽比:0.28 	是否张嘴：False
# 眼睛实时长宽比:0.33 	是否眨眼：False
# pitch:11.331192999402154, yaw:4.716168085094264, roll:12.823755250977332
# 嘴巴实时长宽比:0.27 	是否张嘴：False
# 眼睛实时长宽比:0.36 	是否眨眼：False
# pitch:11.355563511011763, yaw:5.051897433002611, roll:12.351511065194368
# 嘴巴实时长宽比:0.27 	是否张嘴：False
# 眼睛实时长宽比:0.36 	是否眨眼：False
# pitch:9.779559902867675, yaw:4.3590001013684345, roll:10.478748439809937
# 嘴巴实时长宽比:0.29 	是否张嘴：False
# 眼睛实时长宽比:0.36 	是否眨眼：False
# 嘴巴实时长宽比:0.29 	是否张嘴：False
# 眼睛实时长宽比:0.36 	是否眨眼：False
# pitch:9.195486267190823, yaw:5.340429481187592, roll:8.105368260276256
# 嘴巴实时长宽比:0.28 	是否张嘴：False
# 眼睛实时长宽比:0.36 	是否眨眼：False
# pitch:11.503410436448966, yaw:5.728905082233793, roll:6.297584321337474
# 嘴巴实时长宽比:0.28 	是否张嘴：False
# 眼睛实时长宽比:0.36 	是否眨眼：False
# pitch:8.76830395771679, yaw:6.245354515187087, roll:4.616760328004236
# 嘴巴实时长宽比:0.27 	是否张嘴：False
# 眼睛实时长宽比:0.34 	是否眨眼：False
# pitch:8.267225046696147, yaw:4.962730543125203, roll:4.036113929600219
# 嘴巴实时长宽比:0.26 	是否张嘴：False
# 眼睛实时长宽比:0.35 	是否眨眼：False
# pitch:13.082405597606979, yaw:6.822714488468589, roll:1.4858695459417819
# 嘴巴实时长宽比:0.27 	是否张嘴：False
# 眼睛实时长宽比:0.36 	是否眨眼：False
# 嘴巴实时长宽比:0.27 	是否张嘴：False
# 眼睛实时长宽比:0.36 	是否眨眼：False
# pitch:9.602521979771462, yaw:5.2365490413253815, roll:1.0532560506927973
# 嘴巴实时长宽比:0.28 	是否张嘴：False
# 眼睛实时长宽比:0.36 	是否眨眼：False
# 嘴巴实时长宽比:0.28 	是否张嘴：False
# 眼睛实时长宽比:0.36 	是否眨眼：False
# 嘴巴实时长宽比:0.28 	是否张嘴：False
# 眼睛实时长宽比:0.36 	是否眨眼：False
# 嘴巴实时长宽比:0.28 	是否张嘴：False
# 眼睛实时长宽比:0.36 	是否眨眼：False
# 嘴巴实时长宽比:0.28 	是否张嘴：False
# 眼睛实时长宽比:0.36 	是否眨眼：False
# 嘴巴实时长宽比:0.28 	是否张嘴：False
# 眼睛实时长宽比:0.36 	是否眨眼：False
# 嘴巴实时长宽比:0.28 	是否张嘴：False
# 眼睛实时长宽比:0.36 	是否眨眼：False
# 嘴巴实时长宽比:0.28 	是否张嘴：False
# 眼睛实时长宽比:0.36 	是否眨眼：False
# 嘴巴实时长宽比:0.28 	是否张嘴：False
# 眼睛实时长宽比:0.36 	是否眨眼：False
# 嘴巴实时长宽比:0.28 	是否张嘴：False
# 眼睛实时长宽比:0.36 	是否眨眼：False
# 嘴巴实时长宽比:0.28 	是否张嘴：False
# 眼睛实时长宽比:0.36 	是否眨眼：False
# 嘴巴实时长宽比:0.28 	是否张嘴：False
# 眼睛实时长宽比:0.36 	是否眨眼：False
# 嘴巴实时长宽比:0.28 	是否张嘴：False
# 眼睛实时长宽比:0.36 	是否眨眼：False
# 嘴巴实时长宽比:0.28 	是否张嘴：False
# 眼睛实时长宽比:0.36 	是否眨眼：False
# 嘴巴实时长宽比:0.28 	是否张嘴：False
# 眼睛实时长宽比:0.36 	是否眨眼：False
# 嘴巴实时长宽比:0.28 	是否张嘴：False
# 眼睛实时长宽比:0.36 	是否眨眼：False
# 嘴巴实时长宽比:0.28 	是否张嘴：False
# 眼睛实时长宽比:0.36 	是否眨眼：False
# pitch:17.87589585163978, yaw:3.9311485267585837, roll:4.6205150687976735
# 嘴巴实时长宽比:0.28 	是否张嘴：False
# 眼睛实时长宽比:0.35 	是否眨眼：False
# pitch:12.64459110813133, yaw:2.024776584412285, roll:5.365762972832045
# 嘴巴实时长宽比:0.28 	是否张嘴：False
# 眼睛实时长宽比:0.35 	是否眨眼：False
# pitch:11.093211546444126, yaw:0.9237816837360845, roll:5.714899898892278
# 嘴巴实时长宽比:0.30 	是否张嘴：False
# 眼睛实时长宽比:0.36 	是否眨眼：False
# pitch:11.796313051412714, yaw:2.133910081565382, roll:5.514330195396144
# 嘴巴实时长宽比:0.29 	是否张嘴：False
# 眼睛实时长宽比:0.35 	是否眨眼：False
# pitch:11.190335967269824, yaw:2.3535496558321802, roll:5.809865672449487
# 嘴巴实时长宽比:0.29 	是否张嘴：False
# 眼睛实时长宽比:0.37 	是否眨眼：False
# 嘴巴实时长宽比:0.29 	是否张嘴：False
# 眼睛实时长宽比:0.37 	是否眨眼：False
# 嘴巴实时长宽比:0.29 	是否张嘴：False
# 眼睛实时长宽比:0.37 	是否眨眼：False
# pitch:17.4440233334695, yaw:6.676769505792383, roll:6.1944996544194915
# 嘴巴实时长宽比:0.27 	是否张嘴：False
# 眼睛实时长宽比:0.37 	是否眨眼：False
# pitch:13.396900076240525, yaw:4.586608474912905, roll:6.667595475702116
# 嘴巴实时长宽比:0.27 	是否张嘴：False
# 眼睛实时长宽比:0.38 	是否眨眼：False
# pitch:9.405491627382355, yaw:2.8729116619732036, roll:7.40087834695217
# 嘴巴实时长宽比:0.28 	是否张嘴：False
# 眼睛实时长宽比:0.38 	是否眨眼：False
# pitch:11.168810348718704, yaw:4.409111599654533, roll:7.602367063606248
# 嘴巴实时长宽比:0.28 	是否张嘴：False
# 眼睛实时长宽比:0.37 	是否眨眼：False
# 嘴巴实时长宽比:0.28 	是否张嘴：False
# 眼睛实时长宽比:0.37 	是否眨眼：False
# pitch:11.356860053392131, yaw:4.362600638327787, roll:7.648790043996898
# 嘴巴实时长宽比:0.26 	是否张嘴：False
# 眼睛实时长宽比:0.35 	是否眨眼：False
# pitch:12.104862073083552, yaw:4.520751873915401, roll:7.72292158020198
# 嘴巴实时长宽比:0.26 	是否张嘴：False
# 眼睛实时长宽比:0.35 	是否眨眼：False
# pitch:10.118385352869545, yaw:3.3231899779759866, roll:8.408260528553624
# 嘴巴实时长宽比:0.27 	是否张嘴：False
# 眼睛实时长宽比:0.37 	是否眨眼：False
# pitch:10.906060753691225, yaw:4.293780143054161, roll:7.977061921462042
# 嘴巴实时长宽比:0.26 	是否张嘴：False
# 眼睛实时长宽比:0.34 	是否眨眼：False
# pitch:10.944195273972666, yaw:3.872476020451767, roll:8.061975143076516
# 嘴巴实时长宽比:0.26 	是否张嘴：False
# 眼睛实时长宽比:0.36 	是否眨眼：False
# pitch:10.69918331945135, yaw:3.8246290318955483, roll:7.9727249080218945
# 嘴巴实时长宽比:0.27 	是否张嘴：False
# 眼睛实时长宽比:0.36 	是否眨眼：False
# pitch:9.479115084045608, yaw:3.4423805219371895, roll:7.634093126520327
# 嘴巴实时长宽比:0.27 	是否张嘴：False
# 眼睛实时长宽比:0.36 	是否眨眼：False
# pitch:10.817639393918103, yaw:3.819506487566318, roll:7.765543450725522
# 嘴巴实时长宽比:0.27 	是否张嘴：False
# 眼睛实时长宽比:0.35 	是否眨眼：False
# pitch:11.429234104361155, yaw:3.5606566640443913, roll:8.210418471464893
# 嘴巴实时长宽比:0.26 	是否张嘴：False
# 眼睛实时长宽比:0.35 	是否眨眼：False
# pitch:11.674227955605621, yaw:3.437243654138978, roll:8.39801032336305
# 嘴巴实时长宽比:0.26 	是否张嘴：False
# 眼睛实时长宽比:0.37 	是否眨眼：False
# pitch:11.700274250891034, yaw:3.280696265648758, roll:8.358392198543493
# 嘴巴实时长宽比:0.27 	是否张嘴：False
# 眼睛实时长宽比:0.35 	是否眨眼：False
# pitch:11.113574246415972, yaw:3.200596125987876, roll:8.195740317846957
# 嘴巴实时长宽比:0.27 	是否张嘴：False
# 眼睛实时长宽比:0.35 	是否眨眼：False
# pitch:12.05922575633614, yaw:2.866865787090572, roll:8.360112343747986
# 嘴巴实时长宽比:0.28 	是否张嘴：False
# 眼睛实时长宽比:0.35 	是否眨眼：False
# pitch:10.590045649439242, yaw:2.2824368633489476, roll:8.350371964129378
# 嘴巴实时长宽比:0.27 	是否张嘴：False
# 眼睛实时长宽比:0.37 	是否眨眼：False
# 嘴巴实时长宽比:0.27 	是否张嘴：False
# 眼睛实时长宽比:0.37 	是否眨眼：False
# pitch:13.880449701758563, yaw:3.1788116548364926, roll:7.458130297919745
# 嘴巴实时长宽比:0.28 	是否张嘴：False
# 眼睛实时长宽比:0.37 	是否眨眼：False
# pitch:10.410548501175743, yaw:3.1713936156126663, roll:8.547930795743591
# 嘴巴实时长宽比:0.27 	是否张嘴：False
# 眼睛实时长宽比:0.37 	是否眨眼：False
# pitch:12.040645799756968, yaw:3.369068544174015, roll:8.667846873966518
# 嘴巴实时长宽比:0.28 	是否张嘴：False
# 眼睛实时长宽比:0.35 	是否眨眼：False
# pitch:15.605322868978822, yaw:4.401078651386536, roll:7.850085215176096
# 嘴巴实时长宽比:0.28 	是否张嘴：False
# 眼睛实时长宽比:0.36 	是否眨眼：False
# pitch:11.284312445570162, yaw:4.0722302367839625, roll:8.408440022284523
# 嘴巴实时长宽比:0.28 	是否张嘴：False
# 眼睛实时长宽比:0.36 	是否眨眼：False
# pitch:10.503551215545492, yaw:3.0342376703090994, roll:8.427171411416804
# 嘴巴实时长宽比:0.28 	是否张嘴：False
# 眼睛实时长宽比:0.37 	是否眨眼：False
# pitch:10.58934463164581, yaw:2.1481575815417484, roll:8.709582738972069
# 嘴巴实时长宽比:0.27 	是否张嘴：False
# 眼睛实时长宽比:0.36 	是否眨眼：False
# pitch:10.566317065897342, yaw:2.772498532867615, roll:8.164780504951414
# 嘴巴实时长宽比:0.28 	是否张嘴：False
# 眼睛实时长宽比:0.37 	是否眨眼：False
# pitch:10.514105090755226, yaw:2.4329478486284026, roll:8.645415822530847
# 嘴巴实时长宽比:0.27 	是否张嘴：False
# 眼睛实时长宽比:0.36 	是否眨眼：False
# pitch:9.900425978991922, yaw:3.5296066119858507, roll:8.51251273077237
# 嘴巴实时长宽比:0.26 	是否张嘴：False
# 眼睛实时长宽比:0.37 	是否眨眼：False
# pitch:9.729553369795262, yaw:2.6911912028725604, roll:8.604010712013533
# 嘴巴实时长宽比:0.27 	是否张嘴：False
# 眼睛实时长宽比:0.38 	是否眨眼：False
# pitch:10.211714852687908, yaw:3.816760097658909, roll:8.892614752969669
# 嘴巴实时长宽比:0.26 	是否张嘴：False
# 眼睛实时长宽比:0.38 	是否眨眼：False
# pitch:11.8533500481472, yaw:4.634088198818103, roll:8.802764392656874
# 嘴巴实时长宽比:0.28 	是否张嘴：False
# 眼睛实时长宽比:0.38 	是否眨眼：False
# pitch:14.001077771169104, yaw:5.236325787482155, roll:8.281714532298228
# 嘴巴实时长宽比:0.28 	是否张嘴：False
# 眼睛实时长宽比:0.37 	是否眨眼：False
# 嘴巴实时长宽比:0.28 	是否张嘴：False
# 眼睛实时长宽比:0.37 	是否眨眼：False
# 嘴巴实时长宽比:0.28 	是否张嘴：False
# 眼睛实时长宽比:0.37 	是否眨眼：False
# 嘴巴实时长宽比:0.28 	是否张嘴：False
# 眼睛实时长宽比:0.37 	是否眨眼：False
# 嘴巴实时长宽比:0.28 	是否张嘴：False
# 眼睛实时长宽比:0.37 	是否眨眼：False
# 嘴巴实时长宽比:0.28 	是否张嘴：False
# 眼睛实时长宽比:0.37 	是否眨眼：False
# 嘴巴实时长宽比:0.28 	是否张嘴：False
# 眼睛实时长宽比:0.37 	是否眨眼：False
# 嘴巴实时长宽比:0.28 	是否张嘴：False
# 眼睛实时长宽比:0.37 	是否眨眼：False
# 嘴巴实时长宽比:0.28 	是否张嘴：False
# 眼睛实时长宽比:0.37 	是否眨眼：False
# 嘴巴实时长宽比:0.28 	是否张嘴：False
# 眼睛实时长宽比:0.37 	是否眨眼：False
# 嘴巴实时长宽比:0.28 	是否张嘴：False
# 眼睛实时长宽比:0.37 	是否眨眼：False
# pitch:13.891910623260712, yaw:-8.787542405469438, roll:6.009003783068771
# 嘴巴实时长宽比:0.22 	是否张嘴：False
# 眼睛实时长宽比:0.30 	是否眨眼：False
# 嘴巴实时长宽比:0.22 	是否张嘴：False
# 眼睛实时长宽比:0.30 	是否眨眼：False
# 嘴巴实时长宽比:0.22 	是否张嘴：False
# 眼睛实时长宽比:0.30 	是否眨眼：False
# 嘴巴实时长宽比:0.22 	是否张嘴：False
# 眼睛实时长宽比:0.30 	是否眨眼：False
# 嘴巴实时长宽比:0.22 	是否张嘴：False
# 眼睛实时长宽比:0.30 	是否眨眼：False
# 嘴巴实时长宽比:0.22 	是否张嘴：False
# 眼睛实时长宽比:0.30 	是否眨眼：False
# pitch:19.77072666839396, yaw:5.167482450218719, roll:9.19763603462722
# 嘴巴实时长宽比:0.26 	是否张嘴：False
# 眼睛实时长宽比:0.34 	是否眨眼：False
# pitch:15.027221084689982, yaw:4.1431806091282155, roll:9.358691684978398
# 嘴巴实时长宽比:0.26 	是否张嘴：False
# 眼睛实时长宽比:0.35 	是否眨眼：False
# pitch:20.4039757652981, yaw:6.665094278263427, roll:9.131733690185785
# 嘴巴实时长宽比:0.26 	是否张嘴：False
# 眼睛实时长宽比:0.35 	是否眨眼：False
# pitch:13.01049308458241, yaw:4.763830836010056, roll:9.192936431861929
# 嘴巴实时长宽比:0.27 	是否张嘴：False
# 眼睛实时长宽比:0.36 	是否眨眼：False
# pitch:11.976263680950087, yaw:4.56069424364896, roll:9.1258936310404
# 嘴巴实时长宽比:0.27 	是否张嘴：False
# 眼睛实时长宽比:0.35 	是否眨眼：False
# pitch:11.038289037011245, yaw:4.008970953595253, roll:9.026642246294157
# 嘴巴实时长宽比:0.28 	是否张嘴：False
# 眼睛实时长宽比:0.37 	是否眨眼：False
# pitch:10.731214401693665, yaw:4.670090737504634, roll:9.098939489050297
# 嘴巴实时长宽比:0.27 	是否张嘴：False
# 眼睛实时长宽比:0.38 	是否眨眼：False
# pitch:9.594397589936662, yaw:4.4245262609165295, roll:9.09172929035195
# 嘴巴实时长宽比:0.26 	是否张嘴：False
# 眼睛实时长宽比:0.36 	是否眨眼：False
# pitch:9.816903472662393, yaw:4.150658537805221, roll:9.002628548320237
# 嘴巴实时长宽比:0.27 	是否张嘴：False
# 眼睛实时长宽比:0.38 	是否眨眼：False
# pitch:10.8051285836631, yaw:5.030864471118874, roll:8.996849810672092
# 嘴巴实时长宽比:0.26 	是否张嘴：False
# 眼睛实时长宽比:0.35 	是否眨眼：False
# pitch:10.55500566304675, yaw:4.820276464679844, roll:9.18524234212624
# 嘴巴实时长宽比:0.27 	是否张嘴：False
# 眼睛实时长宽比:0.37 	是否眨眼：False
# pitch:11.67920302299468, yaw:5.4094772318544075, roll:9.131879192038985
# 嘴巴实时长宽比:0.28 	是否张嘴：False
# 眼睛实时长宽比:0.37 	是否眨眼：False
# pitch:10.62784209366038, yaw:5.720136095780911, roll:9.448322881104723
# 嘴巴实时长宽比:0.27 	是否张嘴：False
# 眼睛实时长宽比:0.37 	是否眨眼：False
# pitch:12.014388918654515, yaw:5.364462888470779, roll:9.215857264462036
# 嘴巴实时长宽比:0.27 	是否张嘴：False
# 眼睛实时长宽比:0.36 	是否眨眼：False
# 嘴巴实时长宽比:0.27 	是否张嘴：False
# 眼睛实时长宽比:0.36 	是否眨眼：False
# pitch:20.18620616095872, yaw:8.443944660382257, roll:9.57797511704065
# 嘴巴实时长宽比:0.27 	是否张嘴：False
# 眼睛实时长宽比:0.35 	是否眨眼：False
# pitch:20.119009834731294, yaw:8.237176401452098, roll:9.816818576199834
# 嘴巴实时长宽比:0.26 	是否张嘴：False
# 眼睛实时长宽比:0.36 	是否眨眼：False
# pitch:19.351164383566136, yaw:6.9525343158282045, roll:10.14789015898167
# 嘴巴实时长宽比:0.26 	是否张嘴：False
# 眼睛实时长宽比:0.36 	是否眨眼：False
# pitch:20.816360789761404, yaw:8.19076621240109, roll:10.399835552410526
# 嘴巴实时长宽比:0.26 	是否张嘴：False
# 眼睛实时长宽比:0.36 	是否眨眼：False
# pitch:19.92127693401951, yaw:7.688674610358111, roll:10.861314941329866
# 嘴巴实时长宽比:0.25 	是否张嘴：False
# 眼睛实时长宽比:0.36 	是否眨眼：False
# 嘴巴实时长宽比:0.25 	是否张嘴：False
# 眼睛实时长宽比:0.36 	是否眨眼：False
# 嘴巴实时长宽比:0.25 	是否张嘴：False
# 眼睛实时长宽比:0.36 	是否眨眼：False
# pitch:13.58667627615139, yaw:3.7126277147589333, roll:9.987691597874576
# 嘴巴实时长宽比:0.26 	是否张嘴：False
# 眼睛实时长宽比:0.37 	是否眨眼：False
# pitch:13.55749790768043, yaw:3.8100888399658577, roll:9.851536762842406
# 嘴巴实时长宽比:0.27 	是否张嘴：False
# 眼睛实时长宽比:0.34 	是否眨眼：False
# pitch:15.165657225172023, yaw:4.272700813150303, roll:9.219347099686336
# 嘴巴实时长宽比:0.25 	是否张嘴：False
# 眼睛实时长宽比:0.33 	是否眨眼：False
# pitch:16.339086220795455, yaw:4.2572817210086065, roll:8.945208492418327
# 嘴巴实时长宽比:0.24 	是否张嘴：False
# 眼睛实时长宽比:0.32 	是否眨眼：False
# pitch:15.866369799846685, yaw:5.756116431793843, roll:9.37979245878626
# 嘴巴实时长宽比:0.25 	是否张嘴：False
# 眼睛实时长宽比:0.34 	是否眨眼：False
# pitch:16.806268591959697, yaw:5.4584195514350435, roll:9.212876402519175
# 嘴巴实时长宽比:0.26 	是否张嘴：False
# 眼睛实时长宽比:0.32 	是否眨眼：False
# pitch:19.53570846312509, yaw:5.523567283110128, roll:9.416273512072149
# 嘴巴实时长宽比:0.25 	是否张嘴：False
# 眼睛实时长宽比:0.35 	是否眨眼：False
# pitch:16.504788129916857, yaw:3.315124458543917, roll:9.591742868305364
# 嘴巴实时长宽比:0.23 	是否张嘴：False
# 眼睛实时长宽比:0.34 	是否眨眼：False
# pitch:20.29677709220313, yaw:2.6216789972432193, roll:8.51149831924203
# 嘴巴实时长宽比:0.19 	是否张嘴：False
# 眼睛实时长宽比:0.35 	是否眨眼：False
# pitch:12.188299837112655, yaw:3.9590159393240216, roll:9.128692203064313
# 嘴巴实时长宽比:0.25 	是否张嘴：False
# 眼睛实时长宽比:0.37 	是否眨眼：False
# pitch:12.175890613373973, yaw:5.0331836874966625, roll:8.456797197972723
# 嘴巴实时长宽比:0.27 	是否张嘴：False
# 眼睛实时长宽比:0.35 	是否眨眼：False
# pitch:12.4640037840189, yaw:5.252381170296732, roll:8.33731822491689
# 嘴巴实时长宽比:0.27 	是否张嘴：False
# 眼睛实时长宽比:0.37 	是否眨眼：False
# 嘴巴实时长宽比:0.27 	是否张嘴：False
# 眼睛实时长宽比:0.37 	是否眨眼：False
# 嘴巴实时长宽比:0.27 	是否张嘴：False
# 眼睛实时长宽比:0.37 	是否眨眼：False
# pitch:9.544579079106375, yaw:3.9582041571899627, roll:7.059904572745617
# 嘴巴实时长宽比:0.27 	是否张嘴：False
# 眼睛实时长宽比:0.36 	是否眨眼：False
# pitch:9.125337525816116, yaw:4.542093392516432, roll:7.164037710873707
# 嘴巴实时长宽比:0.26 	是否张嘴：False
# 眼睛实时长宽比:0.37 	是否眨眼：False
# pitch:14.489672269832626, yaw:7.44509341409499, roll:6.736644031773181
# 嘴巴实时长宽比:0.27 	是否张嘴：False
# 眼睛实时长宽比:0.36 	是否眨眼：False
# 嘴巴实时长宽比:0.27 	是否张嘴：False
# 眼睛实时长宽比:0.36 	是否眨眼：False
# 嘴巴实时长宽比:0.27 	是否张嘴：False
# 眼睛实时长宽比:0.36 	是否眨眼：False
# 嘴巴实时长宽比:0.27 	是否张嘴：False
# 眼睛实时长宽比:0.36 	是否眨眼：False
# 嘴巴实时长宽比:0.27 	是否张嘴：False
# 眼睛实时长宽比:0.36 	是否眨眼：False
# 嘴巴实时长宽比:0.27 	是否张嘴：False
# 眼睛实时长宽比:0.36 	是否眨眼：False
# 嘴巴实时长宽比:0.27 	是否张嘴：False
# 眼睛实时长宽比:0.36 	是否眨眼：False
# 嘴巴实时长宽比:0.27 	是否张嘴：False
# 眼睛实时长宽比:0.36 	是否眨眼：False
# 嘴巴实时长宽比:0.27 	是否张嘴：False
# 眼睛实时长宽比:0.36 	是否眨眼：False
# pitch:12.701131589564353, yaw:6.567875793291594, roll:7.125606630918272
# 嘴巴实时长宽比:0.28 	是否张嘴：False
# 眼睛实时长宽比:0.34 	是否眨眼：False
# pitch:16.776425872426422, yaw:9.69292094334887, roll:7.582788078889483
# 嘴巴实时长宽比:0.27 	是否张嘴：False
# 眼睛实时长宽比:0.37 	是否眨眼：False
# pitch:17.10817460059603, yaw:10.848226201680351, roll:7.517623518415467
# 嘴巴实时长宽比:0.27 	是否张嘴：False
# 眼睛实时长宽比:0.37 	是否眨眼：False
# pitch:15.479425232782429, yaw:8.840277109787394, roll:7.995846936416696
# 嘴巴实时长宽比:0.27 	是否张嘴：False
# 眼睛实时长宽比:0.37 	是否眨眼：False
# pitch:9.371536565227201, yaw:4.0202480638705795, roll:7.995533624357027
# 嘴巴实时长宽比:0.27 	是否张嘴：False
# 眼睛实时长宽比:0.38 	是否眨眼：False
# pitch:9.241391555874827, yaw:4.014460147350189, roll:8.125972762353301
# 嘴巴实时长宽比:0.28 	是否张嘴：False
# 眼睛实时长宽比:0.37 	是否眨眼：False
# pitch:13.036644925588593, yaw:5.427929563654582, roll:7.243184949698483
# 嘴巴实时长宽比:0.28 	是否张嘴：False
# 眼睛实时长宽比:0.38 	是否眨眼：False
# pitch:10.761395957249603, yaw:3.5085128870370927, roll:7.457864429450534
# 嘴巴实时长宽比:0.28 	是否张嘴：False
# 眼睛实时长宽比:0.38 	是否眨眼：False
# pitch:10.343202125931622, yaw:3.680840856139602, roll:7.53234851143952
# 嘴巴实时长宽比:0.27 	是否张嘴：False
# 眼睛实时长宽比:0.37 	是否眨眼：False
# pitch:9.854269442679088, yaw:3.623434552517185, roll:7.678614018270863
# 嘴巴实时长宽比:0.28 	是否张嘴：False
# 眼睛实时长宽比:0.39 	是否眨眼：False
# pitch:9.190501419250635, yaw:3.5835270248787485, roll:8.210864694247565
# 嘴巴实时长宽比:0.28 	是否张嘴：False
# 眼睛实时长宽比:0.37 	是否眨眼：False
# pitch:14.29340491523075, yaw:4.5200568227842615, roll:7.94928781738483
# 嘴巴实时长宽比:0.26 	是否张嘴：False
# 眼睛实时长宽比:0.37 	是否眨眼：False
# pitch:15.995809547191135, yaw:6.2756590122432225, roll:7.9877210612681715
# 嘴巴实时长宽比:0.26 	是否张嘴：False
# 眼睛实时长宽比:0.37 	是否眨眼：False
# 嘴巴实时长宽比:0.26 	是否张嘴：False
# 眼睛实时长宽比:0.37 	是否眨眼：False
# pitch:20.67899028427785, yaw:7.097659191708238, roll:8.771330319106037
# 嘴巴实时长宽比:0.25 	是否张嘴：False
# 眼睛实时长宽比:0.36 	是否眨眼：False
# pitch:12.326212507183044, yaw:3.2806538764161886, roll:8.272510960851948
# 嘴巴实时长宽比:0.25 	是否张嘴：False
# 眼睛实时长宽比:0.34 	是否眨眼：False
# pitch:11.784951132184528, yaw:3.5908397460021733, roll:7.714171343102626
# 嘴巴实时长宽比:0.25 	是否张嘴：False
# 眼睛实时长宽比:0.39 	是否眨眼：False
# pitch:12.623780322372147, yaw:3.8588131594988653, roll:8.016501857902735
# 嘴巴实时长宽比:0.26 	是否张嘴：False
# 眼睛实时长宽比:0.34 	是否眨眼：False
# pitch:14.567887754287149, yaw:3.082365229956719, roll:8.442427447115323
# 嘴巴实时长宽比:0.25 	是否张嘴：False
# 眼睛实时长宽比:0.34 	是否眨眼：False
# pitch:14.542793158089768, yaw:4.750280069944512, roll:8.187884058543768
# 嘴巴实时长宽比:0.25 	是否张嘴：False
# 眼睛实时长宽比:0.34 	是否眨眼：False
# pitch:20.485058572596525, yaw:6.63602840373573, roll:9.019526590724514
# 嘴巴实时长宽比:0.26 	是否张嘴：False
# 眼睛实时长宽比:0.36 	是否眨眼：False
# pitch:19.903404252116136, yaw:6.043936545889652, roll:9.185930183810564
# 嘴巴实时长宽比:0.25 	是否张嘴：False
# 眼睛实时长宽比:0.36 	是否眨眼：False
# pitch:19.832535888093982, yaw:5.605291337676427, roll:8.805030581270287
# 嘴巴实时长宽比:0.25 	是否张嘴：False
# 眼睛实时长宽比:0.36 	是否眨眼：False
# pitch:19.94297723307731, yaw:6.443483418438567, roll:9.126913566091668
# 嘴巴实时长宽比:0.24 	是否张嘴：False
# 眼睛实时长宽比:0.36 	是否眨眼：False
# pitch:20.47668720525003, yaw:7.046537700341682, roll:9.172034421502653
# 嘴巴实时长宽比:0.24 	是否张嘴：False
# 眼睛实时长宽比:0.35 	是否眨眼：False
# pitch:17.93147127689712, yaw:5.5085524837895985, roll:8.156166168499514
# 嘴巴实时长宽比:0.25 	是否张嘴：False
# 眼睛实时长宽比:0.36 	是否眨眼：False
# pitch:11.747019741139116, yaw:4.568832885765553, roll:7.772852438723773
# 嘴巴实时长宽比:0.26 	是否张嘴：False
# 眼睛实时长宽比:0.36 	是否眨眼：False
# pitch:11.145864387613658, yaw:3.81271373419957, roll:7.453418681262464
# 嘴巴实时长宽比:0.27 	是否张嘴：False
# 眼睛实时长宽比:0.35 	是否眨眼：False
# pitch:16.44268315322372, yaw:7.623653003361348, roll:7.68561177434691
# 嘴巴实时长宽比:0.26 	是否张嘴：False
# 眼睛实时长宽比:0.36 	是否眨眼：False
# pitch:9.306905032689857, yaw:5.043910885105081, roll:6.721739764991301
# 嘴巴实时长宽比:0.27 	是否张嘴：False
# 眼睛实时长宽比:0.37 	是否眨眼：False
# pitch:7.385341918525151, yaw:4.0026500979687025, roll:6.53283434424257
# 嘴巴实时长宽比:0.28 	是否张嘴：False
# 眼睛实时长宽比:0.35 	是否眨眼：False
# pitch:8.852735407132473, yaw:5.517086513806965, roll:6.591402249690807
# 嘴巴实时长宽比:0.28 	是否张嘴：False
# 眼睛实时长宽比:0.37 	是否眨眼：False
# pitch:7.948040136365549, yaw:5.814257141528386, roll:6.722391835012181
# 嘴巴实时长宽比:0.28 	是否张嘴：False
# 眼睛实时长宽比:0.35 	是否眨眼：False
# 嘴巴实时长宽比:0.28 	是否张嘴：False
# 眼睛实时长宽比:0.35 	是否眨眼：False
# 嘴巴实时长宽比:0.28 	是否张嘴：False
# 眼睛实时长宽比:0.35 	是否眨眼：False
# 嘴巴实时长宽比:0.28 	是否张嘴：False
# 眼睛实时长宽比:0.35 	是否眨眼：False
# 嘴巴实时长宽比:0.28 	是否张嘴：False
# 眼睛实时长宽比:0.35 	是否眨眼：False
# 嘴巴实时长宽比:0.28 	是否张嘴：False
# 眼睛实时长宽比:0.35 	是否眨眼：False
# pitch:13.774689989791717, yaw:6.750511913260624, roll:7.088649752409269
# 嘴巴实时长宽比:0.28 	是否张嘴：False
# 眼睛实时长宽比:0.37 	是否眨眼：False
# 嘴巴实时长宽比:0.28 	是否张嘴：False
# 眼睛实时长宽比:0.37 	是否眨眼：False
# 嘴巴实时长宽比:0.28 	是否张嘴：False
# 眼睛实时长宽比:0.37 	是否眨眼：False
# 嘴巴实时长宽比:0.28 	是否张嘴：False
# 眼睛实时长宽比:0.37 	是否眨眼：False
# 嘴巴实时长宽比:0.28 	是否张嘴：False
# 眼睛实时长宽比:0.37 	是否眨眼：False
# 嘴巴实时长宽比:0.28 	是否张嘴：False
# 眼睛实时长宽比:0.37 	是否眨眼：False
# 嘴巴实时长宽比:0.28 	是否张嘴：False
# 眼睛实时长宽比:0.37 	是否眨眼：False
# 嘴巴实时长宽比:0.28 	是否张嘴：False
# 眼睛实时长宽比:0.37 	是否眨眼：False
# pitch:7.609379517487702, yaw:4.121501021517356, roll:7.108269655670192
# 嘴巴实时长宽比:0.29 	是否张嘴：False
# 眼睛实时长宽比:0.39 	是否眨眼：False
# pitch:7.683146152474027, yaw:3.863283098091224, roll:7.216487266286376
# 嘴巴实时长宽比:0.28 	是否张嘴：False
# 眼睛实时长宽比:0.37 	是否眨眼：False
# pitch:7.613858872081809, yaw:3.7852235993306187, roll:6.818345495277437
# 嘴巴实时长宽比:0.28 	是否张嘴：False
# 眼睛实时长宽比:0.38 	是否眨眼：False
# pitch:7.785695590604994, yaw:4.265497625633846, roll:6.902601256352262
# 嘴巴实时长宽比:0.26 	是否张嘴：False
# 眼睛实时长宽比:0.36 	是否眨眼：False
# pitch:8.323074910327822, yaw:4.247963512766024, roll:7.201566655728794
# 嘴巴实时长宽比:0.27 	是否张嘴：False
# 眼睛实时长宽比:0.37 	是否眨眼：False
# pitch:8.020807976975409, yaw:5.503841277377057, roll:6.9976808766572915
# 嘴巴实时长宽比:0.27 	是否张嘴：False
# 眼睛实时长宽比:0.37 	是否眨眼：False
# pitch:8.689268054597298, yaw:5.58627502263372, roll:6.826553776504926
# 嘴巴实时长宽比:0.27 	是否张嘴：False
# 眼睛实时长宽比:0.36 	是否眨眼：False
# pitch:7.779580805676603, yaw:5.7727539970260064, roll:7.034195648493746
# 嘴巴实时长宽比:0.28 	是否张嘴：False
# 眼睛实时长宽比:0.37 	是否眨眼：False
# 嘴巴实时长宽比:0.28 	是否张嘴：False
# 眼睛实时长宽比:0.37 	是否眨眼：False
# 嘴巴实时长宽比:0.28 	是否张嘴：False
# 眼睛实时长宽比:0.37 	是否眨眼：False
# 嘴巴实时长宽比:0.28 	是否张嘴：False
# 眼睛实时长宽比:0.37 	是否眨眼：False
# 嘴巴实时长宽比:0.28 	是否张嘴：False
# 眼睛实时长宽比:0.37 	是否眨眼：False
# 嘴巴实时长宽比:0.28 	是否张嘴：False
# 眼睛实时长宽比:0.37 	是否眨眼：False
# pitch:7.891924433369769, yaw:4.25096861822606, roll:7.477412936531297
# 嘴巴实时长宽比:0.28 	是否张嘴：False
# 眼睛实时长宽比:0.37 	是否眨眼：False
# pitch:7.771857306457463, yaw:4.475034050779816, roll:7.742206821236456
# 嘴巴实时长宽比:0.27 	是否张嘴：False
# 眼睛实时长宽比:0.39 	是否眨眼：False
# 嘴巴实时长宽比:0.27 	是否张嘴：False
# 眼睛实时长宽比:0.39 	是否眨眼：False
# pitch:8.180533336833987, yaw:6.133720119938701, roll:6.758251416868033
# 嘴巴实时长宽比:0.27 	是否张嘴：False
# 眼睛实时长宽比:0.36 	是否眨眼：False
# pitch:8.973684612615004, yaw:5.998635145954985, roll:6.70623095302885
# 嘴巴实时长宽比:0.27 	是否张嘴：False
# 眼睛实时长宽比:0.37 	是否眨眼：False
# pitch:12.111402200726303, yaw:6.977694942864943, roll:6.606802100674891
# 嘴巴实时长宽比:0.26 	是否张嘴：False
# 眼睛实时长宽比:0.36 	是否眨眼：False
# pitch:8.973214577544734, yaw:5.577055040373968, roll:6.961411448808113
# 嘴巴实时长宽比:0.27 	是否张嘴：False
# 眼睛实时长宽比:0.38 	是否眨眼：False
# pitch:7.655358578938668, yaw:5.853447605786597, roll:7.770191851660244
# 嘴巴实时长宽比:0.28 	是否张嘴：False
# 眼睛实时长宽比:0.36 	是否眨眼：False
# pitch:6.93556084629001, yaw:5.600943319838756, roll:7.750079855640993
# 嘴巴实时长宽比:0.29 	是否张嘴：False
# 眼睛实时长宽比:0.36 	是否眨眼：False
# pitch:7.576847159810163, yaw:5.246786333233251, roll:7.674909006454547
# 嘴巴实时长宽比:0.28 	是否张嘴：False
# 眼睛实时长宽比:0.36 	是否眨眼：False
# pitch:7.209453921575508, yaw:5.734990844384209, roll:7.62311797256729
# 嘴巴实时长宽比:0.29 	是否张嘴：False
# 眼睛实时长宽比:0.36 	是否眨眼：False
# pitch:8.191284606957494, yaw:5.054594156196742, roll:7.516258311075691
# 嘴巴实时长宽比:0.28 	是否张嘴：False
# 眼睛实时长宽比:0.36 	是否眨眼：False
# pitch:7.482709421155696, yaw:5.44844628832191, roll:7.50615961185354
# 嘴巴实时长宽比:0.27 	是否张嘴：False
# 眼睛实时长宽比:0.38 	是否眨眼：False
# pitch:7.230830028422749, yaw:3.7392132243952374, roll:7.645116629485311
# 嘴巴实时长宽比:0.28 	是否张嘴：False
# 眼睛实时长宽比:0.37 	是否眨眼：False
# pitch:8.787523297290678, yaw:6.105206229577796, roll:7.143986732204611
# 嘴巴实时长宽比:0.26 	是否张嘴：False
# 眼睛实时长宽比:0.37 	是否眨眼：False
# pitch:6.81466549851953, yaw:5.5768228947444625, roll:7.517439786415593
# 嘴巴实时长宽比:0.28 	是否张嘴：False
# 眼睛实时长宽比:0.37 	是否眨眼：False
# pitch:8.642647236338005, yaw:5.421705886379207, roll:7.7930435722545495
# 嘴巴实时长宽比:0.28 	是否张嘴：False
# 眼睛实时长宽比:0.37 	是否眨眼：False
# pitch:8.446631931609296, yaw:5.594986471155812, roll:8.018494403105747
# 嘴巴实时长宽比:0.27 	是否张嘴：False
# 眼睛实时长宽比:0.37 	是否眨眼：False
# pitch:8.193964844660234, yaw:4.231216246816341, roll:8.14092807621343
# 嘴巴实时长宽比:0.27 	是否张嘴：False
# 眼睛实时长宽比:0.36 	是否眨眼：False
# pitch:8.099077440439178, yaw:5.407393155854257, roll:8.039424040239092
# 嘴巴实时长宽比:0.28 	是否张嘴：False
# 眼睛实时长宽比:0.34 	是否眨眼：False
# pitch:8.00053833271301, yaw:4.707396277026217, roll:7.898712246982518
# 嘴巴实时长宽比:0.29 	是否张嘴：False
# 眼睛实时长宽比:0.36 	是否眨眼：False
# pitch:8.391834638807417, yaw:4.4033016451847855, roll:7.922604177020626
# 嘴巴实时长宽比:0.28 	是否张嘴：False
# 眼睛实时长宽比:0.36 	是否眨眼：False
# pitch:7.93608853548534, yaw:4.383995666156195, roll:8.006947797684242
# 嘴巴实时长宽比:0.28 	是否张嘴：False
# 眼睛实时长宽比:0.36 	是否眨眼：False
# pitch:7.486018231705017, yaw:3.770087088092529, roll:7.8473789479949145
# 嘴巴实时长宽比:0.27 	是否张嘴：False
# 眼睛实时长宽比:0.37 	是否眨眼：False
# pitch:7.273238193179437, yaw:4.653544571068188, roll:8.075263075842743
# 嘴巴实时长宽比:0.27 	是否张嘴：False
# 眼睛实时长宽比:0.37 	是否眨眼：False
# pitch:7.772770381774706, yaw:5.559757377906124, roll:8.011883598785651
# 嘴巴实时长宽比:0.28 	是否张嘴：False
# 眼睛实时长宽比:0.37 	是否眨眼：False
# pitch:9.651891780833997, yaw:5.929320084191717, roll:7.721127123290955
# 嘴巴实时长宽比:0.28 	是否张嘴：False
# 眼睛实时长宽比:0.38 	是否眨眼：False
# pitch:8.827173773626235, yaw:4.7383268200366375, roll:8.659554720575208
# 嘴巴实时长宽比:0.28 	是否张嘴：False
# 眼睛实时长宽比:0.37 	是否眨眼：False
# pitch:8.663063732135429, yaw:5.702901383097127, roll:8.417293572390356
# 嘴巴实时长宽比:0.28 	是否张嘴：False
# 眼睛实时长宽比:0.35 	是否眨眼：False
# pitch:9.277152286401618, yaw:5.081054086489041, roll:8.706286181005352
# 嘴巴实时长宽比:0.27 	是否张嘴：False
# 眼睛实时长宽比:0.37 	是否眨眼：False
# pitch:7.80817350514145, yaw:3.905214756267474, roll:8.374983793849973
# 嘴巴实时长宽比:0.28 	是否张嘴：False
# 眼睛实时长宽比:0.37 	是否眨眼：False
# pitch:7.8422908858132825, yaw:4.4305385422391845, roll:7.945711497947966
# 嘴巴实时长宽比:0.27 	是否张嘴：False
# 眼睛实时长宽比:0.37 	是否眨眼：False
# pitch:8.448281353491113, yaw:4.704904131153861, roll:8.177205148680894
# 嘴巴实时长宽比:0.26 	是否张嘴：False
# 眼睛实时长宽比:0.37 	是否眨眼：False
# pitch:7.84657976621692, yaw:4.843287638305047, roll:8.01537793184551
# 嘴巴实时长宽比:0.28 	是否张嘴：False
# 眼睛实时长宽比:0.37 	是否眨眼：False
# pitch:8.090909115205372, yaw:5.201369843125488, roll:8.33063944809594
# 嘴巴实时长宽比:0.27 	是否张嘴：False
# 眼睛实时长宽比:0.37 	是否眨眼：False
# pitch:9.699810224918338, yaw:5.795068148662937, roll:8.111336098010856
# 嘴巴实时长宽比:0.27 	是否张嘴：False
# 眼睛实时长宽比:0.37 	是否眨眼：False
# pitch:8.37582953923454, yaw:6.171423035644576, roll:8.506777756819762
# 嘴巴实时长宽比:0.27 	是否张嘴：False
# 眼睛实时长宽比:0.38 	是否眨眼：False
# pitch:9.410852723476703, yaw:5.934821974307719, roll:8.113316575621592
# 嘴巴实时长宽比:0.27 	是否张嘴：False
# 眼睛实时长宽比:0.37 	是否眨眼：False
# pitch:8.392071549231694, yaw:4.225448252617902, roll:9.047036778685426
# 嘴巴实时长宽比:0.27 	是否张嘴：False
# 眼睛实时长宽比:0.37 	是否眨眼：False
# pitch:9.358126956478161, yaw:4.582480616493823, roll:9.225576617650026
# 嘴巴实时长宽比:0.27 	是否张嘴：False
# 眼睛实时长宽比:0.37 	是否眨眼：False
# pitch:7.928157010877035, yaw:4.793513680222539, roll:8.543217638673333
# 嘴巴实时长宽比:0.27 	是否张嘴：False
# 眼睛实时长宽比:0.36 	是否眨眼：False
# pitch:7.4722233971789604, yaw:4.260830566570363, roll:8.375530908385679
# 嘴巴实时长宽比:0.27 	是否张嘴：False
# 眼睛实时长宽比:0.38 	是否眨眼：False
# pitch:8.12985476091743, yaw:5.8283376596428855, roll:8.229511171754469
# 嘴巴实时长宽比:0.27 	是否张嘴：False
# 眼睛实时长宽比:0.38 	是否眨眼：False
# pitch:7.777751974572922, yaw:6.508855977406698, roll:8.388288894885024
# 嘴巴实时长宽比:0.28 	是否张嘴：False
# 眼睛实时长宽比:0.36 	是否眨眼：False
# pitch:7.642190932512459, yaw:6.360552487751397, roll:8.270802241997762
# 嘴巴实时长宽比:0.27 	是否张嘴：False
# 眼睛实时长宽比:0.36 	是否眨眼：False
# pitch:9.871251731403209, yaw:6.56099195806273, roll:8.252279377017901
# 嘴巴实时长宽比:0.28 	是否张嘴：False
# 眼睛实时长宽比:0.37 	是否眨眼：False
# pitch:10.048147362780137, yaw:6.346041141410897, roll:8.094096084111632
# 嘴巴实时长宽比:0.27 	是否张嘴：False
# 眼睛实时长宽比:0.36 	是否眨眼：False
# pitch:8.819391017163145, yaw:4.960251684579898, roll:8.829426656872318
# 嘴巴实时长宽比:0.27 	是否张嘴：False
# 眼睛实时长宽比:0.35 	是否眨眼：False
# pitch:9.219807444808628, yaw:5.39083814694582, roll:8.601340103265665
# 嘴巴实时长宽比:0.28 	是否张嘴：False
# 眼睛实时长宽比:0.35 	是否眨眼：False
# pitch:8.2740784458572, yaw:4.640615179593972, roll:8.24161553825767
# 嘴巴实时长宽比:0.27 	是否张嘴：False
# 眼睛实时长宽比:0.37 	是否眨眼：False
# pitch:8.337993536690558, yaw:4.880606530664932, roll:8.398720593296238
# 嘴巴实时长宽比:0.27 	是否张嘴：False
# 眼睛实时长宽比:0.38 	是否眨眼：False
# pitch:9.12421819220612, yaw:4.134453987676395, roll:8.208996538882749
# 嘴巴实时长宽比:0.28 	是否张嘴：False
# 眼睛实时长宽比:0.37 	是否眨眼：False
# pitch:9.705915652888704, yaw:6.47228323529189, roll:8.499685636984951
# 嘴巴实时长宽比:0.28 	是否张嘴：False
# 眼睛实时长宽比:0.37 	是否眨眼：False
# pitch:9.88184755556592, yaw:6.6725108271686215, roll:8.394187345727437
# 嘴巴实时长宽比:0.28 	是否张嘴：False
# 眼睛实时长宽比:0.37 	是否眨眼：False
# pitch:9.768383552363595, yaw:5.454202226922486, roll:8.630120158423976
# 嘴巴实时长宽比:0.28 	是否张嘴：False
# 眼睛实时长宽比:0.38 	是否眨眼：False
# pitch:8.556579991583092, yaw:4.9294642197145935, roll:8.669220822642348
# 嘴巴实时长宽比:0.27 	是否张嘴：False
# 眼睛实时长宽比:0.35 	是否眨眼：False
# pitch:8.094234040264778, yaw:4.434135623146891, roll:8.31553731950636
# 嘴巴实时长宽比:0.28 	是否张嘴：False
# 眼睛实时长宽比:0.37 	是否眨眼：False
# pitch:9.70999968131124, yaw:4.903326795931656, roll:8.507398026254153
# 嘴巴实时长宽比:0.27 	是否张嘴：False
# 眼睛实时长宽比:0.36 	是否眨眼：False
# pitch:7.778075702492741, yaw:3.913310087775771, roll:8.413072762142466
# 嘴巴实时长宽比:0.27 	是否张嘴：False
# 眼睛实时长宽比:0.38 	是否眨眼：False
# pitch:8.313357470649095, yaw:3.3353137353424804, roll:9.021459236694918
# 嘴巴实时长宽比:0.26 	是否张嘴：False
# 眼睛实时长宽比:0.37 	是否眨眼：False
# pitch:8.240984802555756, yaw:4.1498680923350975, roll:8.571075926883196
# 嘴巴实时长宽比:0.28 	是否张嘴：False
# 眼睛实时长宽比:0.37 	是否眨眼：False
# pitch:8.156474580585199, yaw:6.071827025541753, roll:8.356367569628084
# 嘴巴实时长宽比:0.27 	是否张嘴：False
# 眼睛实时长宽比:0.36 	是否眨眼：False
# pitch:8.428497698356612, yaw:5.832376011295208, roll:8.231306722235402
# 嘴巴实时长宽比:0.28 	是否张嘴：False
# 眼睛实时长宽比:0.35 	是否眨眼：False
# pitch:10.017701803058706, yaw:6.008063005341242, roll:8.418295258612297
# 嘴巴实时长宽比:0.27 	是否张嘴：False
# 眼睛实时长宽比:0.35 	是否眨眼：False
# pitch:9.565633832502899, yaw:5.319125853209681, roll:8.891690106869229
# 嘴巴实时长宽比:0.28 	是否张嘴：False
# 眼睛实时长宽比:0.36 	是否眨眼：False
# pitch:10.980472522982572, yaw:5.858043492931879, roll:8.707910981389645
# 嘴巴实时长宽比:0.28 	是否张嘴：False
# 眼睛实时长宽比:0.37 	是否眨眼：False
# pitch:16.42147722766274, yaw:10.189863208422498, roll:9.33453763027294
# 嘴巴实时长宽比:0.27 	是否张嘴：False
# 眼睛实时长宽比:0.37 	是否眨眼：False
# pitch:10.563470360116606, yaw:6.363421141484097, roll:9.02332911030485
# 嘴巴实时长宽比:0.27 	是否张嘴：False
# 眼睛实时长宽比:0.36 	是否眨眼：False
# 嘴巴实时长宽比:0.27 	是否张嘴：False
# 眼睛实时长宽比:0.36 	是否眨眼：False
# pitch:14.68674091024966, yaw:8.41628034131539, roll:10.311631562023441
# 嘴巴实时长宽比:0.27 	是否张嘴：False
# 眼睛实时长宽比:0.38 	是否眨眼：False
# pitch:10.106755880123279, yaw:5.658797034731343, roll:9.63801196553052
# 嘴巴实时长宽比:0.28 	是否张嘴：False
# 眼睛实时长宽比:0.37 	是否眨眼：False
# pitch:8.85673478493382, yaw:4.210062714807993, roll:10.03007994817105
# 嘴巴实时长宽比:0.27 	是否张嘴：False
# 眼睛实时长宽比:0.35 	是否眨眼：False
# pitch:8.199041541697111, yaw:4.666241108990657, roll:9.557450241625732
# 嘴巴实时长宽比:0.27 	是否张嘴：False
# 眼睛实时长宽比:0.36 	是否眨眼：False
# pitch:10.808896862377953, yaw:6.690023767281005, roll:9.064300518741303
# 嘴巴实时长宽比:0.28 	是否张嘴：False
# 眼睛实时长宽比:0.36 	是否眨眼：False
# pitch:16.004430522625665, yaw:7.484574438766758, roll:8.936071402636264
# 嘴巴实时长宽比:0.27 	是否张嘴：False
# 眼睛实时长宽比:0.33 	是否眨眼：False
# 嘴巴实时长宽比:0.27 	是否张嘴：False
# 眼睛实时长宽比:0.33 	是否眨眼：False
# pitch:14.632174961368092, yaw:5.517970242481576, roll:7.394864959383591
# 嘴巴实时长宽比:0.27 	是否张嘴：False
# 眼睛实时长宽比:0.36 	是否眨眼：False
# pitch:16.852596536485752, yaw:7.472729934962899, roll:7.328706530237368
# 嘴巴实时长宽比:0.28 	是否张嘴：False
# 眼睛实时长宽比:0.36 	是否眨眼：False
# 嘴巴实时长宽比:0.28 	是否张嘴：False
# 眼睛实时长宽比:0.36 	是否眨眼：False
# 嘴巴实时长宽比:0.28 	是否张嘴：False
# 眼睛实时长宽比:0.36 	是否眨眼：False
# 嘴巴实时长宽比:0.28 	是否张嘴：False
# 眼睛实时长宽比:0.36 	是否眨眼：False
# 嘴巴实时长宽比:0.28 	是否张嘴：False
# 眼睛实时长宽比:0.36 	是否眨眼：False
# 嘴巴实时长宽比:0.28 	是否张嘴：False
# 眼睛实时长宽比:0.36 	是否眨眼：False
# 嘴巴实时长宽比:0.28 	是否张嘴：False
# 眼睛实时长宽比:0.36 	是否眨眼：False
# pitch:9.006021041571204, yaw:6.4219723942963105, roll:0.6184561011979496
# 嘴巴实时长宽比:0.32 	是否张嘴：False
# 眼睛实时长宽比:0.35 	是否眨眼：False
# pitch:10.176492728761442, yaw:6.565442375690714, roll:0.022306327786514046
# 嘴巴实时长宽比:0.30 	是否张嘴：False
# 眼睛实时长宽比:0.34 	是否眨眼：False
# 嘴巴实时长宽比:0.30 	是否张嘴：False
# 眼睛实时长宽比:0.34 	是否眨眼：False
# 嘴巴实时长宽比:0.30 	是否张嘴：False
# 眼睛实时长宽比:0.34 	是否眨眼：False
# 嘴巴实时长宽比:0.30 	是否张嘴：False
# 眼睛实时长宽比:0.34 	是否眨眼：False
# 嘴巴实时长宽比:0.30 	是否张嘴：False
# 眼睛实时长宽比:0.34 	是否眨眼：False
# 嘴巴实时长宽比:0.30 	是否张嘴：False
# 眼睛实时长宽比:0.34 	是否眨眼：False
# 嘴巴实时长宽比:0.30 	是否张嘴：False
# 眼睛实时长宽比:0.34 	是否眨眼：False
# 嘴巴实时长宽比:0.30 	是否张嘴：False
# 眼睛实时长宽比:0.34 	是否眨眼：False
# 嘴巴实时长宽比:0.30 	是否张嘴：False
# 眼睛实时长宽比:0.34 	是否眨眼：False
# 嘴巴实时长宽比:0.30 	是否张嘴：False
# 眼睛实时长宽比:0.34 	是否眨眼：False
# 嘴巴实时长宽比:0.30 	是否张嘴：False
# 眼睛实时长宽比:0.34 	是否眨眼：False
# 嘴巴实时长宽比:0.30 	是否张嘴：False
# 眼睛实时长宽比:0.34 	是否眨眼：False
# 嘴巴实时长宽比:0.30 	是否张嘴：False
# 眼睛实时长宽比:0.34 	是否眨眼：False
# 嘴巴实时长宽比:0.30 	是否张嘴：False
# 眼睛实时长宽比:0.34 	是否眨眼：False
# 嘴巴实时长宽比:0.30 	是否张嘴：False
# 眼睛实时长宽比:0.34 	是否眨眼：False
# 嘴巴实时长宽比:0.30 	是否张嘴：False
# 眼睛实时长宽比:0.34 	是否眨眼：False
# 嘴巴实时长宽比:0.30 	是否张嘴：False
# 眼睛实时长宽比:0.34 	是否眨眼：False
# 嘴巴实时长宽比:0.30 	是否张嘴：False
# 眼睛实时长宽比:0.34 	是否眨眼：False
# 嘴巴实时长宽比:0.30 	是否张嘴：False
# 眼睛实时长宽比:0.34 	是否眨眼：False
# 嘴巴实时长宽比:0.30 	是否张嘴：False
# 眼睛实时长宽比:0.34 	是否眨眼：False
# 嘴巴实时长宽比:0.30 	是否张嘴：False
# 眼睛实时长宽比:0.34 	是否眨眼：False
# 嘴巴实时长宽比:0.30 	是否张嘴：False
# 眼睛实时长宽比:0.34 	是否眨眼：False
# 嘴巴实时长宽比:0.30 	是否张嘴：False
# 眼睛实时长宽比:0.34 	是否眨眼：False
# 嘴巴实时长宽比:0.30 	是否张嘴：False
# 眼睛实时长宽比:0.34 	是否眨眼：False
# 嘴巴实时长宽比:0.30 	是否张嘴：False
# 眼睛实时长宽比:0.34 	是否眨眼：False
# 嘴巴实时长宽比:0.30 	是否张嘴：False
# 眼睛实时长宽比:0.34 	是否眨眼：False
# 嘴巴实时长宽比:0.30 	是否张嘴：False
# 眼睛实时长宽比:0.34 	是否眨眼：False
# 嘴巴实时长宽比:0.30 	是否张嘴：False
# 眼睛实时长宽比:0.34 	是否眨眼：False
# 嘴巴实时长宽比:0.30 	是否张嘴：False
# 眼睛实时长宽比:0.34 	是否眨眼：False
# 嘴巴实时长宽比:0.30 	是否张嘴：False
# 眼睛实时长宽比:0.34 	是否眨眼：False
# 嘴巴实时长宽比:0.30 	是否张嘴：False
# 眼睛实时长宽比:0.34 	是否眨眼：False
# 嘴巴实时长宽比:0.30 	是否张嘴：False
# 眼睛实时长宽比:0.34 	是否眨眼：False
# 嘴巴实时长宽比:0.30 	是否张嘴：False
# 眼睛实时长宽比:0.34 	是否眨眼：False
# 嘴巴实时长宽比:0.30 	是否张嘴：False
# 眼睛实时长宽比:0.34 	是否眨眼：False
# 嘴巴实时长宽比:0.30 	是否张嘴：False
# 眼睛实时长宽比:0.34 	是否眨眼：False
# 嘴巴实时长宽比:0.30 	是否张嘴：False
# 眼睛实时长宽比:0.34 	是否眨眼：False
# 嘴巴实时长宽比:0.30 	是否张嘴：False
# 眼睛实时长宽比:0.34 	是否眨眼：False
# 嘴巴实时长宽比:0.30 	是否张嘴：False
# 眼睛实时长宽比:0.34 	是否眨眼：False
# 嘴巴实时长宽比:0.30 	是否张嘴：False
# 眼睛实时长宽比:0.34 	是否眨眼：False
# 嘴巴实时长宽比:0.30 	是否张嘴：False
# 眼睛实时长宽比:0.34 	是否眨眼：False
# 嘴巴实时长宽比:0.30 	是否张嘴：False
# 眼睛实时长宽比:0.34 	是否眨眼：False
# 嘴巴实时长宽比:0.30 	是否张嘴：False
# 眼睛实时长宽比:0.34 	是否眨眼：False
# 嘴巴实时长宽比:0.30 	是否张嘴：False
# 眼睛实时长宽比:0.34 	是否眨眼：False
# 嘴巴实时长宽比:0.30 	是否张嘴：False
# 眼睛实时长宽比:0.34 	是否眨眼：False
# 嘴巴实时长宽比:0.30 	是否张嘴：False
# 眼睛实时长宽比:0.34 	是否眨眼：False
# 嘴巴实时长宽比:0.30 	是否张嘴：False
# 眼睛实时长宽比:0.34 	是否眨眼：False
# 嘴巴实时长宽比:0.30 	是否张嘴：False
# 眼睛实时长宽比:0.34 	是否眨眼：False
# 嘴巴实时长宽比:0.30 	是否张嘴：False
# 眼睛实时长宽比:0.34 	是否眨眼：False
# 嘴巴实时长宽比:0.30 	是否张嘴：False
# 眼睛实时长宽比:0.34 	是否眨眼：False
# 嘴巴实时长宽比:0.30 	是否张嘴：False
# 眼睛实时长宽比:0.34 	是否眨眼：False
# 嘴巴实时长宽比:0.30 	是否张嘴：False
# 眼睛实时长宽比:0.34 	是否眨眼：False
# 嘴巴实时长宽比:0.30 	是否张嘴：False
# 眼睛实时长宽比:0.34 	是否眨眼：False
# 嘴巴实时长宽比:0.30 	是否张嘴：False
# 眼睛实时长宽比:0.34 	是否眨眼：False
# 嘴巴实时长宽比:0.30 	是否张嘴：False
# 眼睛实时长宽比:0.34 	是否眨眼：False
# 嘴巴实时长宽比:0.30 	是否张嘴：False
# 眼睛实时长宽比:0.34 	是否眨眼：False
# 嘴巴实时长宽比:0.30 	是否张嘴：False
# 眼睛实时长宽比:0.34 	是否眨眼：False
# 嘴巴实时长宽比:0.30 	是否张嘴：False
# 眼睛实时长宽比:0.34 	是否眨眼：False
# 嘴巴实时长宽比:0.30 	是否张嘴：False
# 眼睛实时长宽比:0.34 	是否眨眼：False
# 嘴巴实时长宽比:0.30 	是否张嘴：False
# 眼睛实时长宽比:0.34 	是否眨眼：False
# pitch:13.384587765274674, yaw:5.587301449482738, roll:3.0079112604144917
# 嘴巴实时长宽比:0.32 	是否张嘴：False
# 眼睛实时长宽比:0.27 	是否眨眼：False
# pitch:12.542853366552794, yaw:4.2403095559277615, roll:2.3938073102096804
# 嘴巴实时长宽比:0.35 	是否张嘴：False
# 眼睛实时长宽比:0.29 	是否眨眼：False
# pitch:12.740274529312344, yaw:2.90994674196566, roll:2.4554628409502435
# 嘴巴实时长宽比:0.33 	是否张嘴：False
# 眼睛实时长宽比:0.30 	是否眨眼：False
# pitch:7.45114025697643, yaw:-0.7023558613489387, roll:2.0987503486211203
# 嘴巴实时长宽比:0.40 	是否张嘴：False
# 眼睛实时长宽比:0.28 	是否眨眼：False
# pitch:6.767571643817139, yaw:-2.407399335050487, roll:2.020981964746015
# 嘴巴实时长宽比:0.41 	是否张嘴：False
# 眼睛实时长宽比:0.30 	是否眨眼：False
# pitch:7.67522701777245, yaw:-2.37384496701326, roll:2.705714173813229
# 嘴巴实时长宽比:0.42 	是否张嘴：False
# 眼睛实时长宽比:0.30 	是否眨眼：False
# pitch:3.722469413343136, yaw:-4.2753122752999175, roll:3.417484827456567
# 嘴巴实时长宽比:0.43 	是否张嘴：False
# 眼睛实时长宽比:0.22 	是否眨眼：False
# pitch:5.508444047341928, yaw:-4.43474256616323, roll:3.309199433084178
# 嘴巴实时长宽比:0.44 	是否张嘴：False
# 眼睛实时长宽比:0.25 	是否眨眼：False
# pitch:3.750556255897186, yaw:-5.825289683030204, roll:3.2913002486450087
# 嘴巴实时长宽比:0.45 	是否张嘴：False
# 眼睛实时长宽比:0.28 	是否眨眼：False
# pitch:3.1600915441028974, yaw:-6.23585289762437, roll:3.30494394284811
# 嘴巴实时长宽比:0.45 	是否张嘴：False
# 眼睛实时长宽比:0.28 	是否眨眼：False
# pitch:4.016823876684622, yaw:-6.5922237965300985, roll:3.0095421361252144
# 嘴巴实时长宽比:0.45 	是否张嘴：False
# 眼睛实时长宽比:0.31 	是否眨眼：False
# pitch:2.6124896821374417, yaw:-6.16401404210365, roll:2.7347689131390163
# 嘴巴实时长宽比:0.46 	是否张嘴：False
# 眼睛实时长宽比:0.31 	是否眨眼：False
# pitch:4.352149366528459, yaw:-6.873015348753406, roll:3.307640644154431
# 嘴巴实时长宽比:0.48 	是否张嘴：False
# 眼睛实时长宽比:0.31 	是否眨眼：False
# pitch:3.2781271291029106, yaw:-6.137772470939078, roll:2.8373397315194557
# 嘴巴实时长宽比:0.47 	是否张嘴：False
# 眼睛实时长宽比:0.34 	是否眨眼：False
# pitch:3.0192762552023793, yaw:-7.240116829431171, roll:3.0608759639163687
# 嘴巴实时长宽比:0.47 	是否张嘴：False
# 眼睛实时长宽比:0.35 	是否眨眼：False
# pitch:3.1845107385290117, yaw:-7.270075527427123, roll:2.7814674522394407
# 嘴巴实时长宽比:0.48 	是否张嘴：False
# 眼睛实时长宽比:0.31 	是否眨眼：False
# pitch:3.063727955718487, yaw:-7.961720298670043, roll:2.4704136249027067
# 嘴巴实时长宽比:0.48 	是否张嘴：False
# 眼睛实时长宽比:0.34 	是否眨眼：False
# pitch:2.862875457475392, yaw:-7.917073523544139, roll:2.7736585238644906
# 嘴巴实时长宽比:0.49 	是否张嘴：False
# 眼睛实时长宽比:0.34 	是否眨眼：False
# pitch:2.862875457475392, yaw:-7.917073523544139, roll:2.7736585238644906
# 嘴巴实时长宽比:0.49 	是否张嘴：False
# 眼睛实时长宽比:0.34 	是否眨眼：False
# pitch:1.8050425994520702, yaw:-8.519860887549752, roll:2.8067624975399346
# 嘴巴实时长宽比:0.50 	是否张嘴：False
# 眼睛实时长宽比:0.27 	是否眨眼：False
# pitch:1.9832122026634498, yaw:-8.451020711537954, roll:3.044452278554901
# 嘴巴实时长宽比:0.48 	是否张嘴：False
# 眼睛实时长宽比:0.20 	是否眨眼：True
# pitch:1.9025899074254466, yaw:-7.894917816277497, roll:3.6309061433163707
# 嘴巴实时长宽比:0.51 	是否张嘴：True
# 眼睛实时长宽比:0.17 	是否眨眼：True
# pitch:2.087949645714915, yaw:-6.7431499136391215, roll:3.574973035544331
# 嘴巴实时长宽比:0.49 	是否张嘴：False
# 眼睛实时长宽比:0.26 	是否眨眼：False
# pitch:2.087949645714915, yaw:-6.7431499136391215, roll:3.574973035544331
# 嘴巴实时长宽比:0.49 	是否张嘴：False
# 眼睛实时长宽比:0.26 	是否眨眼：False
# pitch:1.946390809277528, yaw:-6.516355485361724, roll:4.242066558429652
# 嘴巴实时长宽比:0.52 	是否张嘴：True
# 眼睛实时长宽比:0.30 	是否眨眼：False
# pitch:3.0911763040268823, yaw:-3.133286873119844, roll:4.420645807307882
# 嘴巴实时长宽比:0.47 	是否张嘴：False
# 眼睛实时长宽比:0.31 	是否眨眼：False
# pitch:2.6712988163559057, yaw:-4.389326991284671, roll:5.041381619098694
# 嘴巴实时长宽比:0.48 	是否张嘴：False
# 眼睛实时长宽比:0.31 	是否眨眼：False
# pitch:2.6712988163559057, yaw:-4.389326991284671, roll:5.041381619098694
# 嘴巴实时长宽比:0.48 	是否张嘴：False
# 眼睛实时长宽比:0.31 	是否眨眼：False
# pitch:3.1611805933891546, yaw:-3.585593842806861, roll:5.473803753956863
# 嘴巴实时长宽比:0.47 	是否张嘴：False
# 眼睛实时长宽比:0.33 	是否眨眼：False
# pitch:3.9615912932162773, yaw:-2.1614805403387347, roll:5.952476419296515
# 嘴巴实时长宽比:0.48 	是否张嘴：False
# 眼睛实时长宽比:0.33 	是否眨眼：False
# pitch:4.010083763859994, yaw:-1.602604520009387, roll:5.876563756156832
# 嘴巴实时长宽比:0.46 	是否张嘴：False
# 眼睛实时长宽比:0.32 	是否眨眼：False
# pitch:3.6672120433311535, yaw:-2.9307860840245974, roll:6.412873880961334
# 嘴巴实时长宽比:0.48 	是否张嘴：False
# 眼睛实时长宽比:0.34 	是否眨眼：False
# pitch:3.6672120433311535, yaw:-2.9307860840245974, roll:6.412873880961334
# 嘴巴实时长宽比:0.48 	是否张嘴：False
# 眼睛实时长宽比:0.34 	是否眨眼：False
# pitch:3.454102011950608, yaw:-3.329785032858744, roll:6.642745914730904
# 嘴巴实时长宽比:0.47 	是否张嘴：False
# 眼睛实时长宽比:0.34 	是否眨眼：False
# pitch:4.054160718190772, yaw:-1.7237508645605653, roll:6.751075835134233
# 嘴巴实时长宽比:0.48 	是否张嘴：False
# 眼睛实时长宽比:0.34 	是否眨眼：False
# pitch:3.1819684707032416, yaw:-3.181585974729773, roll:6.841835570436022
# 嘴巴实时长宽比:0.47 	是否张嘴：False
# 眼睛实时长宽比:0.36 	是否眨眼：False
# pitch:3.1819684707032416, yaw:-3.181585974729773, roll:6.841835570436022
# 嘴巴实时长宽比:0.47 	是否张嘴：False
# 眼睛实时长宽比:0.36 	是否眨眼：False
# pitch:2.6946136566039107, yaw:-2.2085303685240145, roll:6.750967784236536
# 嘴巴实时长宽比:0.45 	是否张嘴：False
# 眼睛实时长宽比:0.32 	是否眨眼：False
# pitch:3.908186276832425, yaw:-2.189707261627829, roll:6.589389729798797
# 嘴巴实时长宽比:0.46 	是否张嘴：False
# 眼睛实时长宽比:0.31 	是否眨眼：False
# pitch:3.719904105319677, yaw:-2.870810008959323, roll:6.991243683120583
# 嘴巴实时长宽比:0.48 	是否张嘴：False
# 眼睛实时长宽比:0.33 	是否眨眼：False
# pitch:3.719904105319677, yaw:-2.870810008959323, roll:6.991243683120583
# 嘴巴实时长宽比:0.48 	是否张嘴：False
# 眼睛实时长宽比:0.33 	是否眨眼：False
# pitch:3.0522039148122486, yaw:-2.2927500804384366, roll:6.86501734835481
# 嘴巴实时长宽比:0.45 	是否张嘴：False
# 眼睛实时长宽比:0.32 	是否眨眼：False
# pitch:3.4057790961748737, yaw:-2.1555810422049615, roll:6.667774033182622
# 嘴巴实时长宽比:0.48 	是否张嘴：False
# 眼睛实时长宽比:0.35 	是否眨眼：False
# pitch:3.7752702650829733, yaw:-2.318954927438585, roll:7.054201960875369
# 嘴巴实时长宽比:0.46 	是否张嘴：False
# 眼睛实时长宽比:0.32 	是否眨眼：False
# pitch:3.7752702650829733, yaw:-2.318954927438585, roll:7.054201960875369
# 嘴巴实时长宽比:0.46 	是否张嘴：False
# 眼睛实时长宽比:0.32 	是否眨眼：False
# pitch:3.307590753631005, yaw:-2.1501610598543177, roll:6.748520272437485
# 嘴巴实时长宽比:0.48 	是否张嘴：False
# 眼睛实时长宽比:0.34 	是否眨眼：False
# pitch:3.946023850363347, yaw:-1.725868139006354, roll:6.664194001000167
# 嘴巴实时长宽比:0.46 	是否张嘴：False
# 眼睛实时长宽比:0.33 	是否眨眼：False
# pitch:4.464705533792935, yaw:-1.1945710411298485, roll:6.649879185140724
# 嘴巴实时长宽比:0.47 	是否张嘴：False
# 眼睛实时长宽比:0.33 	是否眨眼：False
# pitch:3.3627630038843, yaw:-1.912710855099915, roll:6.714208532029035
# 嘴巴实时长宽比:0.48 	是否张嘴：False
# 眼睛实时长宽比:0.34 	是否眨眼：False
# pitch:3.3627630038843, yaw:-1.912710855099915, roll:6.714208532029035
# 嘴巴实时长宽比:0.48 	是否张嘴：False
# 眼睛实时长宽比:0.34 	是否眨眼：False
# pitch:3.938078690140958, yaw:-0.4554472468335353, roll:6.207970131360372
# 嘴巴实时长宽比:0.46 	是否张嘴：False
# 眼睛实时长宽比:0.33 	是否眨眼：False
# pitch:4.010009918038293, yaw:-1.71484729444088, roll:6.536033475843926
# 嘴巴实时长宽比:0.47 	是否张嘴：False
# 眼睛实时长宽比:0.34 	是否眨眼：False
# pitch:3.2737843105372155, yaw:-2.433891219138844, roll:6.4427628091638285
# 嘴巴实时长宽比:0.48 	是否张嘴：False
# 眼睛实时长宽比:0.34 	是否眨眼：False
# pitch:3.2737843105372155, yaw:-2.433891219138844, roll:6.4427628091638285
# 嘴巴实时长宽比:0.48 	是否张嘴：False
# 眼睛实时长宽比:0.34 	是否眨眼：False
# pitch:3.6731009320985986, yaw:-2.0813980614347605, roll:6.636870195618542
# 嘴巴实时长宽比:0.47 	是否张嘴：False
# 眼睛实时长宽比:0.34 	是否眨眼：False
# pitch:4.331393941425209, yaw:-1.8846456104657237, roll:6.808619944900054
# 嘴巴实时长宽比:0.47 	是否张嘴：False
# 眼睛实时长宽比:0.34 	是否眨眼：False
# pitch:3.3220177678283753, yaw:-1.578898572105709, roll:6.481104686271883
# 嘴巴实时长宽比:0.47 	是否张嘴：False
# 眼睛实时长宽比:0.32 	是否眨眼：False
# pitch:4.548962873709683, yaw:-1.32998031137784, roll:6.731637777182183
# 嘴巴实时长宽比:0.47 	是否张嘴：False
# 眼睛实时长宽比:0.32 	是否眨眼：False
# pitch:4.548962873709683, yaw:-1.32998031137784, roll:6.731637777182183
# 嘴巴实时长宽比:0.47 	是否张嘴：False
# 眼睛实时长宽比:0.32 	是否眨眼：False
# pitch:3.9931996160234924, yaw:-2.5021434276992633, roll:6.723847610486964
# 嘴巴实时长宽比:0.47 	是否张嘴：False
# 眼睛实时长宽比:0.34 	是否眨眼：False
# pitch:3.9931996160234924, yaw:-2.5021434276992633, roll:6.723847610486964
# 嘴巴实时长宽比:0.47 	是否张嘴：False
# 眼睛实时长宽比:0.34 	是否眨眼：False
# pitch:3.90639792137098, yaw:-2.7122693242534583, roll:6.314101294950537
# 嘴巴实时长宽比:0.47 	是否张嘴：False
# 眼睛实时长宽比:0.33 	是否眨眼：False
# pitch:3.90639792137098, yaw:-2.7122693242534583, roll:6.314101294950537
# 嘴巴实时长宽比:0.47 	是否张嘴：False
# 眼睛实时长宽比:0.33 	是否眨眼：False
# pitch:4.170622707551945, yaw:-2.8702198211632504, roll:6.7356301142609665
# 嘴巴实时长宽比:0.48 	是否张嘴：False
# 眼睛实时长宽比:0.32 	是否眨眼：False
# pitch:4.170622707551945, yaw:-2.8702198211632504, roll:6.7356301142609665
# 嘴巴实时长宽比:0.48 	是否张嘴：False
# 眼睛实时长宽比:0.32 	是否眨眼：False
# pitch:3.696451077824398, yaw:-2.137477730209485, roll:6.3626226607392535
# 嘴巴实时长宽比:0.46 	是否张嘴：False
# 眼睛实时长宽比:0.31 	是否眨眼：False
# pitch:3.696451077824398, yaw:-2.137477730209485, roll:6.3626226607392535
# 嘴巴实时长宽比:0.46 	是否张嘴：False
# 眼睛实时长宽比:0.31 	是否眨眼：False
# pitch:3.997651611379635, yaw:-2.524687094859195, roll:6.429563829098184
# 嘴巴实时长宽比:0.50 	是否张嘴：False
# 眼睛实时长宽比:0.31 	是否眨眼：False
# pitch:3.997651611379635, yaw:-2.524687094859195, roll:6.429563829098184
# 嘴巴实时长宽比:0.50 	是否张嘴：False
# 眼睛实时长宽比:0.31 	是否眨眼：False
# pitch:3.9886340459942797, yaw:-3.883231632074365, roll:6.475600571449878
# 嘴巴实时长宽比:0.46 	是否张嘴：False
# 眼睛实时长宽比:0.32 	是否眨眼：False
# pitch:3.9886340459942797, yaw:-3.883231632074365, roll:6.475600571449878
# 嘴巴实时长宽比:0.46 	是否张嘴：False
# 眼睛实时长宽比:0.32 	是否眨眼：False
# pitch:4.225450852235603, yaw:-3.766110155160422, roll:6.850569558123457
# 嘴巴实时长宽比:0.48 	是否张嘴：False
# 眼睛实时长宽比:0.33 	是否眨眼：False
# pitch:4.225450852235603, yaw:-3.766110155160422, roll:6.850569558123457
# 嘴巴实时长宽比:0.48 	是否张嘴：False
# 眼睛实时长宽比:0.33 	是否眨眼：False
# pitch:4.249595164915658, yaw:-1.972846025044614, roll:6.616228272457588
# 嘴巴实时长宽比:0.48 	是否张嘴：False
# 眼睛实时长宽比:0.30 	是否眨眼：False
# pitch:4.249595164915658, yaw:-1.972846025044614, roll:6.616228272457588
# 嘴巴实时长宽比:0.48 	是否张嘴：False
# 眼睛实时长宽比:0.30 	是否眨眼：False
# pitch:4.777201897423443, yaw:-3.1375831581209774, roll:6.450084889179994
# 嘴巴实时长宽比:0.49 	是否张嘴：False
# 眼睛实时长宽比:0.34 	是否眨眼：False
# pitch:4.777201897423443, yaw:-3.1375831581209774, roll:6.450084889179994
# 嘴巴实时长宽比:0.49 	是否张嘴：False
# 眼睛实时长宽比:0.34 	是否眨眼：False
# pitch:5.590759406186667, yaw:-2.551778235915643, roll:6.635896045082974
# 嘴巴实时长宽比:0.49 	是否张嘴：False
# 眼睛实时长宽比:0.31 	是否眨眼：False
# pitch:5.590759406186667, yaw:-2.551778235915643, roll:6.635896045082974
# 嘴巴实时长宽比:0.49 	是否张嘴：False
# 眼睛实时长宽比:0.31 	是否眨眼：False
# pitch:5.535339901574971, yaw:-3.0657518788355524, roll:6.82391248083672
# 嘴巴实时长宽比:0.48 	是否张嘴：False
# 眼睛实时长宽比:0.31 	是否眨眼：False
# pitch:5.535339901574971, yaw:-3.0657518788355524, roll:6.82391248083672
# 嘴巴实时长宽比:0.48 	是否张嘴：False
# 眼睛实时长宽比:0.31 	是否眨眼：False
# pitch:4.838625017562832, yaw:-1.8071049514962427, roll:6.27803013453439
# 嘴巴实时长宽比:0.48 	是否张嘴：False
# 眼睛实时长宽比:0.33 	是否眨眼：False
# pitch:4.838625017562832, yaw:-1.8071049514962427, roll:6.27803013453439
# 嘴巴实时长宽比:0.48 	是否张嘴：False
# 眼睛实时长宽比:0.33 	是否眨眼：False
# pitch:4.444475401014598, yaw:-1.2133756891488927, roll:6.072072020888914
# 嘴巴实时长宽比:0.47 	是否张嘴：False
# 眼睛实时长宽比:0.34 	是否眨眼：False
# pitch:4.444475401014598, yaw:-1.2133756891488927, roll:6.072072020888914
# 嘴巴实时长宽比:0.47 	是否张嘴：False
# 眼睛实时长宽比:0.34 	是否眨眼：False
# pitch:5.039061585085842, yaw:-1.887632205112788, roll:6.341189720277875
# 嘴巴实时长宽比:0.47 	是否张嘴：False
# 眼睛实时长宽比:0.32 	是否眨眼：False
# pitch:5.039061585085842, yaw:-1.887632205112788, roll:6.341189720277875
# 嘴巴实时长宽比:0.47 	是否张嘴：False
# 眼睛实时长宽比:0.32 	是否眨眼：False
# pitch:4.716387219981687, yaw:-1.876408654031538, roll:5.9440059183450265
# 嘴巴实时长宽比:0.46 	是否张嘴：False
# 眼睛实时长宽比:0.34 	是否眨眼：False
# pitch:4.716387219981687, yaw:-1.876408654031538, roll:5.9440059183450265
# 嘴巴实时长宽比:0.46 	是否张嘴：False
# 眼睛实时长宽比:0.34 	是否眨眼：False
# pitch:4.295915554322038, yaw:-2.5461383854652806, roll:6.340307887796307
# 嘴巴实时长宽比:0.47 	是否张嘴：False
# 眼睛实时长宽比:0.35 	是否眨眼：False
# pitch:4.295915554322038, yaw:-2.5461383854652806, roll:6.340307887796307
# 嘴巴实时长宽比:0.47 	是否张嘴：False
# 眼睛实时长宽比:0.35 	是否眨眼：False
# pitch:4.733423028176702, yaw:-2.676564746763639, roll:6.34904740438818
# 嘴巴实时长宽比:0.46 	是否张嘴：False
# 眼睛实时长宽比:0.34 	是否眨眼：False
# pitch:4.733423028176702, yaw:-2.676564746763639, roll:6.34904740438818
# 嘴巴实时长宽比:0.46 	是否张嘴：False
# 眼睛实时长宽比:0.34 	是否眨眼：False
# pitch:3.961337781825452, yaw:-2.229978789311464, roll:6.176360660028035
# 嘴巴实时长宽比:0.46 	是否张嘴：False
# 眼睛实时长宽比:0.34 	是否眨眼：False
# pitch:3.961337781825452, yaw:-2.229978789311464, roll:6.176360660028035
# 嘴巴实时长宽比:0.46 	是否张嘴：False
# 眼睛实时长宽比:0.34 	是否眨眼：False
# pitch:3.9167502220576997, yaw:-2.3085055739990223, roll:6.176123801105742
# 嘴巴实时长宽比:0.48 	是否张嘴：False
# 眼睛实时长宽比:0.34 	是否眨眼：False
# pitch:3.9167502220576997, yaw:-2.3085055739990223, roll:6.176123801105742
# 嘴巴实时长宽比:0.48 	是否张嘴：False
# 眼睛实时长宽比:0.34 	是否眨眼：False
# pitch:4.153575898177844, yaw:-1.8766027734784108, roll:6.0737505340672095
# 嘴巴实时长宽比:0.47 	是否张嘴：False
# 眼睛实时长宽比:0.33 	是否眨眼：False
# pitch:4.153575898177844, yaw:-1.8766027734784108, roll:6.0737505340672095
# 嘴巴实时长宽比:0.47 	是否张嘴：False
# 眼睛实时长宽比:0.33 	是否眨眼：False
# pitch:3.7030946040759414, yaw:-1.3913903600285655, roll:5.966447732541464
# 嘴巴实时长宽比:0.47 	是否张嘴：False
# 眼睛实时长宽比:0.34 	是否眨眼：False
# pitch:3.7030946040759414, yaw:-1.3913903600285655, roll:5.966447732541464
# 嘴巴实时长宽比:0.47 	是否张嘴：False
# 眼睛实时长宽比:0.34 	是否眨眼：False
# pitch:3.141305640309436, yaw:-1.5793295044992572, roll:5.800744952700831
# 嘴巴实时长宽比:0.49 	是否张嘴：False
# 眼睛实时长宽比:0.21 	是否眨眼：False
# pitch:3.141305640309436, yaw:-1.5793295044992572, roll:5.800744952700831
# 嘴巴实时长宽比:0.49 	是否张嘴：False
# 眼睛实时长宽比:0.21 	是否眨眼：False
# pitch:2.628607793087812, yaw:-1.4241968826973819, roll:6.053022906785264
# 嘴巴实时长宽比:0.46 	是否张嘴：False
# 眼睛实时长宽比:0.16 	是否眨眼：True
# pitch:3.755484765005192, yaw:-1.6851750664766951, roll:6.204763759340146
# 嘴巴实时长宽比:0.47 	是否张嘴：False
# 眼睛实时长宽比:0.26 	是否眨眼：False
# pitch:3.755484765005192, yaw:-1.6851750664766951, roll:6.204763759340146
# 嘴巴实时长宽比:0.47 	是否张嘴：False
# 眼睛实时长宽比:0.26 	是否眨眼：False
# pitch:3.6089922265912118, yaw:-1.1002586104582193, roll:6.416227184518095
# 嘴巴实时长宽比:0.48 	是否张嘴：False
# 眼睛实时长宽比:0.29 	是否眨眼：False
# pitch:3.6089922265912118, yaw:-1.1002586104582193, roll:6.416227184518095
# 嘴巴实时长宽比:0.48 	是否张嘴：False
# 眼睛实时长宽比:0.29 	是否眨眼：False
# pitch:4.234702334299551, yaw:-0.7136787820224828, roll:6.339860694141606
# 嘴巴实时长宽比:0.46 	是否张嘴：False
# 眼睛实时长宽比:0.30 	是否眨眼：False
# pitch:4.234702334299551, yaw:-0.7136787820224828, roll:6.339860694141606
# 嘴巴实时长宽比:0.46 	是否张嘴：False
# 眼睛实时长宽比:0.30 	是否眨眼：False
# pitch:5.377859907185469, yaw:-1.1206897009067198, roll:6.549490225374788
# 嘴巴实时长宽比:0.45 	是否张嘴：False
# 眼睛实时长宽比:0.31 	是否眨眼：False
# pitch:5.377859907185469, yaw:-1.1206897009067198, roll:6.549490225374788
# 嘴巴实时长宽比:0.45 	是否张嘴：False
# 眼睛实时长宽比:0.31 	是否眨眼：False
# pitch:5.150931514045909, yaw:-1.2753224061821546, roll:6.521610888527002
# 嘴巴实时长宽比:0.46 	是否张嘴：False
# 眼睛实时长宽比:0.34 	是否眨眼：False
# pitch:5.150931514045909, yaw:-1.2753224061821546, roll:6.521610888527002
# 嘴巴实时长宽比:0.46 	是否张嘴：False
# 眼睛实时长宽比:0.34 	是否眨眼：False
# pitch:4.947147821710938, yaw:-0.836604188161981, roll:6.303386574522709
# 嘴巴实时长宽比:0.44 	是否张嘴：False
# 眼睛实时长宽比:0.33 	是否眨眼：False
# pitch:4.947147821710938, yaw:-0.836604188161981, roll:6.303386574522709
# 嘴巴实时长宽比:0.44 	是否张嘴：False
# 眼睛实时长宽比:0.33 	是否眨眼：False
# pitch:4.645301089325982, yaw:-0.46344716844440587, roll:6.3727352316882095
# 嘴巴实时长宽比:0.44 	是否张嘴：False
# 眼睛实时长宽比:0.32 	是否眨眼：False
# pitch:4.645301089325982, yaw:-0.46344716844440587, roll:6.3727352316882095
# 嘴巴实时长宽比:0.44 	是否张嘴：False
# 眼睛实时长宽比:0.32 	是否眨眼：False
# pitch:4.082262722364871, yaw:-1.9598797304016269, roll:6.4294794782364155
# 嘴巴实时长宽比:0.47 	是否张嘴：False
# 眼睛实时长宽比:0.35 	是否眨眼：False
# pitch:4.082262722364871, yaw:-1.9598797304016269, roll:6.4294794782364155
# 嘴巴实时长宽比:0.47 	是否张嘴：False
# 眼睛实时长宽比:0.35 	是否眨眼：False
# pitch:3.9283357342951706, yaw:-2.066761190135689, roll:6.088065071544658
# 嘴巴实时长宽比:0.45 	是否张嘴：False
# 眼睛实时长宽比:0.19 	是否眨眼：True
# pitch:3.9283357342951706, yaw:-2.066761190135689, roll:6.088065071544658
# 嘴巴实时长宽比:0.45 	是否张嘴：False
# 眼睛实时长宽比:0.19 	是否眨眼：True
# pitch:3.2154638835859175, yaw:-1.1759291927128221, roll:6.081632996923217
# 嘴巴实时长宽比:0.46 	是否张嘴：False
# 眼睛实时长宽比:0.17 	是否眨眼：True
# pitch:1.7115025137631719, yaw:-0.1407856533098234, roll:5.865919262197462
# 嘴巴实时长宽比:0.46 	是否张嘴：False
# 眼睛实时长宽比:0.21 	是否眨眼：False
# pitch:4.223345639867084, yaw:-0.44913906436157, roll:6.461304766853697
# 嘴巴实时长宽比:0.46 	是否张嘴：False
# 眼睛实时长宽比:0.22 	是否眨眼：False
# pitch:3.3532357900479313, yaw:-1.0143761020290023, roll:6.4788773593671065
# 嘴巴实时长宽比:0.48 	是否张嘴：False
# 眼睛实时长宽比:0.24 	是否眨眼：False
# pitch:3.3532357900479313, yaw:-1.0143761020290023, roll:6.4788773593671065
# 嘴巴实时长宽比:0.48 	是否张嘴：False
# 眼睛实时长宽比:0.24 	是否眨眼：False
# pitch:3.4511828164638603, yaw:-0.40928507468847075, roll:6.086268096453293
# 嘴巴实时长宽比:0.45 	是否张嘴：False
# 眼睛实时长宽比:0.23 	是否眨眼：False
# pitch:3.670900484154527, yaw:-0.5743181927066354, roll:6.22177588332116
# 嘴巴实时长宽比:0.48 	是否张嘴：False
# 眼睛实时长宽比:0.23 	是否眨眼：False
# pitch:3.72902877774628, yaw:0.0901042621898186, roll:6.088849494922565
# 嘴巴实时长宽比:0.46 	是否张嘴：False
# 眼睛实时长宽比:0.24 	是否眨眼：False
# pitch:3.72902877774628, yaw:0.0901042621898186, roll:6.088849494922565
# 嘴巴实时长宽比:0.46 	是否张嘴：False
# 眼睛实时长宽比:0.24 	是否眨眼：False
# pitch:4.2005437717723595, yaw:-1.6909303537975389, roll:6.391430059324661
# 嘴巴实时长宽比:0.46 	是否张嘴：False
# 眼睛实时长宽比:0.23 	是否眨眼：False
# pitch:4.225133448278377, yaw:-1.5964494421577118, roll:6.544225131552474
# 嘴巴实时长宽比:0.48 	是否张嘴：False
# 眼睛实时长宽比:0.24 	是否眨眼：False
# pitch:3.5506381539222076, yaw:-1.4906565864301853, roll:6.227168088145425
# 嘴巴实时长宽比:0.48 	是否张嘴：False
# 眼睛实时长宽比:0.26 	是否眨眼：False
# pitch:3.5506381539222076, yaw:-1.4906565864301853, roll:6.227168088145425
# 嘴巴实时长宽比:0.48 	是否张嘴：False
# 眼睛实时长宽比:0.26 	是否眨眼：False
# pitch:3.877292170557796, yaw:-2.832384685638085, roll:6.28007722526024
# 嘴巴实时长宽比:0.50 	是否张嘴：False
# 眼睛实时长宽比:0.25 	是否眨眼：False
# pitch:2.892647557915585, yaw:-2.360847543846889, roll:6.314694944349284
# 嘴巴实时长宽比:0.51 	是否张嘴：True
# 眼睛实时长宽比:0.25 	是否眨眼：False
# pitch:3.751705364196626, yaw:-1.8615303250462492, roll:6.1345887591992945
# 嘴巴实时长宽比:0.48 	是否张嘴：False
# 眼睛实时长宽比:0.20 	是否眨眼：True
# pitch:3.4198923979194995, yaw:-2.5387556466815213, roll:6.374891763121175
# 嘴巴实时长宽比:0.48 	是否张嘴：False
# 眼睛实时长宽比:0.18 	是否眨眼：True

# %%
import numpy as np
x=np.array([5,3,0])
y=np.array([4,4,0])
# 两个向量
Lx=np.sqrt(x.dot(x))
Ly=np.sqrt(y.dot(y))
#相当于勾股定理，求得斜线的长度
cos_angle=x.dot(y)/(Lx*Ly)#求得cos_sita的值再反过来计算，绝对长度乘以cos角度为矢量长度
angle=np.arccos(cos_angle)
angle2=angle*360/2/np.pi#变为角度
print(angle2)
#x.dot(y) =  y=∑(ai*bi)
# Out:
# 14.036243467926484

# %%
import numpy as np
a = np.array([0,1,0])
b = np.array([0,0,0])
c = np.array([1,0,0])
# 两个向量
Lba = np.sqrt((a-b).dot(a-b))
Lbc = np.sqrt((c-b).dot(c-b))
cos_angle = (a-b).dot(c-b)/(Lba*Lbc)#相当于勾股定理，求得斜线的长度
angle = np.arccos(cos_angle)#求得cos_sita的值再反过来计算，绝对长度乘以cos角度为矢量长度
angle2=angle*360/2/np.pi#变为角度
print(angle2)
# Out:
# 90.0
